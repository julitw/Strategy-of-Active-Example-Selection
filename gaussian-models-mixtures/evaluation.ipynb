# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from utils import evaluate_predictions_from_folders
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %%
# folder_paths = ['results/emb_temp0/gpt4omini', 'results/emb_temp0/llama3', 'results/emb_temp0/cohere'   ]
folder_paths = ['results/emb_temp0/llama3'  ]

# %%
df = evaluate_predictions_from_folders(folder_paths, True, 'original_label', 'output' )
df.sort_values(by='file')
# Out:
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# błąd przetwarzania pliku results/emb_temp0/llama3/20_newsgroups_llama3_emb_gaussian_temp0_expstare.csv: 'was_in_selected_samples'
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# błąd przetwarzania pliku results/emb_temp0/llama3/social_media_llama3_emb_kmeans_temp0_exp1.csv: 'was_in_selected_samples'
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                                 file  accuracy  f1_score  \
# 13  20_newsgroups_llama3_emb_gaussian_temp0_exp1.csv  0.721676  0.608166
# 2     20_newsgroups_llama3_emb_kmeans_temp0_exp1.csv  0.676561  0.566949
# 4   20_newsgroups_llama3_emb_spectral_temp0_exp1.csv  0.704103  0.505870
# 7         ag_news_llama3_emb_gaussian_temp0_exp1.csv  0.875000  0.874336
# 10          ag_news_llama3_emb_kmeans_temp0_exp1.csv  0.897246  0.449827
# 9         ag_news_llama3_emb_spectral_temp0_exp1.csv  0.868783  0.868136
# 16    go_emotions_llama3_emb_gaussian_temp0_exp1.csv  0.370192  0.194700
# 14      go_emotions_llama3_emb_kmeans_temp0_exp1.csv  0.351901  0.178701
# 0     go_emotions_llama3_emb_spectral_temp0_exp1.csv  0.350718  0.184891
# 15   social_media_llama3_emb_gaussian_temp0_exp1.csv  0.692386  0.554234
# 6    social_media_llama3_emb_spectral_temp0_exp1.csv  0.656657  0.498397
# 1            sst5_llama3_emb_gaussian_temp0_exp1.csv  0.566528  0.399692
# 8              sst5_llama3_emb_kmeans_temp0_exp1.csv  0.562694  0.560421
# 5            sst5_llama3_emb_spectral_temp0_exp1.csv  0.565940  0.566333
# 11          yahoo_llama3_emb_gaussian_temp0_exp1.csv  0.703206  0.573698
# 12            yahoo_llama3_emb_kmeans_temp0_exp1.csv  0.724352  0.656390
# 3           yahoo_llama3_emb_spectral_temp0_exp1.csv  0.716062  0.712610
#
#       recall  precision
# 13  0.602063   0.633675
# 2   0.559441   0.643101
# 4   0.503464   0.533734
# 7   0.875519   0.877492
# 10  0.449186   0.452136
# 9   0.868993   0.874241
# 16  0.193698   0.241108
# 14  0.180090   0.238146
# 0   0.183482   0.249959
# 15  0.546422   0.591749
# 6   0.497324   0.620026
# 1   0.405885   0.438023
# 8   0.564060   0.616063
# 5   0.566471   0.606937
# 11  0.587560   0.607774
# 12  0.658084   0.669118
# 3   0.716220   0.730103
