# %%
import os 
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd # type: ignore

# %%
from utils import get_dataset, get_model_by_tag, get_prompt_template
from LLMAnnotator import LLMAnnotator

# %%
os.environ['OPENAI_API_KEY_CLARIN']=os.getenv("OPENAI_API_KEY_CLARIN")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

token = os.getenv("OPENAI_API_KEY_CLARIN")

# %%
model_tag = 'llama3'  
dataset_tag = 'social_media'
prompt = 'no_samples'
temp = 0
number_of_experimet = 1

# %%
model = get_model_by_tag(model_tag, token, temp)  
dataset_for_annotation = get_dataset(dataset_tag=dataset_tag)
prompt_txt = get_prompt_template(dataset_tag, prompt)
examples_for_prompt = pd.DataFrame()

output_path = f'./results/{prompt}_temp{temp}/{model_tag}/{dataset_tag}_{model_tag}_{prompt}_temp{temp}_exp{number_of_experimet}.csv'
os.makedirs(f'./results/{prompt}_temp{temp}/{model_tag}', exist_ok=True)

# %%
dataset_for_annotation.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
print(model, dataset_for_annotation, prompt_txt, examples_for_prompt, output_path)
# Out:
# Llama3_1LLM
# Params: {}                                                    text           label
# 0     2020 is in less than 2 hours and I don't feel ...        moderate
# 1     Depression or laziness? : For quite a long tim...        moderate
# 2     $1,000,000 or no more depression? : Which woul...  not depression
# 3     Negative Nancy : I’ve recently started dating ...        moderate
# 4     I’m sure I’ll die alone at this point : I know...        moderate
# ...                                                 ...             ...
# 1062  Two labels, two boxes : A month or so ago, in ...        moderate
# 1063  I almost cried while my family was wishing eac...        moderate
# 1064  Am I the only one who hates new years? : Now t...        moderate
# 1065  I just want to smile. : I can’t smile. It does...          severe
# 1066  new year new chance : I wanted to go on a new ...        moderate
#
# [1067 rows x 2 columns] Task: Read the following text and determine the most appropriate category based on its content.
#
# Categories:
# - not depression
# - moderate
# - severe
#
# Text for you: "{text}"
#
# Return only one category. No explanations. Empty DataFrame
# Columns: []
# Index: [] ./results/no_samples_temp0/llama3/social_media_llama3_no_samples_temp0_exp1.csv

# %%
text_col = "text"
label_col = "label"
output_col = "output"

# %%
annotator = LLMAnnotator(
    model=model,
    dataset=dataset_for_annotation,
    examples_for_prompt=examples_for_prompt,
    prompt_template=prompt_txt,
    column_text=text_col,
    column_label=label_col,
    column_output=output_col
)

# %%
df = annotator.get_results()
# Out:
# Nr: 0 Predicted label: severe
# Nr: 1 Predicted label: severe
# Nr: 2 Predicted label: not depression
# Nr: 3 Predicted label: moderate
# Nr: 4 Predicted label: severe
# Nr: 5 Predicted label: moderate
# Nr: 6 Predicted label: severe
# Nr: 7 Predicted label: severe
# Nr: 8 Predicted label: severe
# Nr: 9 Predicted label: severe
# Nr: 10 Predicted label: severe
# Nr: 11 Predicted label: severe
# Nr: 12 Predicted label: severe
# Nr: 13 Predicted label: moderate
# Nr: 14 Predicted label: severe
# Nr: 15 Predicted label: not depression
# Nr: 16 Predicted label: not depression
# Nr: 17 Predicted label: moderate
# Nr: 18 Predicted label: severe
# Nr: 19 Predicted label: severe
# Nr: 20 Predicted label: severe
# Nr: 21 Predicted label: severe
# Nr: 22 Predicted label: not depression
# Nr: 23 Predicted label: severe
# Nr: 24 Predicted label: severe
# Nr: 25 Predicted label: severe
# Nr: 26 Predicted label: severe
# Nr: 27 Predicted label: moderate
# Nr: 28 Predicted label: severe
# Nr: 29 Predicted label: severe
# Nr: 30 Predicted label: severe
# Nr: 31 Predicted label: moderate
# Nr: 32 Predicted label: severe
# Nr: 33 Predicted label: severe
# Nr: 34 Predicted label: severe
# Nr: 35 Predicted label: not depression
# Nr: 36 Predicted label: moderate
# Nr: 37 Predicted label: severe
# Nr: 38 Predicted label: severe
# Nr: 39 Predicted label: severe
# Nr: 40 Predicted label: severe
# Nr: 41 Predicted label: severe
# Nr: 42 Predicted label: severe
# Nr: 43 Predicted label: severe
# Nr: 44 Predicted label: not depression
# Nr: 45 Predicted label: moderate
# Nr: 46 Predicted label: not depression
# Nr: 47 Predicted label: severe
# Nr: 48 Predicted label: severe
# Nr: 49 Predicted label: moderate
# Nr: 50 Predicted label: severe
# Nr: 51 Predicted label: severe
# Nr: 52 Predicted label: severe
# Nr: 53 Predicted label: not depression
# Nr: 54 Predicted label: not depression
# Nr: 55 Predicted label: not depression
# Nr: 56 Predicted label: not depression
# Nr: 57 Predicted label: severe
# Nr: 58 Predicted label: moderate
# Nr: 59 Predicted label: severe
# Nr: 60 Predicted label: severe
# Nr: 61 Predicted label: severe
# Nr: 62 Predicted label: not depression
# Nr: 63 Predicted label: severe
# Nr: 64 Predicted label: not depression
# Nr: 65 Predicted label: moderate
# Nr: 66 Predicted label: severe
# Nr: 67 Predicted label: not depression
# Nr: 68 Predicted label: moderate
# Nr: 69 Predicted label: moderate
# Nr: 70 Predicted label: not depression
# Nr: 71 Predicted label: severe
# Nr: 72 Predicted label: not depression
# Nr: 73 Predicted label: severe
# Nr: 74 Predicted label: severe
# Nr: 75 Predicted label: severe
# Nr: 76 Predicted label: severe
# Nr: 77 Predicted label: severe
# Nr: 78 Predicted label: severe
# Nr: 79 Predicted label: severe
# Nr: 80 Predicted label: severe
# Nr: 81 Predicted label: moderate
# Nr: 82 Predicted label: severe
# Nr: 83 Predicted label: not depression
# Nr: 84 Predicted label: severe
# Nr: 85 Predicted label: severe
# Nr: 86 Predicted label: severe
# Nr: 87 Predicted label: not depression
# Nr: 88 Predicted label: severe
# Nr: 89 Predicted label: severe
# Nr: 90 Predicted label: severe
# Nr: 91 Predicted label: not depression
# Nr: 92 Predicted label: severe
# Nr: 93 Predicted label: severe
# Nr: 94 Predicted label: severe
# Nr: 95 Predicted label: severe
# Nr: 96 Predicted label: moderate
# Nr: 97 Predicted label: severe
# Nr: 98 Predicted label: not depression
# Nr: 99 Predicted label: severe
# Nr: 100 Predicted label: severe
# Nr: 101 Predicted label: moderate
# Nr: 102 Predicted label: severe
# Nr: 103 Predicted label: not depression
# Nr: 104 Predicted label: severe
# Nr: 105 Predicted label: severe
# Nr: 106 Predicted label: Severe
# Nr: 107 Predicted label: severe
# Nr: 108 Predicted label: severe
# Nr: 109 Predicted label: severe
# Nr: 110 Predicted label: severe
# Nr: 111 Predicted label: moderate
# Nr: 112 Predicted label: not depression
# Nr: 113 Predicted label: severe
# Nr: 114 Predicted label: severe
# Nr: 115 Predicted label: severe
# Nr: 116 Predicted label: severe
# Nr: 117 Predicted label: moderate
# Nr: 118 Predicted label: severe
# Nr: 119 Predicted label: severe
# Nr: 120 Predicted label: moderate
# Nr: 121 Predicted label: not depression
# Nr: 122 Predicted label: severe
# Nr: 123 Predicted label: severe
# Nr: 124 Predicted label: not depression
# Nr: 125 Predicted label: severe
# Nr: 126 Predicted label: severe
# Nr: 127 Predicted label: severe
# Nr: 128 Predicted label: severe
# Nr: 129 Predicted label: moderate
# Nr: 130 Predicted label: severe
# Nr: 131 Predicted label: severe
# Nr: 132 Predicted label: severe
# Nr: 133 Predicted label: severe
# Nr: 134 Predicted label: severe
# Nr: 135 Predicted label: severe
# Nr: 136 Predicted label: severe
# Nr: 137 Predicted label: severe
# Nr: 138 Predicted label: severe
# Nr: 139 Predicted label: severe
# Nr: 140 Predicted label: not depression
# Nr: 141 Predicted label: severe
# Nr: 142 Predicted label: not depression
# Nr: 143 Predicted label: severe
# Nr: 144 Predicted label: moderate
# Nr: 145 Predicted label: severe
# Nr: 146 Predicted label: severe
# Nr: 147 Predicted label: not depression
# Nr: 148 Predicted label: severe
# Nr: 149 Predicted label: severe
# Nr: 150 Predicted label: not depression
# Nr: 151 Predicted label: severe
# Nr: 152 Predicted label: severe
# Nr: 153 Predicted label: not depression
# Nr: 154 Predicted label: severe
# Nr: 155 Predicted label: severe
# Nr: 156 Predicted label: severe
# Nr: 157 Predicted label: severe
# Nr: 158 Predicted label: severe
# Nr: 159 Predicted label: severe
# Nr: 160 Predicted label: severe
# Nr: 161 Predicted label: severe
# Nr: 162 Predicted label: not depression
# Nr: 163 Predicted label: severe
# Nr: 164 Predicted label: severe
# Nr: 165 Predicted label: moderate
# Nr: 166 Predicted label: severe
# Nr: 167 Predicted label: severe
# Nr: 168 Predicted label: severe
# Nr: 169 Predicted label: moderate
# Nr: 170 Predicted label: severe
# Nr: 171 Predicted label: severe
# Nr: 172 Predicted label: severe
# Nr: 173 Predicted label: not depression
# Nr: 174 Predicted label: severe
# Nr: 175 Predicted label: severe
# Nr: 176 Predicted label: severe
# Nr: 177 Predicted label: severe
# Nr: 178 Predicted label: moderate
# Nr: 179 Predicted label: severe
# Nr: 180 Predicted label: moderate
# Nr: 181 Predicted label: severe
# Nr: 182 Predicted label: severe
# Nr: 183 Predicted label: severe
# Nr: 184 Predicted label: severe
# Nr: 185 Predicted label: severe
# Nr: 186 Predicted label: severe
# Nr: 187 Predicted label: moderate
# Nr: 188 Predicted label: severe
# Nr: 189 Predicted label: not depression
# Nr: 190 Predicted label: moderate
# Nr: 191 Predicted label: severe
# Nr: 192 Predicted label: moderate
# Nr: 193 Predicted label: severe
# Nr: 194 Predicted label: severe
# Nr: 195 Predicted label: not depression
# Nr: 196 Predicted label: severe
# Nr: 197 Predicted label: severe
# Nr: 198 Predicted label: severe
# Nr: 199 Predicted label: severe
# Nr: 200 Predicted label: severe
# Nr: 201 Predicted label: not depression
# Nr: 202 Predicted label: not depression
# Nr: 203 Predicted label: moderate
# Nr: 204 Predicted label: not depression
# Nr: 205 Predicted label: severe
# Nr: 206 Predicted label: not depression
# Nr: 207 Predicted label: severe
# Nr: 208 Predicted label: severe
# Nr: 209 Predicted label: severe
# Nr: 210 Predicted label: moderate
# Nr: 211 Predicted label: severe
# Nr: 212 Predicted label: severe
# Nr: 213 Predicted label: moderate
# Nr: 214 Predicted label: severe
# Nr: 215 Predicted label: severe
# Nr: 216 Predicted label: severe
# Nr: 217 Predicted label: moderate
# Nr: 218 Predicted label: severe
# Nr: 219 Predicted label: moderate
# Nr: 220 Predicted label: severe
# Nr: 221 Predicted label: moderate
# Nr: 222 Predicted label: severe
# Nr: 223 Predicted label: severe
# Nr: 224 Predicted label: severe
# Nr: 225 Predicted label: moderate
# Nr: 226 Predicted label: severe
# Nr: 227 Predicted label: severe
# Nr: 228 Predicted label: severe
# Nr: 229 Predicted label: severe
# Nr: 230 Predicted label: moderate
# Nr: 231 Predicted label: severe
# Nr: 232 Predicted label: moderate
# Nr: 233 Predicted label: severe
# Nr: 234 Predicted label: not depression
# Nr: 235 Predicted label: severe
# Nr: 236 Predicted label: moderate
# Nr: 237 Predicted label: moderate
# Nr: 238 Predicted label: moderate
# Nr: 239 Predicted label: not depression
# Nr: 240 Predicted label: severe
# Nr: 241 Predicted label: severe
# Nr: 242 Predicted label: severe
# Nr: 243 Predicted label: severe
# Nr: 244 Predicted label: severe
# Nr: 245 Predicted label: severe
# Nr: 246 Predicted label: severe
# Nr: 247 Predicted label: not depression
# Nr: 248 Predicted label: moderate
# Nr: 249 Predicted label: severe
# Nr: 250 Predicted label: severe
# Nr: 251 Predicted label: severe
# Nr: 252 Predicted label: not depression
# Nr: 253 Predicted label: severe
# Nr: 254 Predicted label: moderate
# Nr: 255 Predicted label: moderate
# Nr: 256 Predicted label: severe
# Nr: 257 Predicted label: not depression
# Nr: 258 Predicted label: severe
# Nr: 259 Predicted label: severe
# Nr: 260 Predicted label: severe
# Nr: 261 Predicted label: moderate
# Nr: 262 Predicted label: severe
# Nr: 263 Predicted label: severe
# Nr: 264 Predicted label: severe
# Nr: 265 Predicted label: moderate
# Nr: 266 Predicted label: not depression
# Nr: 267 Predicted label: severe
# Nr: 268 Predicted label: severe
# Nr: 269 Predicted label: not depression
# Nr: 270 Predicted label: severe
# Nr: 271 Predicted label: severe
# Nr: 272 Predicted label: not depression
# Nr: 273 Predicted label: severe
# Nr: 274 Predicted label: moderate
# Nr: 275 Predicted label: severe
# Nr: 276 Predicted label: severe
# Nr: 277 Predicted label: severe
# Nr: 278 Predicted label: severe
# Nr: 279 Predicted label: severe
# Nr: 280, próba 1/30 – przekroczono timeout 60s, przerywam
# Nr: 280 Predicted label: severe
# Nr: 281 Predicted label: severe
# Nr: 282 Predicted label: severe
# Nr: 283 Predicted label: severe
# Nr: 284 Predicted label: not depression
# Nr: 285 Predicted label: severe
# Nr: 286 Predicted label: severe
# Nr: 287 Predicted label: severe
# Nr: 288 Predicted label: moderate
# Nr: 289 Predicted label: severe
# Nr: 290 Predicted label: severe
# Nr: 291 Predicted label: moderate
# Nr: 292 Predicted label: severe
# Nr: 293 Predicted label: not depression
# Nr: 294 Predicted label: not depression
# Nr: 295 Predicted label: severe
# Nr: 296 Predicted label: not depression
# Nr: 297 Predicted label: severe
# Nr: 298 Predicted label: severe
# Nr: 299 Predicted label: severe
# Nr: 300 Predicted label: moderate
# Nr: 301 Predicted label: not depression
# Nr: 302 Predicted label: severe
# Nr: 303 Predicted label: severe
# Nr: 304 Predicted label: severe
# Nr: 305 Predicted label: severe
# Nr: 306 Predicted label: severe
# Nr: 307 Predicted label: not depression
# Nr: 308 Predicted label: severe
# Nr: 309 Predicted label: not depression
# Nr: 310 Predicted label: severe
# Nr: 311 Predicted label: severe
# Nr: 312 Predicted label: not depression
# Nr: 313 Predicted label: not depression
# Nr: 314 Predicted label: severe
# Nr: 315 Predicted label: severe
# Nr: 316 Predicted label: severe
# Nr: 317 Predicted label: severe
# Nr: 318 Predicted label: not depression
# Nr: 319 Predicted label: severe
# Nr: 320 Predicted label: not depression
# Nr: 321 Predicted label: severe
# Nr: 322 Predicted label: not depression
# Nr: 323 Predicted label: severe
# Nr: 324 Predicted label: severe
# Nr: 325 Predicted label: severe
# Nr: 326 Predicted label: severe
# Nr: 327 Predicted label: severe
# Nr: 328 Predicted label: severe
# Nr: 329 Predicted label: severe
# Nr: 330 Predicted label: severe
# Nr: 331 Predicted label: moderate
# Nr: 332 Predicted label: not depression
# Nr: 333 Predicted label: severe
# Nr: 334 Predicted label: moderate
# Nr: 335 Predicted label: severe
# Nr: 336 Predicted label: severe
# Nr: 337 Predicted label: severe
# Nr: 338 Predicted label: severe
# Nr: 339 Predicted label: severe
# Nr: 340 Predicted label: moderate
# Nr: 341 Predicted label: severe
# Nr: 342 Predicted label: not depression
# Nr: 343 Predicted label: moderate
# Nr: 344 Predicted label: severe
# Nr: 345 Predicted label: severe
# Nr: 346 Predicted label: moderate
# Nr: 347 Predicted label: severe
# Nr: 348 Predicted label: severe
# Nr: 349 Predicted label: moderate
# Nr: 350 Predicted label: severe
# Nr: 351 Predicted label: not depression
# Nr: 352 Predicted label: severe
# Nr: 353 Predicted label: severe
# Nr: 354 Predicted label: severe
# Nr: 355 Predicted label: severe
# Nr: 356 Predicted label: severe
# Nr: 357 Predicted label: moderate
# Nr: 358 Predicted label: severe
# Nr: 359 Predicted label: severe
# Nr: 360 Predicted label: not depression
# Nr: 361 Predicted label: moderate
# Nr: 362 Predicted label: severe
# Nr: 363 Predicted label: severe
# Nr: 364 Predicted label: moderate
# Nr: 365 Predicted label: severe
# Nr: 366 Predicted label: severe
# Nr: 367 Predicted label: moderate
# Nr: 368 Predicted label: severe
# Nr: 369 Predicted label: moderate
# Nr: 370 Predicted label: not depression
# Nr: 371 Predicted label: severe
# Nr: 372 Predicted label: severe
# Nr: 373 Predicted label: severe
# Nr: 374 Predicted label: severe
# Nr: 375 Predicted label: severe
# Nr: 376 Predicted label: moderate
# Nr: 377 Predicted label: severe
# Nr: 378 Predicted label: moderate
# Nr: 379 Predicted label: severe
# Nr: 380 Predicted label: not depression
# Nr: 381 Predicted label: severe
# Nr: 382 Predicted label: severe
# Nr: 383 Predicted label: severe
# Nr: 384 Predicted label: severe
# Nr: 385 Predicted label: severe
# Nr: 386 Predicted label: not depression
# Nr: 387 Predicted label: severe
# Nr: 388 Predicted label: not depression
# Nr: 389 Predicted label: severe
# Nr: 390 Predicted label: not depression
# Nr: 391 Predicted label: severe
# Nr: 392 Predicted label: severe
# Nr: 393 Predicted label: not depression
# Nr: 394 Predicted label: moderate
# Nr: 395 Predicted label: moderate
# Nr: 396 Predicted label: severe
# Nr: 397 Predicted label: moderate
# Nr: 398 Predicted label: severe
# Nr: 399 Predicted label: severe
# Nr: 400 Predicted label: severe
# Nr: 401 Predicted label: severe
# Nr: 402 Predicted label: not depression
# Nr: 403 Predicted label: severe
# Nr: 404 Predicted label: severe
# Nr: 405 Predicted label: moderate
# Nr: 406 Predicted label: severe
# Nr: 407 Predicted label: severe
# Nr: 408 Predicted label: severe
# Nr: 409 Predicted label: severe
# Nr: 410 Predicted label: severe
# Nr: 411 Predicted label: severe
# Nr: 412 Predicted label: not depression
# Nr: 413 Predicted label: severe
# Nr: 414 Predicted label: severe
# Nr: 415 Predicted label: severe
# Nr: 416 Predicted label: severe
# Nr: 417 Predicted label: severe
# Nr: 418 Predicted label: severe
# Nr: 419 Predicted label: severe
# Nr: 420 Predicted label: not depression
# Nr: 421 Predicted label: not depression
# Nr: 422 Predicted label: severe
# Nr: 423 Predicted label: severe
# Nr: 424 Predicted label: severe
# Nr: 425 Predicted label: not depression
# Nr: 426 Predicted label: severe
# Nr: 427 Predicted label: moderate
# Nr: 428 Predicted label: severe
# Nr: 429 Predicted label: severe
# Nr: 430 Predicted label: not depression
# Nr: 431 Predicted label: severe
# Nr: 432 Predicted label: moderate
# Nr: 433 Predicted label: moderate
# Nr: 434 Predicted label: severe
# Nr: 435 Predicted label: severe
# Nr: 436 Predicted label: severe
# Nr: 437 Predicted label: severe
# Nr: 438 Predicted label: severe
# Nr: 439 Predicted label: severe
# Nr: 440 Predicted label: severe
# Nr: 441 Predicted label: severe
# Nr: 442 Predicted label: not depression
# Nr: 443 Predicted label: not depression
# Nr: 444 Predicted label: severe
# Nr: 445 Predicted label: severe
# Nr: 446 Predicted label: severe
# Nr: 447 Predicted label: not depression
# Nr: 448 Predicted label: severe
# Nr: 449 Predicted label: moderate
# Nr: 450 Predicted label: not depression
# Nr: 451 Predicted label: severe
# Nr: 452 Predicted label: not depression
# Nr: 453 Predicted label: severe
# Nr: 454 Predicted label: severe
# Nr: 455 Predicted label: moderate
# Nr: 456 Predicted label: moderate
# Nr: 457 Predicted label: severe
# Nr: 458 Predicted label: severe
# Nr: 459 Predicted label: not depression
# Nr: 460 Predicted label: not depression
# Nr: 461 Predicted label: severe
# Nr: 462 Predicted label: severe
# Nr: 463 Predicted label: severe
# Nr: 464 Predicted label: severe
# Nr: 465 Predicted label: severe
# Nr: 466 Predicted label: moderate
# Nr: 467 Predicted label: severe
# Nr: 468 Predicted label: moderate
# Nr: 469 Predicted label: not depression
# Nr: 470 Predicted label: moderate
# Nr: 471 Predicted label: severe
# Nr: 472 Predicted label: severe
# Nr: 473 Predicted label: severe
# Nr: 474 Predicted label: severe
# Nr: 475 Predicted label: severe
# Nr: 476 Predicted label: severe
# Nr: 477 Predicted label: severe
# Nr: 478 Predicted label: severe
# Nr: 479 Predicted label: severe
# Nr: 480 Predicted label: severe
# Nr: 481 Predicted label: severe
# Nr: 482 Predicted label: severe
# Nr: 483 Predicted label: severe
# Nr: 484 Predicted label: severe
# Nr: 485 Predicted label: severe
# Nr: 486 Predicted label: severe
# Nr: 487 Predicted label: severe
# Nr: 488 Predicted label: severe
# Nr: 489 Predicted label: severe
# Nr: 490 Predicted label: severe
# Nr: 491 Predicted label: not depression
# Nr: 492 Predicted label: not depression
# Nr: 493 Predicted label: severe
# Nr: 494 Predicted label: severe
# Nr: 495 Predicted label: severe
# Nr: 496 Predicted label: not depression
# Nr: 497 Predicted label: moderate
# Nr: 498 Predicted label: moderate
# Nr: 499 Predicted label: severe
# Nr: 500 Predicted label: severe
# Nr: 501 Predicted label: severe
# Nr: 502 Predicted label: severe
# Nr: 503 Predicted label: severe
# Nr: 504 Predicted label: severe
# Nr: 505 Predicted label: severe
# Nr: 506 Predicted label: severe
# Nr: 507 Predicted label: severe
# Nr: 508 Predicted label: not depression
# Nr: 509 Predicted label: severe
# Nr: 510 Predicted label: severe
# Nr: 511 Predicted label: severe
# Nr: 512 Predicted label: severe
# Nr: 513 Predicted label: severe
# Nr: 514 Predicted label: severe
# Nr: 515 Predicted label: severe
# Nr: 516 Predicted label: severe
# Nr: 517 Predicted label: severe
# Nr: 518 Predicted label: severe
# Nr: 519 Predicted label: severe
# Nr: 520 Predicted label: moderate
# Nr: 521 Predicted label: severe
# Nr: 522 Predicted label: not depression
# Nr: 523 Predicted label: not depression
# Nr: 524 Predicted label: severe
# Nr: 525 Predicted label: moderate
# Nr: 526 Predicted label: severe
# Nr: 527 Predicted label: severe
# Nr: 528 Predicted label: severe
# Nr: 529 Predicted label: severe
# Nr: 530 Predicted label: severe
# Nr: 531 Predicted label: severe
# Nr: 532 Predicted label: severe
# Nr: 533 Predicted label: moderate
# Nr: 534 Predicted label: severe
# Nr: 535 Predicted label: severe
# Nr: 536 Predicted label: severe
# Nr: 537 Predicted label: moderate
# Nr: 538 Predicted label: severe
# Nr: 539 Predicted label: moderate
# Nr: 540 Predicted label: severe
# Nr: 541 Predicted label: severe
# Nr: 542 Predicted label: severe
# Nr: 543 Predicted label: severe
# Nr: 544 Predicted label: severe
# Nr: 545 Predicted label: severe
# Nr: 546 Predicted label: severe
# Nr: 547 Predicted label: moderate
# Nr: 548 Predicted label: severe
# Nr: 549 Predicted label: severe
# Nr: 550 Predicted label: not depression
# Nr: 551 Predicted label: severe
# Nr: 552 Predicted label: severe
# Nr: 553 Predicted label: severe
# Nr: 554 Predicted label: severe
# Nr: 555 Predicted label: moderate
# Nr: 556 Predicted label: severe
# Nr: 557 Predicted label: severe
# Nr: 558 Predicted label: moderate
# Nr: 559 Predicted label: not depression
# Nr: 560 Predicted label: severe
# Nr: 561 Predicted label: severe
# Nr: 562 Predicted label: severe
# Nr: 563 Predicted label: severe
# Nr: 564 Predicted label: severe
# Nr: 565 Predicted label: moderate
# Nr: 566 Predicted label: not depression
# Nr: 567 Predicted label: not depression
# Nr: 568 Predicted label: not depression
# Nr: 569 Predicted label: not depression
# Nr: 570 Predicted label: not depression
# Nr: 571 Predicted label: not depression
# Nr: 572 Predicted label: severe
# Nr: 573 Predicted label: severe
# Nr: 574 Predicted label: severe
# Nr: 575 Predicted label: severe
# Nr: 576 Predicted label: severe
# Nr: 577 Predicted label: moderate
# Nr: 578 Predicted label: moderate
# Nr: 579 Predicted label: severe
# Nr: 580 Predicted label: severe
# Nr: 581 Predicted label: severe
# Nr: 582 Predicted label: severe
# Nr: 583 Predicted label: severe
# Nr: 584 Predicted label: severe
# Nr: 585 Predicted label: moderate
# Nr: 586 Predicted label: severe
# Nr: 587 Predicted label: severe
# Nr: 588 Predicted label: severe
# Nr: 589 Predicted label: not depression
# Nr: 590 Predicted label: severe
# Nr: 591 Predicted label: severe
# Nr: 592 Predicted label: severe
# Nr: 593 Predicted label: severe
# Nr: 594 Predicted label: moderate
# Nr: 595 Predicted label: not depression
# Nr: 596 Predicted label: not depression
# Nr: 597 Predicted label: severe
# Nr: 598 Predicted label: severe
# Nr: 599 Predicted label: severe
# Nr: 600 Predicted label: severe
# Nr: 601 Predicted label: moderate
# Nr: 602 Predicted label: severe
# Nr: 603 Predicted label: moderate
# Nr: 604 Predicted label: severe
# Nr: 605 Predicted label: severe
# Nr: 606 Predicted label: severe
# Nr: 607 Predicted label: severe
# Nr: 608 Predicted label: not depression
# Nr: 609 Predicted label: severe
# Nr: 610 Predicted label: moderate
# Nr: 611 Predicted label: moderate
# Nr: 612 Predicted label: not depression
# Nr: 613 Predicted label: not depression
# Nr: 614 Predicted label: severe
# Nr: 615 Predicted label: severe
# Nr: 616 Predicted label: moderate
# Nr: 617 Predicted label: not depression
# Nr: 618 Predicted label: severe
# Nr: 619 Predicted label: severe
# Nr: 620 Predicted label: not depression
# Nr: 621 Predicted label: moderate
# Nr: 622 Predicted label: severe
# Nr: 623 Predicted label: not depression
# Nr: 624 Predicted label: severe
# Nr: 625 Predicted label: severe
# Nr: 626 Predicted label: severe
# Nr: 627 Predicted label: severe
# Nr: 628 Predicted label: severe
# Nr: 629 Predicted label: severe
# Nr: 630 Predicted label: severe
# Nr: 631 Predicted label: not depression
# Nr: 632 Predicted label: severe
# Nr: 633 Predicted label: severe
# Nr: 634 Predicted label: severe
# Nr: 635 Predicted label: not depression
# Nr: 636 Predicted label: severe
# Nr: 637 Predicted label: not depression
# Nr: 638 Predicted label: not depression
# Nr: 639 Predicted label: not depression
# Nr: 640 Predicted label: not depression
# Nr: 641 Predicted label: moderate
# Nr: 642 Predicted label: severe
# Nr: 643 Predicted label: severe
# Nr: 644 Predicted label: not depression
# Nr: 645 Predicted label: severe
# Nr: 646 Predicted label: severe
# Nr: 647 Predicted label: moderate
# Nr: 648 Predicted label: not depression
# Nr: 649 Predicted label: not depression
# Nr: 650 Predicted label: severe
# Nr: 651 Predicted label: severe
# Nr: 652 Predicted label: severe
# Nr: 653 Predicted label: severe
# Nr: 654 Predicted label: severe
# Nr: 655 Predicted label: severe
# Nr: 656 Predicted label: severe
# Nr: 657 Predicted label: moderate
# Nr: 658 Predicted label: severe
# Nr: 659 Predicted label: severe
# Nr: 660 Predicted label: severe
# Nr: 661 Predicted label: severe
# Nr: 662 Predicted label: not depression
# Nr: 663 Predicted label: not depression
# Nr: 664 Predicted label: moderate
# Nr: 665 Predicted label: severe
# Nr: 666 Predicted label: severe
# Nr: 667 Predicted label: moderate
# Nr: 668 Predicted label: severe
# Nr: 669 Predicted label: moderate
# Nr: 670 Predicted label: not depression
# Nr: 671 Predicted label: not depression
# Nr: 672 Predicted label: severe
# Nr: 673 Predicted label: severe
# Nr: 674 Predicted label: severe
# Nr: 675 Predicted label: severe
# Nr: 676 Predicted label: severe
# Nr: 677 Predicted label: severe
# Nr: 678 Predicted label: severe
# Nr: 679 Predicted label: severe
# Nr: 680 Predicted label: severe
# Nr: 681 Predicted label: severe
# Nr: 682 Predicted label: moderate
# Nr: 683 Predicted label: severe
# Nr: 684 Predicted label: severe
# Nr: 685 Predicted label: severe
# Nr: 686 Predicted label: severe
# Nr: 687 Predicted label: severe
# Nr: 688 Predicted label: severe
# Nr: 689 Predicted label: not depression
# Nr: 690 Predicted label: severe
# Nr: 691 Predicted label: severe
# Nr: 692 Predicted label: severe
# Nr: 693 Predicted label: moderate
# Nr: 694 Predicted label: severe
# Nr: 695 Predicted label: severe
# Nr: 696 Predicted label: severe
# Nr: 697 Predicted label: severe
# Nr: 698 Predicted label: severe
# Nr: 699 Predicted label: severe
# Nr: 700 Predicted label: moderate
# Nr: 701 Predicted label: severe
# Nr: 702 Predicted label: severe
# Nr: 703 Predicted label: not depression
# Nr: 704 Predicted label: severe
# Nr: 705 Predicted label: moderate
# Nr: 706 Predicted label: severe
# Nr: 707 Predicted label: severe
# Nr: 708 Predicted label: severe
# Nr: 709 Predicted label: not depression
# Nr: 710 Predicted label: moderate
# Nr: 711 Predicted label: severe
# Nr: 712 Predicted label: severe
# Nr: 713 Predicted label: severe
# Nr: 714 Predicted label: moderate
# Nr: 715 Predicted label: severe
# Nr: 716 Predicted label: severe
# Nr: 717 Predicted label: moderate
# Nr: 718 Predicted label: not depression
# Nr: 719 Predicted label: not depression
# Nr: 720 Predicted label: not depression
# Nr: 721 Predicted label: severe
# Nr: 722 Predicted label: severe
# Nr: 723 Predicted label: moderate
# Nr: 724 Predicted label: severe
# Nr: 725 Predicted label: severe
# Nr: 726 Predicted label: severe
# Nr: 727 Predicted label: severe
# Nr: 728 Predicted label: severe
# Nr: 729 Predicted label: severe
# Nr: 730 Predicted label: severe
# Nr: 731 Predicted label: not depression
# Nr: 732 Predicted label: severe
# Nr: 733 Predicted label: moderate
# Nr: 734 Predicted label: severe
# Nr: 735 Predicted label: moderate
# Nr: 736 Predicted label: severe
# Nr: 737 Predicted label: severe
# Nr: 738 Predicted label: not depression
# Nr: 739 Predicted label: severe
# Nr: 740 Predicted label: severe
# Nr: 741 Predicted label: severe
# Nr: 742 Predicted label: severe
# Nr: 743 Predicted label: not depression
# Nr: 744 Predicted label: severe
# Nr: 745 Predicted label: not depression
# Nr: 746 Predicted label: moderate
# Nr: 747 Predicted label: severe
# Nr: 748 Predicted label: severe
# Nr: 749 Predicted label: severe
# Nr: 750 Predicted label: severe
# Nr: 751 Predicted label: severe
# Nr: 752 Predicted label: severe
# Nr: 753 Predicted label: severe
# Nr: 754 Predicted label: severe
# Nr: 755 Predicted label: not depression
# Nr: 756 Predicted label: not depression
# Nr: 757 Predicted label: moderate
# Nr: 758 Predicted label: severe
# Nr: 759 Predicted label: moderate
# Nr: 760 Predicted label: severe
# Nr: 761 Predicted label: severe
# Nr: 762 Predicted label: severe
# Nr: 763 Predicted label: severe
# Nr: 764 Predicted label: severe
# Nr: 765 Predicted label: severe
# Nr: 766 Predicted label: moderate
# Nr: 767 Predicted label: severe
# Nr: 768 Predicted label: moderate
# Nr: 769 Predicted label: severe
# Nr: 770 Predicted label: severe
# Nr: 771 Predicted label: severe
# Nr: 772 Predicted label: severe
# Nr: 773 Predicted label: severe
# Nr: 774 Predicted label: moderate
# Nr: 775 Predicted label: severe
# Nr: 776 Predicted label: severe
# Nr: 777 Predicted label: severe
# Nr: 778 Predicted label: severe
# Nr: 779 Predicted label: not depression
# Nr: 780 Predicted label: moderate
# Nr: 781 Predicted label: severe
# Nr: 782 Predicted label: severe
# Nr: 783 Predicted label: severe
# Nr: 784 Predicted label: severe
# Nr: 785 Predicted label: severe
# Nr: 786 Predicted label: severe
# Nr: 787 Predicted label: moderate
# Nr: 788 Predicted label: severe
# Nr: 789 Predicted label: moderate
# Nr: 790 Predicted label: not depression
# Nr: 791 Predicted label: severe
# Nr: 792 Predicted label: severe
# Nr: 793 Predicted label: severe
# Nr: 794 Predicted label: severe
# Nr: 795 Predicted label: severe
# Nr: 796 Predicted label: severe
# Nr: 797 Predicted label: severe
# Nr: 798 Predicted label: severe
# Nr: 799 Predicted label: severe
# Nr: 800 Predicted label: severe
# Nr: 801 Predicted label: severe
# Nr: 802 Predicted label: severe
# Nr: 803 Predicted label: moderate
# Nr: 804 Predicted label: severe
# Nr: 805 Predicted label: severe
# Nr: 806 Predicted label: severe
# Nr: 807 Predicted label: severe
# Nr: 808 Predicted label: not depression
# Nr: 809 Predicted label: severe
# Nr: 810 Predicted label: severe
# Nr: 811 Predicted label: severe
# Nr: 812 Predicted label: moderate
# Nr: 813 Predicted label: not depression
# Nr: 814 Predicted label: moderate
# Nr: 815 Predicted label: moderate
# Nr: 816 Predicted label: severe
# Nr: 817 Predicted label: not depression
# Nr: 818 Predicted label: not depression
# Nr: 819 Predicted label: not depression
# Nr: 820 Predicted label: severe
# Nr: 821 Predicted label: severe
# Nr: 822 Predicted label: not depression
# Nr: 823 Predicted label: severe
# Nr: 824 Predicted label: moderate
# Nr: 825 Predicted label: not depression
# Nr: 826 Predicted label: severe
# Nr: 827 Predicted label: moderate
# Nr: 828 Predicted label: severe
# Nr: 829 Predicted label: severe
# Nr: 830 Predicted label: not depression
# Nr: 831 Predicted label: severe
# Nr: 832 Predicted label: not depression
# Nr: 833 Predicted label: severe
# Nr: 834 Predicted label: severe
# Nr: 835 Predicted label: severe
# Nr: 836 Predicted label: moderate
# Nr: 837 Predicted label: severe
# Nr: 838 Predicted label: severe
# Nr: 839 Predicted label: severe
# Nr: 840 Predicted label: severe
# Nr: 841 Predicted label: moderate
# Nr: 842 Predicted label: moderate
# Nr: 843 Predicted label: not depression
# Nr: 844 Predicted label: severe
# Nr: 845 Predicted label: severe
# Nr: 846 Predicted label: severe
# Nr: 847 Predicted label: moderate
# Nr: 848 Predicted label: severe
# Nr: 849 Predicted label: not depression
# Nr: 850 Predicted label: severe
# Nr: 851 Predicted label: severe
# Nr: 852 Predicted label: severe
# Nr: 853 Predicted label: moderate
# Nr: 854 Predicted label: severe
# Nr: 855 Predicted label: not depression
# Nr: 856 Predicted label: moderate
# Nr: 857 Predicted label: severe
# Nr: 858 Predicted label: severe
# Nr: 859 Predicted label: severe
# Nr: 860 Predicted label: moderate
# Nr: 861 Predicted label: severe
# Nr: 862 Predicted label: severe
# Nr: 863 Predicted label: moderate
# Nr: 864 Predicted label: moderate
# Nr: 865 Predicted label: moderate
# Nr: 866 Predicted label: severe
# Nr: 867 Predicted label: severe
# Nr: 868 Predicted label: moderate
# Nr: 869 Predicted label: severe
# Nr: 870 Predicted label: severe
# Nr: 871 Predicted label: severe
# Nr: 872 Predicted label: not depression
# Nr: 873 Predicted label: severe
# Nr: 874 Predicted label: severe
# Nr: 875 Predicted label: severe
# Nr: 876 Predicted label: severe
# Nr: 877 Predicted label: moderate
# Nr: 878 Predicted label: severe
# Nr: 879 Predicted label: severe
# Nr: 880 Predicted label: severe
# Nr: 881 Predicted label: severe
# Nr: 882 Predicted label: not depression
# Nr: 883 Predicted label: moderate
# Nr: 884 Predicted label: severe
# Nr: 885 Predicted label: not depression
# Nr: 886 Predicted label: severe
# Nr: 887 Predicted label: moderate
# Nr: 888 Predicted label: severe
# Nr: 889 Predicted label: severe
# Nr: 890 Predicted label: severe
# Nr: 891 Predicted label: moderate
# Nr: 892 Predicted label: severe
# Nr: 893 Predicted label: moderate
# Nr: 894 Predicted label: severe
# Nr: 895 Predicted label: severe
# Nr: 896 Predicted label: moderate
# Nr: 897 Predicted label: moderate
# Nr: 898 Predicted label: severe
# Nr: 899 Predicted label: not depression
# Nr: 900 Predicted label: not depression
# Nr: 901 Predicted label: moderate
# Nr: 902 Predicted label: severe
# Nr: 903 Predicted label: not depression
# Nr: 904 Predicted label: severe
# Nr: 905 Predicted label: not depression
# Nr: 906 Predicted label: severe
# Nr: 907 Predicted label: severe
# Nr: 908 Predicted label: severe
# Nr: 909 Predicted label: severe
# Nr: 910 Predicted label: not depression
# Nr: 911 Predicted label: moderate
# Nr: 912 Predicted label: moderate
# Nr: 913 Predicted label: severe
# Nr: 914 Predicted label: not depression
# Nr: 915 Predicted label: severe
# Nr: 916 Predicted label: severe
# Nr: 917 Predicted label: moderate
# Nr: 918 Predicted label: severe
# Nr: 919 Predicted label: severe
# Nr: 920 Predicted label: severe
# Nr: 921 Predicted label: moderate
# Nr: 922 Predicted label: not depression
# Nr: 923 Predicted label: not depression
# Nr: 924 Predicted label: not depression
# Nr: 925 Predicted label: severe
# Nr: 926 Predicted label: severe
# Nr: 927 Predicted label: severe
# Nr: 928 Predicted label: severe
# Nr: 929 Predicted label: moderate
# Nr: 930 Predicted label: not depression
# Nr: 931 Predicted label: severe
# Nr: 932 Predicted label: severe
# Nr: 933 Predicted label: severe
# Nr: 934 Predicted label: severe
# Nr: 935 Predicted label: severe
# Nr: 936 Predicted label: severe
# Nr: 937 Predicted label: moderate
# Nr: 938 Predicted label: severe
# Nr: 939 Predicted label: severe
# Nr: 940 Predicted label: severe
# Nr: 941 Predicted label: not depression
# Nr: 942 Predicted label: severe
# Nr: 943 Predicted label: severe
# Nr: 944 Predicted label: not depression
# Nr: 945 Predicted label: severe
# Nr: 946 Predicted label: severe
# Nr: 947 Predicted label: severe
# Nr: 948 Predicted label: severe
# Nr: 949 Predicted label: severe
# Nr: 950 Predicted label: severe
# Nr: 951 Predicted label: severe
# Nr: 952 Predicted label: moderate
# Nr: 953 Predicted label: severe
# Nr: 954 Predicted label: severe
# Nr: 955 Predicted label: severe
# Nr: 956 Predicted label: severe
# Nr: 957 Predicted label: not depression
# Nr: 958 Predicted label: severe
# Nr: 959 Predicted label: severe
# Nr: 960 Predicted label: severe
# Nr: 961 Predicted label: severe
# Nr: 962 Predicted label: severe
# Nr: 963 Predicted label: severe
# Nr: 964 Predicted label: moderate
# Nr: 965 Predicted label: moderate
# Nr: 966 Predicted label: severe
# Nr: 967 Predicted label: severe
# Nr: 968 Predicted label: moderate
# Nr: 969 Predicted label: severe
# Nr: 970 Predicted label: not depression
# Nr: 971 Predicted label: moderate
# Nr: 972 Predicted label: severe
# Nr: 973 Predicted label: severe
# Nr: 974 Predicted label: moderate
# Nr: 975 Predicted label: not depression
# Nr: 976 Predicted label: not depression
# Nr: 977 Predicted label: severe
# Nr: 978 Predicted label: moderate
# Nr: 979 Predicted label: severe
# Nr: 980 Predicted label: not depression
# Nr: 981 Predicted label: severe
# Nr: 982 Predicted label: not depression
# Nr: 983 Predicted label: severe
# Nr: 984 Predicted label: not depression
# Nr: 985 Predicted label: not depression
# Nr: 986 Predicted label: severe
# Nr: 987 Predicted label: severe
# Nr: 988 Predicted label: severe
# Nr: 989 Predicted label: severe
# Nr: 990 Predicted label: severe
# Nr: 991 Predicted label: severe
# Nr: 992 Predicted label: severe
# Nr: 993 Predicted label: severe
# Nr: 994 Predicted label: severe
# Nr: 995 Predicted label: severe
# Nr: 996 Predicted label: severe
# Nr: 997 Predicted label: severe
# Nr: 998 Predicted label: severe
# Nr: 999 Predicted label: severe
# Nr: 1000 Predicted label: severe
# Nr: 1001 Predicted label: severe
# Nr: 1002 Predicted label: moderate
# Nr: 1003 Predicted label: severe
# Nr: 1004 Predicted label: not depression
# Nr: 1005 Predicted label: severe
# Nr: 1006 Predicted label: severe
# Nr: 1007 Predicted label: not depression
# Nr: 1008 Predicted label: severe
# Nr: 1009 Predicted label: severe
# Nr: 1010 Predicted label: not depression
# Nr: 1011 Predicted label: severe
# Nr: 1012 Predicted label: severe
# Nr: 1013 Predicted label: severe
# Nr: 1014 Predicted label: severe
# Nr: 1015 Predicted label: severe
# Nr: 1016 Predicted label: not depression
# Nr: 1017 Predicted label: severe
# Nr: 1018 Predicted label: severe
# Nr: 1019 Predicted label: severe
# Nr: 1020 Predicted label: severe
# Nr: 1021 Predicted label: severe
# Nr: 1022 Predicted label: Severe
# Nr: 1023 Predicted label: severe
# Nr: 1024 Predicted label: severe
# Nr: 1025 Predicted label: severe
# Nr: 1026 Predicted label: severe
# Nr: 1027 Predicted label: severe
# Nr: 1028 Predicted label: severe
# Nr: 1029 Predicted label: severe
# Nr: 1030 Predicted label: severe
# Nr: 1031 Predicted label: moderate
# Nr: 1032 Predicted label: severe
# Nr: 1033 Predicted label: severe
# Nr: 1034 Predicted label: moderate
# Nr: 1035 Predicted label: severe
# Nr: 1036 Predicted label: severe
# Nr: 1037 Predicted label: severe
# Nr: 1038 Predicted label: severe
# Nr: 1039 Predicted label: severe
# Nr: 1040 Predicted label: severe
# Nr: 1041 Predicted label: not depression
# Nr: 1042 Predicted label: severe
# Nr: 1043 Predicted label: severe
# Nr: 1044 Predicted label: severe
# Nr: 1045 Predicted label: moderate
# Nr: 1046 Predicted label: severe
# Nr: 1047 Predicted label: severe
# Nr: 1048 Predicted label: severe
# Nr: 1049 Predicted label: severe
# Nr: 1050 Predicted label: severe
# Nr: 1051 Predicted label: severe
# Nr: 1052 Predicted label: severe
# Nr: 1053 Predicted label: severe
# Nr: 1054 Predicted label: not depression
# Nr: 1055 Predicted label: severe
# Nr: 1056 Predicted label: severe
# Nr: 1057 Predicted label: severe
# Nr: 1058 Predicted label: severe
# Nr: 1059 Predicted label: severe
# Nr: 1060 Predicted label: severe
# Nr: 1061 Predicted label: severe
# Nr: 1062 Predicted label: severe
# Nr: 1063 Predicted label: severe
# Nr: 1064 Predicted label: severe
# Nr: 1065 Predicted label: severe
# Nr: 1066 Predicted label: severe

# %%
annotator.save_results(output_path=output_path)
# Out:
# Results saved successfully to ./results/no_samples_temp0/llama3/social_media_llama3_no_samples_temp0_exp1.csv

# %%
df = pd.read_csv(output_path)
df
# Out:
#                                                    text          output  \
# 0     2020 is in less than 2 hours and I don't feel ...          severe
# 1     Depression or laziness? : For quite a long tim...          severe
# 2     $1,000,000 or no more depression? : Which woul...  not depression
# 3     Negative Nancy : I’ve recently started dating ...        moderate
# 4     I’m sure I’ll die alone at this point : I know...          severe
# ...                                                 ...             ...
# 1062  Two labels, two boxes : A month or so ago, in ...          severe
# 1063  I almost cried while my family was wishing eac...          severe
# 1064  Am I the only one who hates new years? : Now t...          severe
# 1065  I just want to smile. : I can’t smile. It does...          severe
# 1066  new year new chance : I wanted to go on a new ...          severe
#
#                                                logprobs  \
# 0     {'content': [{'token': 'se', 'logprob': -0.065...
# 1     {'content': [{'token': 'se', 'logprob': -0.515...
# 2     {'content': [{'token': 'not', 'logprob': -0.13...
# 3     {'content': [{'token': 'mod', 'logprob': -0.19...
# 4     {'content': [{'token': 'se', 'logprob': -0.035...
# ...                                                 ...
# 1062  {'content': [{'token': 'se', 'logprob': -0.032...
# 1063  {'content': [{'token': 'se', 'logprob': -0.073...
# 1064  {'content': [{'token': 'se', 'logprob': -0.044...
# 1065  {'content': [{'token': 'se', 'logprob': -0.416...
# 1066  {'content': [{'token': 'se', 'logprob': -0.034...
#
#                                            top_logprobs  original_label
# 0     [{'token': 'se', 'logprob': -0.065786696970462...        moderate
# 1     [{'token': 'se', 'logprob': -0.515187621116638...        moderate
# 2     [{'token': 'not', 'logprob': -0.13507702946662...  not depression
# 3     [{'token': 'mod', 'logprob': -0.19033730030059...        moderate
# 4     [{'token': 'se', 'logprob': -0.035857222974300...        moderate
# ...                                                 ...             ...
# 1062  [{'token': 'se', 'logprob': -0.032176330685615...        moderate
# 1063  [{'token': 'se', 'logprob': -0.073738232254982...        moderate
# 1064  [{'token': 'se', 'logprob': -0.044703345745801...        moderate
# 1065  [{'token': 'se', 'logprob': -0.416693091392517...          severe
# 1066  [{'token': 'se', 'logprob': -0.034104421734809...        moderate
#
# [1067 rows x 5 columns]

# %%
import ast

def format_top_logprobs(top_logprobs_str):
    try:
        top_logprobs = ast.literal_eval(top_logprobs_str)
        return '\n'.join([f"{d['token']:<15} → logprob: {d['logprob']}" for d in top_logprobs])
    except Exception as e:
        return f"Error: {e}"

df['top_logprobs_formatted'] = df['top_logprobs'].apply(format_top_logprobs)

# %%
df['top_logprobs_formatted']
# Out:
# 0       se              → logprob: -0.0657866969704628...
# 1       se              → logprob: -0.5151876211166382...
# 2       not             → logprob: -0.1350770294666290...
# 3       mod             → logprob: -0.1903373003005981...
# 4       se              → logprob: -0.0358572229743003...
#                               ...
# 1062    se              → logprob: -0.0321763306856155...
# 1063    se              → logprob: -0.073738232254982\...
# 1064    se              → logprob: -0.0447033457458019...
# 1065    se              → logprob: -0.4166930913925171...
# 1066    se              → logprob: -0.0341044217348098...
# Name: top_logprobs_formatted, Length: 1067, dtype: object

# %%
import pprint

pprint.pprint(df['top_logprobs_formatted'].iloc[0])
# Out:
# ('se              → logprob: -0.0657866969704628\n'
#  'Se              → logprob: -2.815786600112915\n'
#  '-               → logprob: -6.190786838531494\n'
#  '-se             → logprob: -6.440786838531494\n'
#  'mod             → logprob: -9.440786361694336\n'
#  'not             → logprob: -10.440786361694336\n'
#  '-Se             → logprob: -10.940786361694336\n'
#  'Moder           → logprob: -11.315786361694336\n'
#  'Not             → logprob: -12.065786361694336\n'
#  'severity        → logprob: -12.565786361694336\n'
#  '_se             → logprob: -12.940786361694336\n'
#  '\tse             → logprob: -13.065786361694336\n'
#  'serious         → logprob: -13.315786361694336\n'
#  'Category        → logprob: -13.565786361694336\n'
#  'SE              → logprob: -13.815786361694336\n'
#  'Severity        → logprob: -13.940786361694336\n'
#  'I               → logprob: -14.065786361694336\n'
#  '.se             → logprob: -14.315786361694336\n'
#  'server          → logprob: -14.315786361694336\n'
#  '(se             → logprob: -14.815786361694336')
