# %%
import os 
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd # type: ignore

# %%
from utils import get_dataset, get_model_by_tag, get_prompt_template
from LLMAnnotator import LLMAnnotator

# %%
os.environ['OPENAI_API_KEY_CLARIN']=os.getenv("OPENAI_API_KEY_CLARIN")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

token = os.getenv("OPENAI_API_KEY_CLARIN")

# %%
model_tag = 'gpt4omini'  
dataset_tag = 'sst5'
prompt = 'no_samples_numbers'
temp = 0
number_of_experimet = 1

# %%
model = get_model_by_tag(model_tag, token, temp)  
dataset_for_annotation = get_dataset(dataset_tag=dataset_tag)
prompt_txt = get_prompt_template(dataset_tag, prompt)
examples_for_prompt = pd.DataFrame()

output_path = f'./results/{prompt}_temp{temp}/{model_tag}/{dataset_tag}_{model_tag}_{prompt}_temp{temp}_exp{number_of_experimet}.csv'
os.makedirs(f'./results/{prompt}_temp{temp}/{model_tag}', exist_ok=True)

# %%
dataset_for_annotation.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
print(model, dataset_for_annotation, prompt_txt, examples_for_prompt, output_path)
# Out:
# GPT4oMiniLLM
# Params: {}                                                   text  label
# 0    Though the opera itself takes place mostly ind...      3
# 1    If you can read the subtitles ( the opera is s...      4
# 2    ( `` Safe Conduct '' ) is a long movie at 163 ...      4
# 3    The beauty of Alexander Payne 's ode to the Ev...      4
# 4    The fourth in a series that I 'll bet most par...      3
# ..                                                 ...    ...
# 995           In other words , it 's badder than bad .      1
# 996  The direction occasionally rises to the level ...      2
# 997                       The movie is ingenious fun .      5
# 998  The cast comes through even when the movie doe...      3
# 999  Most of the movie is so deadly dull that watch...      1
#
# [1000 rows x 2 columns] Task: Read the following text and determine the most appropriate rating based on its content.
#
# Ratings:
# 1 = very poor
# 2 = poor
# 3 = average
# 4 = good
# 5 = excellent
#
# Text for you: "{text}"
#
# Return only one number (1, 2, 3, 4, or 5). Use only ASCII digits. No Unicode variants. Do not add any spaces, newlines, or other characters. Avoid explanations. Empty DataFrame
# Columns: []
# Index: [] ./results/no_samples_numbers_temp0/gpt4omini/sst5_gpt4omini_no_samples_numbers_temp0_exp1.csv

# %%
text_col = "text"
label_col = "label"
output_col = "output"

# %%
annotator = LLMAnnotator(
    model=model,
    dataset=dataset_for_annotation,
    examples_for_prompt=examples_for_prompt,
    prompt_template=prompt_txt,
    column_text=text_col,
    column_label=label_col,
    column_output=output_col
)

# %%
df = annotator.get_results()
# Out:
# Nr: 0 Predicted label: 2
# Nr: 1 Predicted label: 4
# Nr: 2 Predicted label: 4
# Nr: 3 Predicted label: 4
# Nr: 4 Predicted label: 2
# Nr: 5 Predicted label: 3
# Nr: 6 Predicted label: 4
# Nr: 7 Predicted label: 2
# Nr: 8 Predicted label: 5
# Nr: 9 Predicted label: 2
# Nr: 10 Predicted label: 5
# Nr: 11 Predicted label: 1
# Nr: 12 Predicted label: 3
# Nr: 13 Predicted label: 4
# Nr: 14 Predicted label: 5
# Nr: 15 Predicted label: 4
# Nr: 16 Predicted label: 2
# Nr: 17 Predicted label: 4
# Nr: 18 Predicted label: 2
# Nr: 19 Predicted label: 2
# Nr: 20 Predicted label: 1
# Nr: 21 Predicted label: 3
# Nr: 22 Predicted label: 2
# Nr: 23 Predicted label: 2
# Nr: 24 Predicted label: 2
# Nr: 25 Predicted label: 2
# Nr: 26 Predicted label: 2
# Nr: 27 Predicted label: 5
# Nr: 28 Predicted label: 4
# Nr: 29 Predicted label: 5
# Nr: 30 Predicted label: 2
# Nr: 31 Predicted label: 2
# Nr: 32 Predicted label: 4
# Nr: 33 Predicted label: 3
# Nr: 34 Predicted label: 3
# Nr: 35 Predicted label: 2
# Nr: 36 Predicted label: 4
# Nr: 37 Predicted label: 2
# Nr: 38 Predicted label: 5
# Nr: 39 Predicted label: 1
# Nr: 40 Predicted label: 2
# Nr: 41 Predicted label: 2
# Nr: 42 Predicted label: 2
# Nr: 43 Predicted label: 3
# Nr: 44 Predicted label: 4
# Nr: 45 Predicted label: 1
# Nr: 46 Predicted label: 3
# Nr: 47 Predicted label: 3
# Nr: 48 Predicted label: 2
# Nr: 49 Predicted label: 4
# Nr: 50 Predicted label: 2
# Nr: 51 Predicted label: 5
# Nr: 52 Predicted label: 2
# Nr: 53 Predicted label: 3
# Nr: 54 Predicted label: 2
# Nr: 55 Predicted label: 1
# Nr: 56 Predicted label: 4
# Nr: 57 Predicted label: 1
# Nr: 58 Predicted label: 2
# Nr: 59 Predicted label: 5
# Nr: 60 Predicted label: 2
# Nr: 61 Predicted label: 1
# Nr: 62 Predicted label: 3
# Nr: 63 Predicted label: 2
# Nr: 64 Predicted label: 5
# Nr: 65 Predicted label: 4
# Nr: 66 Predicted label: 4
# Nr: 67 Predicted label: 4
# Nr: 68 Predicted label: 2
# Nr: 69 Predicted label: 4
# Nr: 70 Predicted label: 2
# Nr: 71 Predicted label: 3
# Nr: 72 Predicted label: 3
# Nr: 73 Predicted label: 3
# Nr: 74 Predicted label: 2
# Nr: 75 Predicted label: 2
# Nr: 76 Predicted label: 4
# Nr: 77 Predicted label: 2
# Nr: 78 Predicted label: 4
# Nr: 79 Predicted label: 2
# Nr: 80 Predicted label: 4
# Nr: 81 Predicted label: 2
# Nr: 82 Predicted label: 2
# Nr: 83 Predicted label: 1
# Nr: 84 Predicted label: 2
# Nr: 85 Predicted label: 2
# Nr: 86 Predicted label: 4
# Nr: 87 Predicted label: 4
# Nr: 88 Predicted label: 2
# Nr: 89 Predicted label: 3
# Nr: 90 Predicted label: 2
# Nr: 91 Predicted label: 2
# Nr: 92 Predicted label: 3
# Nr: 93 Predicted label: 2
# Nr: 94 Predicted label: 4
# Nr: 95 Predicted label: 2
# Nr: 96 Predicted label: 4
# Nr: 97 Predicted label: 1
# Nr: 98 Predicted label: 2
# Nr: 99 Predicted label: 5
# Nr: 100 Predicted label: 4
# Nr: 101 Predicted label: 3
# Nr: 102 Predicted label: 5
# Nr: 103 Predicted label: 2
# Nr: 104 Predicted label: 4
# Nr: 105 Predicted label: 3
# Nr: 106 Predicted label: 4
# Nr: 107 Predicted label: 4
# Nr: 108 Predicted label: 2
# Nr: 109 Predicted label: 5
# Nr: 110 Predicted label: 4
# Nr: 111 Predicted label: 5
# Nr: 112 Predicted label: 4
# Nr: 113 Predicted label: 4
# Nr: 114 Predicted label: 2
# Nr: 115 Predicted label: 2
# Nr: 116 Predicted label: 1
# Nr: 117 Predicted label: 5
# Nr: 118 Predicted label: 2
# Nr: 119 Predicted label: 2
# Nr: 120 Predicted label: 4
# Nr: 121 Predicted label: 4
# Nr: 122 Predicted label: 4
# Nr: 123 Predicted label: 2
# Nr: 124 Predicted label: 1
# Nr: 125 Predicted label: 3
# Nr: 126 Predicted label: 3
# Nr: 127 Predicted label: 2
# Nr: 128 Predicted label: 5
# Nr: 129 Predicted label: 5
# Nr: 130 Predicted label: 3
# Nr: 131 Predicted label: 4
# Nr: 132 Predicted label: 2
# Nr: 133 Predicted label: 5
# Nr: 134 Predicted label: 2
# Nr: 135 Predicted label: 2
# Nr: 136 Predicted label: 1
# Nr: 137 Predicted label: 3
# Nr: 138 Predicted label: 1
# Nr: 139 Predicted label: 2
# Nr: 140 Predicted label: 2
# Nr: 141 Predicted label: 3
# Nr: 142 Predicted label: 4
# Nr: 143 Predicted label: 2
# Nr: 144 Predicted label: 5
# Nr: 145 Predicted label: 5
# Nr: 146 Predicted label: 4
# Nr: 147 Predicted label: 2
# Nr: 148 Predicted label: 5
# Nr: 149 Predicted label: 1
# Nr: 150 Predicted label: 4
# Nr: 151 Predicted label: 2
# Nr: 152 Predicted label: 4
# Nr: 153 Predicted label: 4
# Nr: 154 Predicted label: 5
# Nr: 155 Predicted label: 4
# Nr: 156 Predicted label: 3
# Nr: 157 Predicted label: 4
# Nr: 158 Predicted label: 1
# Nr: 159 Predicted label: 5
# Nr: 160 Predicted label: 2
# Nr: 161 Predicted label: 4
# Nr: 162 Predicted label: 4
# Nr: 163 Predicted label: 5
# Nr: 164 Predicted label: 4
# Nr: 165 Predicted label: 3
# Nr: 166 Predicted label: 2
# Nr: 167 Predicted label: 4
# Nr: 168 Predicted label: 2
# Nr: 169 Predicted label: 2
# Nr: 170 Predicted label: 3
# Nr: 171 Predicted label: 4
# Nr: 172 Predicted label: 2
# Nr: 173 Predicted label: 4
# Nr: 174 Predicted label: 3
# Nr: 175 Predicted label: 3
# Nr: 176 Predicted label: 2
# Nr: 177 Predicted label: 2
# Nr: 178 Predicted label: 4
# Nr: 179 Predicted label: 4
# Nr: 180 Predicted label: 2
# Nr: 181 Predicted label: 5
# Nr: 182 Predicted label: 2
# Nr: 183 Predicted label: 3
# Nr: 184 Predicted label: 4
# Nr: 185 Predicted label: 2
# Nr: 186 Predicted label: 1
# Nr: 187 Predicted label: 2
# Nr: 188 Predicted label: 5
# Nr: 189 Predicted label: 4
# Nr: 190 Predicted label: 4
# Nr: 191 Predicted label: 4
# Nr: 192 Predicted label: 4
# Nr: 193 Predicted label: 1
# Nr: 194 Predicted label: 3
# Nr: 195 Predicted label: 2
# Nr: 196 Predicted label: 2
# Nr: 197 Predicted label: 2
# Nr: 198 Predicted label: 4
# Nr: 199 Predicted label: 1
# Nr: 200 Predicted label: 2
# Nr: 201 Predicted label: 4
# Nr: 202 Predicted label: 4
# Nr: 203 Predicted label: 4
# Nr: 204 Predicted label: 5
# Nr: 205 Predicted label: 2
# Nr: 206 Predicted label: 3
# Nr: 207 Predicted label: 4
# Nr: 208 Predicted label: 2
# Nr: 209 Predicted label: 5
# Nr: 210 Predicted label: 3
# Nr: 211 Predicted label: 2
# Nr: 212 Predicted label: 4
# Nr: 213 Predicted label: 5
# Nr: 214 Predicted label: 3
# Nr: 215 Predicted label: 2
# Nr: 216 Predicted label: 4
# Nr: 217 Predicted label: 2
# Nr: 218 Predicted label: 5
# Nr: 219 Predicted label: 4
# Nr: 220 Predicted label: 2
# Nr: 221 Predicted label: 4
# Nr: 222 Predicted label: 5
# Nr: 223 Predicted label: 2
# Nr: 224 Predicted label: 4
# Nr: 225 Predicted label: 2
# Nr: 226 Predicted label: 3
# Nr: 227 Predicted label: 2
# Nr: 228 Predicted label: 5
# Nr: 229 Predicted label: 3
# Nr: 230 Predicted label: 2
# Nr: 231 Predicted label: 4
# Nr: 232 Predicted label: 4
# Nr: 233 Predicted label: 3
# Nr: 234 Predicted label: 1
# Nr: 235 Predicted label: 2
# Nr: 236 Predicted label: 1
# Nr: 237 Predicted label: 5
# Nr: 238 Predicted label: 1
# Nr: 239 Predicted label: 3
# Nr: 240 Predicted label: 1
# Nr: 241 Predicted label: 2
# Nr: 242 Predicted label: 3
# Nr: 243 Predicted label: 5
# Nr: 244 Predicted label: 1
# Nr: 245 Predicted label: 2
# Nr: 246 Predicted label: 3
# Nr: 247 Predicted label: 2
# Nr: 248 Predicted label: 2
# Nr: 249 Predicted label: 2
# Nr: 250 Predicted label: 2
# Nr: 251 Predicted label: 5
# Nr: 252 Predicted label: 4
# Nr: 253 Predicted label: 4
# Nr: 254 Predicted label: 2
# Nr: 255 Predicted label: 3
# Nr: 256 Predicted label: 3
# Nr: 257 Predicted label: 4
# Nr: 258 Predicted label: 4
# Nr: 259 Predicted label: 1
# Nr: 260 Predicted label: 4
# Nr: 261 Predicted label: 3
# Nr: 262 Predicted label: 2
# Nr: 263 Predicted label: 2
# Nr: 264 Predicted label: 1
# Nr: 265 Predicted label: 4
# Nr: 266 Predicted label: 4
# Nr: 267 Predicted label: 3
# Nr: 268 Predicted label: 4
# Nr: 269 Predicted label: 3
# Nr: 270 Predicted label: 2
# Nr: 271 Predicted label: 2
# Nr: 272 Predicted label: 4
# Nr: 273 Predicted label: 3
# Nr: 274 Predicted label: 3
# Nr: 275 Predicted label: 2
# Nr: 276 Predicted label: 1
# Nr: 277 Predicted label: 4
# Nr: 278 Predicted label: 1
# Nr: 279 Predicted label: 4
# Nr: 280 Predicted label: 3
# Nr: 281 Predicted label: 4
# Nr: 282 Predicted label: 2
# Nr: 283 Predicted label: 2
# Nr: 284 Predicted label: 2
# Nr: 285 Predicted label: 5
# Nr: 286 Predicted label: 2
# Nr: 287 Predicted label: 4
# Nr: 288 Predicted label: 2
# Nr: 289 Predicted label: 4
# Nr: 290 Predicted label: 5
# Nr: 291 Predicted label: 4
# Nr: 292 Predicted label: 2
# Nr: 293 Predicted label: 3
# Nr: 294 Predicted label: 3
# Nr: 295 Predicted label: 2
# Nr: 296 Predicted label: 4
# Nr: 297 Predicted label: 3
# Nr: 298 Predicted label: 2
# Nr: 299 Predicted label: 2
# Nr: 300 Predicted label: 2
# Nr: 301 Predicted label: 3
# Nr: 302 Predicted label: 3
# Nr: 303 Predicted label: 2
# Nr: 304 Predicted label: 4
# Nr: 305 Predicted label: 5
# Nr: 306 Predicted label: 3
# Nr: 307 Predicted label: 2
# Nr: 308 Predicted label: 4
# Nr: 309 Predicted label: 4
# Nr: 310 Predicted label: 3
# Nr: 311 Predicted label: 3
# Nr: 312 Predicted label: 3
# Nr: 313 Predicted label: 4
# Nr: 314 Predicted label: 4
# Nr: 315 Predicted label: 3
# Nr: 316 Predicted label: 3
# Nr: 317 Predicted label: 2
# Nr: 318 Predicted label: 3
# Nr: 319 Predicted label: 2
# Nr: 320 Predicted label: 1
# Nr: 321 Predicted label: 2
# Nr: 322 Predicted label: 2
# Nr: 323 Predicted label: 4
# Nr: 324 Predicted label: 5
# Nr: 325 Predicted label: 3
# Nr: 326 Predicted label: 2
# Nr: 327 Predicted label: 3
# Nr: 328 Predicted label: 5
# Nr: 329 Predicted label: 1
# Nr: 330 Predicted label: 4
# Nr: 331 Predicted label: 2
# Nr: 332 Predicted label: 5
# Nr: 333 Predicted label: 3
# Nr: 334 Predicted label: 1
# Nr: 335 Predicted label: 2
# Nr: 336 Predicted label: 4
# Nr: 337 Predicted label: 3
# Nr: 338 Predicted label: 5
# Nr: 339 Predicted label: 3
# Nr: 340 Predicted label: 3
# Nr: 341 Predicted label: 4
# Nr: 342 Predicted label: 1
# Nr: 343 Predicted label: 1
# Nr: 344 Predicted label: 2
# Nr: 345 Predicted label: 3
# Nr: 346 Predicted label: 4
# Nr: 347 Predicted label: 4
# Nr: 348 Predicted label: 2
# Nr: 349 Predicted label: 5
# Nr: 350 Predicted label: 1
# Nr: 351 Predicted label: 2
# Nr: 352 Predicted label: 4
# Nr: 353 Predicted label: 2
# Nr: 354 Predicted label: 2
# Nr: 355 Predicted label: 2
# Nr: 356 Predicted label: 3
# Nr: 357 Predicted label: 3
# Nr: 358 Predicted label: 2
# Nr: 359 Predicted label: 1
# Nr: 360 Predicted label: 1
# Nr: 361 Predicted label: 4
# Nr: 362 Predicted label: 2
# Nr: 363 Predicted label: 4
# Nr: 364 Predicted label: 1
# Nr: 365 Predicted label: 2
# Nr: 366 Predicted label: 4
# Nr: 367 Predicted label: 1
# Nr: 368 Predicted label: 2
# Nr: 369 Predicted label: 4
# Nr: 370 Predicted label: 1
# Nr: 371 Predicted label: 4
# Nr: 372 Predicted label: 1
# Nr: 373 Predicted label: 2
# Nr: 374 Predicted label: 2
# Nr: 375 Predicted label: 4
# Nr: 376 Predicted label: 2
# Nr: 377 Predicted label: 2
# Nr: 378 Predicted label: 5
# Nr: 379 Predicted label: 5
# Nr: 380 Predicted label: 2
# Nr: 381 Predicted label: 1
# Nr: 382 Predicted label: 3
# Nr: 383 Predicted label: 2
# Nr: 384 Predicted label: 2
# Nr: 385 Predicted label: 5
# Nr: 386 Predicted label: 4
# Nr: 387 Predicted label: 1
# Nr: 388 Predicted label: 4
# Nr: 389 Predicted label: 4
# Nr: 390 Predicted label: 1
# Nr: 391 Predicted label: 2
# Nr: 392 Predicted label: 3
# Nr: 393 Predicted label: 1
# Nr: 394 Predicted label: 3
# Nr: 395 Predicted label: 2
# Nr: 396 Predicted label: 1
# Nr: 397 Predicted label: 2
# Nr: 398 Predicted label: 2
# Nr: 399 Predicted label: 4
# Nr: 400 Predicted label: 2
# Nr: 401 Predicted label: 3
# Nr: 402 Predicted label: 2
# Nr: 403 Predicted label: 3
# Nr: 404 Predicted label: 4
# Nr: 405 Predicted label: 5
# Nr: 406 Predicted label: 4
# Nr: 407 Predicted label: 2
# Nr: 408 Predicted label: 2
# Nr: 409 Predicted label: 3
# Nr: 410 Predicted label: 3
# Nr: 411 Predicted label: 4
# Nr: 412 Predicted label: 3
# Nr: 413 Predicted label: 3
# Nr: 414 Predicted label: 5
# Nr: 415 Predicted label: 4
# Nr: 416 Predicted label: 4
# Nr: 417 Predicted label: 4
# Nr: 418 Predicted label: 3
# Nr: 419 Predicted label: 4
# Nr: 420 Predicted label: 2
# Nr: 421 Predicted label: 5
# Nr: 422 Predicted label: 4
# Nr: 423 Predicted label: 3
# Nr: 424 Predicted label: 4
# Nr: 425 Predicted label: 4
# Nr: 426 Predicted label: 2
# Nr: 427 Predicted label: 2
# Nr: 428 Predicted label: 4
# Nr: 429 Predicted label: 2
# Nr: 430 Predicted label: 2
# Nr: 431 Predicted label: 2
# Nr: 432 Predicted label: 1
# Nr: 433 Predicted label: 3
# Nr: 434 Predicted label: 2
# Nr: 435 Predicted label: 2
# Nr: 436 Predicted label: 1
# Nr: 437 Predicted label: 1
# Nr: 438 Predicted label: 4
# Nr: 439 Predicted label: 2
# Nr: 440 Predicted label: 2
# Nr: 441 Predicted label: 3
# Nr: 442 Predicted label: 4
# Nr: 443 Predicted label: 3
# Nr: 444 Predicted label: 3
# Nr: 445 Predicted label: 2
# Nr: 446 Predicted label: 5
# Nr: 447 Predicted label: 1
# Nr: 448 Predicted label: 4
# Nr: 449 Predicted label: 3
# Nr: 450 Predicted label: 5
# Nr: 451 Predicted label: 4
# Nr: 452 Predicted label: 3
# Nr: 453 Predicted label: 2
# Nr: 454 Predicted label: 1
# Nr: 455 Predicted label: 4
# Nr: 456 Predicted label: 4
# Nr: 457 Predicted label: 4
# Nr: 458 Predicted label: 3
# Nr: 459 Predicted label: 3
# Nr: 460 Predicted label: 1
# Nr: 461 Predicted label: 1
# Nr: 462 Predicted label: 2
# Nr: 463 Predicted label: 4
# Nr: 464 Predicted label: 1
# Nr: 465 Predicted label: 1
# Nr: 466 Predicted label: 1
# Nr: 467 Predicted label: 3
# Nr: 468 Predicted label: 2
# Nr: 469 Predicted label: 3
# Nr: 470 Predicted label: 3
# Nr: 471 Predicted label: 1
# Nr: 472 Predicted label: 5
# Nr: 473 Predicted label: 2
# Nr: 474 Predicted label: 1
# Nr: 475 Predicted label: 5
# Nr: 476 Predicted label: 5
# Nr: 477 Predicted label: 4
# Nr: 478 Predicted label: 3
# Nr: 479 Predicted label: 3
# Nr: 480 Predicted label: 4
# Nr: 481 Predicted label: 2
# Nr: 482 Predicted label: 1
# Nr: 483 Predicted label: 3
# Nr: 484 Predicted label: 3
# Nr: 485 Predicted label: 1
# Nr: 486 Predicted label: 2
# Nr: 487 Predicted label: 1
# Nr: 488 Predicted label: 2
# Nr: 489 Predicted label: 3
# Nr: 490 Predicted label: 5
# Nr: 491 Predicted label: 3
# Nr: 492 Predicted label: 4
# Nr: 493 Predicted label: 3
# Nr: 494 Predicted label: 3
# Nr: 495 Predicted label: 1
# Nr: 496 Predicted label: 3
# Nr: 497 Predicted label: 5
# Nr: 498 Predicted label: 5
# Nr: 499 Predicted label: 5
# Nr: 500 Predicted label: 4
# Nr: 501 Predicted label: 2
# Nr: 502 Predicted label: 3
# Nr: 503 Predicted label: 4
# Nr: 504 Predicted label: 3
# Nr: 505 Predicted label: 5
# Nr: 506 Predicted label: 4
# Nr: 507 Predicted label: 1
# Nr: 508 Predicted label: 4
# Nr: 509 Predicted label: 4
# Nr: 510 Predicted label: 3
# Nr: 511 Predicted label: 1
# Nr: 512 Predicted label: 3
# Nr: 513 Predicted label: 1
# Nr: 514 Predicted label: 1
# Nr: 515 Predicted label: 4
# Nr: 516 Predicted label: 3
# Nr: 517 Predicted label: 2
# Nr: 518 Predicted label: 4
# Nr: 519 Predicted label: 1
# Nr: 520 Predicted label: 2
# Nr: 521 Predicted label: 4
# Nr: 522 Predicted label: 4
# Nr: 523 Predicted label: 2
# Nr: 524 Predicted label: 3
# Nr: 525 Predicted label: 2
# Nr: 526 Predicted label: 3
# Nr: 527 Predicted label: 1
# Nr: 528 Predicted label: 4
# Nr: 529 Predicted label: 1
# Nr: 530 Predicted label: 3
# Nr: 531 Predicted label: 2
# Nr: 532 Predicted label: 4
# Nr: 533 Predicted label: 5
# Nr: 534 Predicted label: 5
# Nr: 535 Predicted label: 4
# Nr: 536 Predicted label: 1
# Nr: 537 Predicted label: 1
# Nr: 538 Predicted label: 3
# Nr: 539 Predicted label: 3
# Nr: 540 Predicted label: 1
# Nr: 541 Predicted label: 3
# Nr: 542 Predicted label: 2
# Nr: 543 Predicted label: 3
# Nr: 544 Predicted label: 2
# Nr: 545 Predicted label: 5
# Nr: 546 Predicted label: 3
# Nr: 547 Predicted label: 4
# Nr: 548 Predicted label: 4
# Nr: 549 Predicted label: 2
# Nr: 550 Predicted label: 2
# Nr: 551 Predicted label: 3
# Nr: 552 Predicted label: 5
# Nr: 553 Predicted label: 1
# Nr: 554 Predicted label: 5
# Nr: 555 Predicted label: 4
# Nr: 556 Predicted label: 2
# Nr: 557 Predicted label: 1
# Nr: 558 Predicted label: 1
# Nr: 559 Predicted label: 2
# Nr: 560 Predicted label: 2
# Nr: 561 Predicted label: 5
# Nr: 562 Predicted label: 4
# Nr: 563 Predicted label: 4
# Nr: 564 Predicted label: 2
# Nr: 565 Predicted label: 2
# Nr: 566 Predicted label: 5
# Nr: 567 Predicted label: 2
# Nr: 568 Predicted label: 2
# Nr: 569 Predicted label: 5
# Nr: 570 Predicted label: 2
# Nr: 571 Predicted label: 1
# Nr: 572 Predicted label: 4
# Nr: 573 Predicted label: 1
# Nr: 574 Predicted label: 3
# Nr: 575 Predicted label: 5
# Nr: 576 Predicted label: 1
# Nr: 577 Predicted label: 4
# Nr: 578 Predicted label: 3
# Nr: 579 Predicted label: 3
# Nr: 580 Predicted label: 1
# Nr: 581 Predicted label: 1
# Nr: 582 Predicted label: 5
# Nr: 583 Predicted label: 4
# Nr: 584 Predicted label: 4
# Nr: 585 Predicted label: 3
# Nr: 586 Predicted label: 3
# Nr: 587 Predicted label: 4
# Nr: 588 Predicted label: 1
# Nr: 589 Predicted label: 1
# Nr: 590 Predicted label: 3
# Nr: 591 Predicted label: 4
# Nr: 592 Predicted label: 4
# Nr: 593 Predicted label: 3
# Nr: 594 Predicted label: 5
# Nr: 595 Predicted label: 2
# Nr: 596 Predicted label: 1
# Nr: 597 Predicted label: 4
# Nr: 598 Predicted label: 2
# Nr: 599 Predicted label: 3
# Nr: 600 Predicted label: 2
# Nr: 601 Predicted label: 1
# Nr: 602 Predicted label: 2
# Nr: 603 Predicted label: 2
# Nr: 604 Predicted label: 4
# Nr: 605 Predicted label: 4
# Nr: 606 Predicted label: 2
# Nr: 607 Predicted label: 2
# Nr: 608 Predicted label: 4
# Nr: 609 Predicted label: 4
# Nr: 610 Predicted label: 2
# Nr: 611 Predicted label: 2
# Nr: 612 Predicted label: 4
# Nr: 613 Predicted label: 4
# Nr: 614 Predicted label: 5
# Nr: 615 Predicted label: 4
# Nr: 616 Predicted label: 4
# Nr: 617 Predicted label: 1
# Nr: 618 Predicted label: 4
# Nr: 619 Predicted label: 2
# Nr: 620 Predicted label: 4
# Nr: 621 Predicted label: 2
# Nr: 622 Predicted label: 5
# Nr: 623 Predicted label: 1
# Nr: 624 Predicted label: 1
# Nr: 625 Predicted label: 3
# Nr: 626 Predicted label: 1
# Nr: 627 Predicted label: 5
# Nr: 628 Predicted label: 4
# Nr: 629 Predicted label: 4
# Nr: 630 Predicted label: 4
# Nr: 631 Predicted label: 3
# Nr: 632 Predicted label: 1
# Nr: 633 Predicted label: 4
# Nr: 634 Predicted label: 4
# Nr: 635 Predicted label: 2
# Nr: 636 Predicted label: 2
# Nr: 637 Predicted label: 5
# Nr: 638 Predicted label: 2
# Nr: 639 Predicted label: 4
# Nr: 640 Predicted label: 1
# Nr: 641 Predicted label: 2
# Nr: 642 Predicted label: 1
# Nr: 643 Predicted label: 5
# Nr: 644 Predicted label: 2
# Nr: 645 Predicted label: 2
# Nr: 646 Predicted label: 5
# Nr: 647 Predicted label: 5
# Nr: 648 Predicted label: 4
# Nr: 649 Predicted label: 4
# Nr: 650 Predicted label: 1
# Nr: 651 Predicted label: 4
# Nr: 652 Predicted label: 5
# Nr: 653 Predicted label: 3
# Nr: 654 Predicted label: 5
# Nr: 655 Predicted label: 5
# Nr: 656 Predicted label: 1
# Nr: 657 Predicted label: 5
# Nr: 658 Predicted label: 2
# Nr: 659 Predicted label: 2
# Nr: 660 Predicted label: 2
# Nr: 661 Predicted label: 4
# Nr: 662 Predicted label: 5
# Nr: 663 Predicted label: 3
# Nr: 664 Predicted label: 1
# Nr: 665 Predicted label: 2
# Nr: 666 Predicted label: 4
# Nr: 667 Predicted label: 2
# Nr: 668 Predicted label: 3
# Nr: 669 Predicted label: 4
# Nr: 670 Predicted label: 4
# Nr: 671 Predicted label: 3
# Nr: 672 Predicted label: 5
# Nr: 673 Predicted label: 4
# Nr: 674 Predicted label: 2
# Nr: 675 Predicted label: 2
# Nr: 676 Predicted label: 1
# Nr: 677 Predicted label: 3
# Nr: 678 Predicted label: 5
# Nr: 679 Predicted label: 1
# Nr: 680 Predicted label: 4
# Nr: 681 Predicted label: 5
# Nr: 682 Predicted label: 5
# Nr: 683 Predicted label: 1
# Nr: 684 Predicted label: 4
# Nr: 685 Predicted label: 1
# Nr: 686 Predicted label: 3
# Nr: 687 Predicted label: 4
# Nr: 688 Predicted label: 3
# Nr: 689 Predicted label: 2
# Nr: 690 Predicted label: 4
# Nr: 691 Predicted label: 2
# Nr: 692 Predicted label: 4
# Nr: 693 Predicted label: 4
# Nr: 694 Predicted label: 5
# Nr: 695 Predicted label: 2
# Nr: 696 Predicted label: 4
# Nr: 697 Predicted label: 2
# Nr: 698 Predicted label: 3
# Nr: 699 Predicted label: 1
# Nr: 700 Predicted label: 5
# Nr: 701 Predicted label: 4
# Nr: 702 Predicted label: 4
# Nr: 703 Predicted label: 2
# Nr: 704 Predicted label: 5
# Nr: 705 Predicted label: 3
# Nr: 706 Predicted label: 1
# Nr: 707 Predicted label: 2
# Nr: 708 Predicted label: 4
# Nr: 709 Predicted label: 4
# Nr: 710 Predicted label: 4
# Nr: 711 Predicted label: 3
# Nr: 712 Predicted label: 1
# Nr: 713 Predicted label: 2
# Nr: 714 Predicted label: 2
# Nr: 715 Predicted label: 1
# Nr: 716 Predicted label: 1
# Nr: 717 Predicted label: 5
# Nr: 718 Predicted label: 3
# Nr: 719 Predicted label: 2
# Nr: 720 Predicted label: 2
# Nr: 721 Predicted label: 2
# Nr: 722 Predicted label: 4
# Nr: 723 Predicted label: 2
# Nr: 724 Predicted label: 1
# Nr: 725 Predicted label: 4
# Nr: 726 Predicted label: 2
# Nr: 727 Predicted label: 2
# Nr: 728 Predicted label: 4
# Nr: 729 Predicted label: 2
# Nr: 730 Predicted label: 1
# Nr: 731 Predicted label: 4
# Nr: 732 Predicted label: 5
# Nr: 733 Predicted label: 4
# Nr: 734 Predicted label: 4
# Nr: 735 Predicted label: 4
# Nr: 736 Predicted label: 4
# Nr: 737 Predicted label: 1
# Nr: 738 Predicted label: 4
# Nr: 739 Predicted label: 1
# Nr: 740 Predicted label: 4
# Nr: 741 Predicted label: 5
# Nr: 742 Predicted label: 5
# Nr: 743 Predicted label: 5
# Nr: 744 Predicted label: 2
# Nr: 745 Predicted label: 4
# Nr: 746 Predicted label: 4
# Nr: 747 Predicted label: 3
# Nr: 748 Predicted label: 4
# Nr: 749 Predicted label: 5
# Nr: 750 Predicted label: 4
# Nr: 751 Predicted label: 5
# Nr: 752 Predicted label: 4
# Nr: 753 Predicted label: 1
# Nr: 754 Predicted label: 4
# Nr: 755 Predicted label: 4
# Nr: 756 Predicted label: 2
# Nr: 757 Predicted label: 5
# Nr: 758 Predicted label: 2
# Nr: 759 Predicted label: 2
# Nr: 760 Predicted label: 1
# Nr: 761 Predicted label: 4
# Nr: 762 Predicted label: 1
# Nr: 763 Predicted label: 5
# Nr: 764 Predicted label: 4
# Nr: 765 Predicted label: 4
# Nr: 766 Predicted label: 1
# Nr: 767 Predicted label: 4
# Nr: 768 Predicted label: 4
# Nr: 769 Predicted label: 2
# Nr: 770 Predicted label: 4
# Nr: 771 Predicted label: 5
# Nr: 772 Predicted label: 2
# Nr: 773 Predicted label: 2
# Nr: 774 Predicted label: 2
# Nr: 775 Predicted label: 4
# Nr: 776 Predicted label: 4
# Nr: 777 Predicted label: 2
# Nr: 778 Predicted label: 3
# Nr: 779 Predicted label: 4
# Nr: 780 Predicted label: 4
# Nr: 781 Predicted label: 4
# Nr: 782 Predicted label: 1
# Nr: 783 Predicted label: 4
# Nr: 784 Predicted label: 3
# Nr: 785 Predicted label: 2
# Nr: 786 Predicted label: 5
# Nr: 787 Predicted label: 5
# Nr: 788 Predicted label: 3
# Nr: 789 Predicted label: 2
# Nr: 790 Predicted label: 4
# Nr: 791 Predicted label: 4
# Nr: 792 Predicted label: 4
# Nr: 793 Predicted label: 4
# Nr: 794 Predicted label: 4
# Nr: 795 Predicted label: 3
# Nr: 796 Predicted label: 4
# Nr: 797 Predicted label: 5
# Nr: 798 Predicted label: 4
# Nr: 799 Predicted label: 5
# Nr: 800 Predicted label: 2
# Nr: 801 Predicted label: 4
# Nr: 802 Predicted label: 3
# Nr: 803 Predicted label: 3
# Nr: 804 Predicted label: 1
# Nr: 805 Predicted label: 2
# Nr: 806 Predicted label: 4
# Nr: 807 Predicted label: 2
# Nr: 808 Predicted label: 2
# Nr: 809 Predicted label: 1
# Nr: 810 Predicted label: 2
# Nr: 811 Predicted label: 2
# Nr: 812 Predicted label: 4
# Nr: 813 Predicted label: 5
# Nr: 814 Predicted label: 4
# Nr: 815 Predicted label: 4
# Nr: 816 Predicted label: 5
# Nr: 817 Predicted label: 4
# Nr: 818 Predicted label: 2
# Nr: 819 Predicted label: 5
# Nr: 820 Predicted label: 3
# Nr: 821 Predicted label: 3
# Nr: 822 Predicted label: 3
# Nr: 823 Predicted label: 3
# Nr: 824 Predicted label: 3
# Nr: 825 Predicted label: 2
# Nr: 826 Predicted label: 5
# Nr: 827 Predicted label: 1
# Nr: 828 Predicted label: 2
# Nr: 829 Predicted label: 5
# Nr: 830 Predicted label: 1
# Nr: 831 Predicted label: 4
# Nr: 832 Predicted label: 4
# Nr: 833 Predicted label: 2
# Nr: 834 Predicted label: 1
# Nr: 835 Predicted label: 4
# Nr: 836 Predicted label: 4
# Nr: 837 Predicted label: 3
# Nr: 838 Predicted label: 1
# Nr: 839 Predicted label: 4
# Nr: 840 Predicted label: 3
# Nr: 841 Predicted label: 4
# Nr: 842 Predicted label: 4
# Nr: 843 Predicted label: 1
# Nr: 844 Predicted label: 5
# Nr: 845 Predicted label: 4
# Nr: 846 Predicted label: 2
# Nr: 847 Predicted label: 4
# Nr: 848 Predicted label: 1
# Nr: 849 Predicted label: 2
# Nr: 850 Predicted label: 2
# Nr: 851 Predicted label: 4
# Nr: 852 Predicted label: 5
# Nr: 853 Predicted label: 2
# Nr: 854 Predicted label: 2
# Nr: 855 Predicted label: 2
# Nr: 856 Predicted label: 4
# Nr: 857 Predicted label: 1
# Nr: 858 Predicted label: 4
# Nr: 859 Predicted label: 4
# Nr: 860 Predicted label: 3
# Nr: 861 Predicted label: 3
# Nr: 862 Predicted label: 1
# Nr: 863 Predicted label: 4
# Nr: 864 Predicted label: 2
# Nr: 865 Predicted label: 4
# Nr: 866 Predicted label: 4
# Nr: 867 Predicted label: 2
# Nr: 868 Predicted label: 1
# Nr: 869 Predicted label: 2
# Nr: 870 Predicted label: 4
# Nr: 871 Predicted label: 1
# Nr: 872 Predicted label: 5
# Nr: 873 Predicted label: 1
# Nr: 874 Predicted label: 5
# Nr: 875 Predicted label: 5
# Nr: 876 Predicted label: 2
# Nr: 877 Predicted label: 4
# Nr: 878 Predicted label: 1
# Nr: 879 Predicted label: 1
# Nr: 880 Predicted label: 2
# Nr: 881 Predicted label: 4
# Nr: 882 Predicted label: 2
# Nr: 883 Predicted label: 2
# Nr: 884 Predicted label: 4
# Nr: 885 Predicted label: 2
# Nr: 886 Predicted label: 4
# Nr: 887 Predicted label: 2
# Nr: 888 Predicted label: 4
# Nr: 889 Predicted label: 2
# Nr: 890 Predicted label: 2
# Nr: 891 Predicted label: 4
# Nr: 892 Predicted label: 4
# Nr: 893 Predicted label: 2
# Nr: 894 Predicted label: 4
# Nr: 895 Predicted label: 2
# Nr: 896 Predicted label: 4
# Nr: 897 Predicted label: 2
# Nr: 898 Predicted label: 4
# Nr: 899 Predicted label: 5
# Nr: 900 Predicted label: 5
# Nr: 901 Predicted label: 4
# Nr: 902 Predicted label: 2
# Nr: 903 Predicted label: 2
# Nr: 904 Predicted label: 2
# Nr: 905 Predicted label: 2
# Nr: 906 Predicted label: 1
# Nr: 907 Predicted label: 3
# Nr: 908 Predicted label: 3
# Nr: 909 Predicted label: 3
# Nr: 910 Predicted label: 5
# Nr: 911 Predicted label: 4
# Nr: 912 Predicted label: 1
# Nr: 913 Predicted label: 3
# Nr: 914 Predicted label: 3
# Nr: 915 Predicted label: 2
# Nr: 916 Predicted label: 5
# Nr: 917 Predicted label: 4
# Nr: 918 Predicted label: 4
# Nr: 919 Predicted label: 2
# Nr: 920 Predicted label: 2
# Nr: 921 Predicted label: 2
# Nr: 922 Predicted label: 4
# Nr: 923 Predicted label: 2
# Nr: 924 Predicted label: 3
# Nr: 925 Predicted label: 2
# Nr: 926 Predicted label: 2
# Nr: 927 Predicted label: 1
# Nr: 928 Predicted label: 3
# Nr: 929 Predicted label: 5
# Nr: 930 Predicted label: 1
# Nr: 931 Predicted label: 2
# Nr: 932 Predicted label: 4
# Nr: 933 Predicted label: 1
# Nr: 934 Predicted label: 1
# Nr: 935 Predicted label: 1
# Nr: 936 Predicted label: 3
# Nr: 937 Predicted label: 3
# Nr: 938 Predicted label: 2
# Nr: 939 Predicted label: 2
# Nr: 940 Predicted label: 4
# Nr: 941 Predicted label: 4
# Nr: 942 Predicted label: 4
# Nr: 943 Predicted label: 4
# Nr: 944 Predicted label: 3
# Nr: 945 Predicted label: 4
# Nr: 946 Predicted label: 3
# Nr: 947 Predicted label: 4
# Nr: 948 Predicted label: 3
# Nr: 949 Predicted label: 3
# Nr: 950 Predicted label: 5
# Nr: 951 Predicted label: 4
# Nr: 952 Predicted label: 3
# Nr: 953 Predicted label: 1
# Nr: 954 Predicted label: 4
# Nr: 955 Predicted label: 4
# Nr: 956 Predicted label: 3
# Nr: 957 Predicted label: 3
# Nr: 958 Predicted label: 3
# Nr: 959 Predicted label: 2
# Nr: 960 Predicted label: 2
# Nr: 961 Predicted label: 2
# Nr: 962 Predicted label: 5
# Nr: 963 Predicted label: 4
# Nr: 964 Predicted label: 3
# Nr: 965 Predicted label: 2
# Nr: 966 Predicted label: 2
# Nr: 967 Predicted label: 3
# Nr: 968 Predicted label: 1
# Nr: 969 Predicted label: 2
# Nr: 970 Predicted label: 5
# Nr: 971 Predicted label: 1
# Nr: 972 Predicted label: 2
# Nr: 973 Predicted label: 4
# Nr: 974 Predicted label: 3
# Nr: 975 Predicted label: 2
# Nr: 976 Predicted label: 1
# Nr: 977 Predicted label: 4
# Nr: 978 Predicted label: 2
# Nr: 979 Predicted label: 4
# Nr: 980 Predicted label: 3
# Nr: 981 Predicted label: 4
# Nr: 982 Predicted label: 4
# Nr: 983 Predicted label: 2
# Nr: 984 Predicted label: 2
# Nr: 985 Predicted label: 1
# Nr: 986 Predicted label: 1
# Nr: 987 Predicted label: 3
# Nr: 988 Predicted label: 2
# Nr: 989 Predicted label: 2
# Nr: 990 Predicted label: 1
# Nr: 991 Predicted label: 4
# Nr: 992 Predicted label: 2
# Nr: 993 Predicted label: 2
# Nr: 994 Predicted label: 1
# Nr: 995 Predicted label: 2
# Nr: 996 Predicted label: 2
# Nr: 997 Predicted label: 4
# Nr: 998 Predicted label: 3
# Nr: 999 Predicted label: 1

# %%
annotator.save_results(output_path=output_path)
# Out:
# Results saved successfully to ./results/no_samples_numbers_temp0/gpt4omini/sst5_gpt4omini_no_samples_numbers_temp0_exp1.csv

# %%
df = pd.read_csv(output_path)
df
# Out:
#                                                   text  output  \
# 0    Though the opera itself takes place mostly ind...       2
# 1    If you can read the subtitles ( the opera is s...       4
# 2    ( `` Safe Conduct '' ) is a long movie at 163 ...       4
# 3    The beauty of Alexander Payne 's ode to the Ev...       4
# 4    The fourth in a series that I 'll bet most par...       2
# ..                                                 ...     ...
# 995           In other words , it 's badder than bad .       2
# 996  The direction occasionally rises to the level ...       2
# 997                       The movie is ingenious fun .       4
# 998  The cast comes through even when the movie doe...       3
# 999  Most of the movie is so deadly dull that watch...       1
#
#                                               logprobs  \
# 0    {'content': [{'token': '2', 'bytes': [50], 'lo...
# 1    {'content': [{'token': '4', 'bytes': [52], 'lo...
# 2    {'content': [{'token': '4', 'bytes': [52], 'lo...
# 3    {'content': [{'token': '4', 'bytes': [52], 'lo...
# 4    {'content': [{'token': '2', 'bytes': [50], 'lo...
# ..                                                 ...
# 995  {'content': [{'token': '2', 'bytes': [50], 'lo...
# 996  {'content': [{'token': '2', 'bytes': [50], 'lo...
# 997  {'content': [{'token': '4', 'bytes': [52], 'lo...
# 998  {'content': [{'token': '3', 'bytes': [51], 'lo...
# 999  {'content': [{'token': '1', 'bytes': [49], 'lo...
#
#                                           top_logprobs  original_label
# 0    [{'token': '2', 'bytes': [50], 'logprob': -0.0...               3
# 1    [{'token': '4', 'bytes': [52], 'logprob': -0.0...               4
# 2    [{'token': '4', 'bytes': [52], 'logprob': -0.0...               4
# 3    [{'token': '4', 'bytes': [52], 'logprob': -0.0...               4
# 4    [{'token': '2', 'bytes': [50], 'logprob': -0.6...               3
# ..                                                 ...             ...
# 995  [{'token': '2', 'bytes': [50], 'logprob': -0.5...               1
# 996  [{'token': '2', 'bytes': [50], 'logprob': -2.1...               2
# 997  [{'token': '4', 'bytes': [52], 'logprob': -0.3...               5
# 998  [{'token': '3', 'bytes': [51], 'logprob': -0.1...               3
# 999  [{'token': '1', 'bytes': [49], 'logprob': -5.8...               1
#
# [1000 rows x 5 columns]

# %%
import ast

def format_top_logprobs(top_logprobs_str):
    try:
        top_logprobs = ast.literal_eval(top_logprobs_str)
        return '\n'.join([f"{d['token']:<15} → logprob: {d['logprob']}" for d in top_logprobs])
    except Exception as e:
        return f"Error: {e}"

df['top_logprobs_formatted'] = df['top_logprobs'].apply(format_top_logprobs)

# %%
df['top_logprobs_formatted']
# Out:
# 0      2               → logprob: -0.0086145689710974...
# 1      4               → logprob: -0.0141635099425911...
# 2      4               → logprob: -0.0001798225275706...
# 3      4               → logprob: -0.0380414947867393...
# 4      2               → logprob: -0.6931512355804443...
#                              ...
# 995    2               → logprob: -0.5759444236755371...
# 996    2               → logprob: -2.1008713702030946...
# 997    4               → logprob: -0.3868710398674011...
# 998    3               → logprob: -0.1602272689342498...
# 999    1               → logprob: -5.836499985889532e...
# Name: top_logprobs_formatted, Length: 1000, dtype: object

# %%
import pprint

pprint.pprint(df['top_logprobs_formatted'].iloc[0])
# Out:
# ('2               → logprob: -0.00861456897109747\n'
#  '3               → logprob: -4.758614540100098\n'
#  '1               → logprob: -18.383615493774414\n'
#  '２               → logprob: -20.883615493774414\n'
#  '4               → logprob: -21.008615493774414\n'
#  '₂               → logprob: -21.633615493774414\n'
#  '<|end|>         → logprob: -21.883615493774414\n'
#  '۲               → logprob: -22.383615493774414\n'
#  '²               → logprob: -23.883615493774414\n'
#  '২               → logprob: -24.446115493774414\n'
#  '२               → logprob: -24.696115493774414\n'
#  '٢               → logprob: -25.071115493774414\n'
#  'two             → logprob: -25.133615493774414\n'
#  '                → logprob: -25.383615493774414\n'
#  '３               → logprob: -25.446115493774414\n'
#  ' two            → logprob: -25.571115493774414\n'
#  'Two             → logprob: -25.758615493774414\n'
#  '۳               → logprob: -26.071115493774414\n'
#  '二               → logprob: -26.258615493774414\n'
#  'Rating          → logprob: -26.758615493774414')
