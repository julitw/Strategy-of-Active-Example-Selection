# %%
import os 
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd # type: ignore

# %%
from utils import get_dataset, get_model_by_tag, get_prompt_template
from LLMAnnotator import LLMAnnotator

# %%
os.environ['OPENAI_API_KEY_CLARIN']=os.getenv("OPENAI_API_KEY_CLARIN")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

token = os.getenv("OPENAI_API_KEY_CLARIN")

# %%
model_tag = 'llama3'  
dataset_tag = 'sst5'
prompt = 'no_samples'
temp = 0
number_of_experimet = 1

# %%
model = get_model_by_tag(model_tag, token, temp)  
dataset_for_annotation = get_dataset(dataset_tag=dataset_tag)
prompt_txt = get_prompt_template(dataset_tag, prompt)
examples_for_prompt = pd.DataFrame()

output_path = f'./results/{prompt}_temp{temp}/{model_tag}/{dataset_tag}_{model_tag}_{prompt}_temp{temp}_exp{number_of_experimet}.csv'
os.makedirs(f'./results/{prompt}_temp{temp}/{model_tag}', exist_ok=True)

# %%
dataset_for_annotation.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
print(model, dataset_for_annotation, prompt_txt, examples_for_prompt, output_path)
# Out:
# Llama3_1LLM
# Params: {}                                                   text  label
# 0    Though the opera itself takes place mostly ind...      3
# 1    If you can read the subtitles ( the opera is s...      4
# 2    ( `` Safe Conduct '' ) is a long movie at 163 ...      4
# 3    The beauty of Alexander Payne 's ode to the Ev...      4
# 4    The fourth in a series that I 'll bet most par...      3
# ..                                                 ...    ...
# 995           In other words , it 's badder than bad .      1
# 996  The direction occasionally rises to the level ...      2
# 997                       The movie is ingenious fun .      5
# 998  The cast comes through even when the movie doe...      3
# 999  Most of the movie is so deadly dull that watch...      1
#
# [1000 rows x 2 columns] Task: Read the following text and determine the most appropriate rating based on its content.
#
# Ratings:
# - 1
# - 2
# - 3
# - 4
# - 5
#
# Text for you: "{text}"
#
# Return only one rating (1, 2, 3, 4 or 5). No explanations. Empty DataFrame
# Columns: []
# Index: [] ./results/no_samples_temp0/llama3/sst5_llama3_no_samples_temp0_exp1.csv

# %%
text_col = "text"
label_col = "label"
output_col = "output"

# %%
annotator = LLMAnnotator(
    model=model,
    dataset=dataset_for_annotation,
    examples_for_prompt=examples_for_prompt,
    prompt_template=prompt_txt,
    column_text=text_col,
    column_label=label_col,
    column_output=output_col
)

# %%
df = annotator.get_results()
# Out:
# Nr: 0 Predicted label: 2
# Nr: 1 Predicted label: 4
# Nr: 2 Predicted label: 5
# Nr: 3 Predicted label: 5
# Nr: 4 Predicted label: 3
# Nr: 5 Predicted label: 3
# Nr: 6 Predicted label: 4
# Nr: 7 Predicted label: 2
# Nr: 8 Predicted label: 5
# Nr: 9 Predicted label: 1
# Nr: 10 Predicted label: 5
# Nr: 11 Predicted label: 1
# Nr: 12 Predicted label: 3
# Nr: 13 Predicted label: 5
# Nr: 14 Predicted label: 5
# Nr: 15 Predicted label: 4
# Nr: 16 Predicted label: 2
# Nr: 17 Predicted label: 5
# Nr: 18 Predicted label: 5
# Nr: 19 Predicted label: 2
# Nr: 20 Predicted label: 1
# Nr: 21 Predicted label: 3
# Nr: 22 Predicted label: 4
# Nr: 23 Predicted label: 2
# Nr: 24, próba 1/30 – błąd: Request failed with status 404: {"detail":"Error in model execution (input dumped to /tmp/err_execute_model_input_20250428-045546.pkl): CUDA out of memory. Tried to allocate 836.00 MiB. GPU 0 has a total capacity of 79.26 GiB of which 714.75 MiB is free. Including non-PyTorch memory, this process has 78.54 GiB memory in use. Of the allocated memory 75.64 GiB is allocated by PyTorch, with 60.00 MiB allocated in private pools (e.g., CUDA Graphs), and 1.48 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)"}
# Nr: 24, próba 2/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 3/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 4/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 5/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 6/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 7/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 8/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 9/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 10/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 11/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 12/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 13/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 14/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 15/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 16/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 17/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 18/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 19/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 20/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 21/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 22/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 23/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 24/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 25/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 26/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 27/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 28/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 29/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 24, próba 30/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 1/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 2/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 3/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 4/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 5/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 6/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 7/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 8/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 9/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 10/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 11/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 12/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 13/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 14/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 15/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 16/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 17/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 18/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 19/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 20/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 21/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 22/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 23/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 24/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 25/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 26/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 27/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 28/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 29/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 25, próba 30/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 1/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 2/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 3/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 4/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 5/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 6/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 7/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 8/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 9/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 10/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 11/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 12/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 13/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 14/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 15/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 16/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 17/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 18/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 19/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 20/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 21/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 22/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 23/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 24/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 25/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 26/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 27/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 28/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 29/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 26, próba 30/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 27, próba 1/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 18.877931833267212"}
# Nr: 27, próba 2/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 18.50152015686035"}
# Nr: 27, próba 3/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 18.17267870903015"}
# Nr: 27, próba 4/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 17.783364295959473"}
# Nr: 27, próba 5/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 17.363779544830322"}
# Nr: 27, próba 6/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 17.077346086502075"}
# Nr: 27, próba 7/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 16.749895334243774"}
# Nr: 27, próba 8/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 16.45832920074463"}
# Nr: 27, próba 9/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 16.140553951263428"}
# Nr: 27, próba 10/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 15.833265542984009"}
# Nr: 27, próba 11/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 15.533514022827148"}
# Nr: 27, próba 12/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 15.230907678604126"}
# Nr: 27, próba 13/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 14.800341606140137"}
# Nr: 27, próba 14/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 14.483360052108765"}
# Nr: 27, próba 15/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 14.182487726211548"}
# Nr: 27, próba 16/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 13.861095428466797"}
# Nr: 27, próba 17/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 13.495253562927246"}
# Nr: 27, próba 18/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 13.208778858184814"}
# Nr: 27, próba 19/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 12.890673637390137"}
# Nr: 27, próba 20/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 12.600379228591919"}
# Nr: 27, próba 21/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 12.298012971878052"}
# Nr: 27, próba 22/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 11.997298955917358"}
# Nr: 27, próba 23/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 11.695031642913818"}
# Nr: 27, próba 24/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 11.399362564086914"}
# Nr: 27, próba 25/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 11.098333358764648"}
# Nr: 27, próba 26/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 10.797482967376709"}
# Nr: 27, próba 27/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 10.500708818435669"}
# Nr: 27, próba 28/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 10.203514814376831"}
# Nr: 27, próba 29/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 9.896061420440674"}
# Nr: 27, próba 30/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 9.592352867126465"}
# Nr: 28, próba 1/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 9.292511463165283"}
# Nr: 28, próba 2/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 8.986668586730957"}
# Nr: 28, próba 3/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 8.660165071487427"}
# Nr: 28, próba 4/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 8.367091178894043"}
# Nr: 28, próba 5/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 8.034531593322754"}
# Nr: 28, próba 6/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 7.671772241592407"}
# Nr: 28, próba 7/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 7.361196279525757"}
# Nr: 28, próba 8/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 7.039570093154907"}
# Nr: 28, próba 9/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in
30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 2.4448513984680176"}
# Nr: 62, próba 4/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 2.1541242599487305"}
# Nr: 62, próba 5/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 1.8394956588745117"}
# Nr: 62, próba 6/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 1.5389974117279053"}
# Nr: 62, próba 7/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 1.1404798030853271"}
# Nr: 62, próba 8/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 0.7457060813903809"}
# Nr: 62, próba 9/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 0.4432821273803711"}
# Nr: 62, próba 10/30 – błąd: Request failed with status 429: {"detail":"Too many requests for 89.64.10.30. Try again in 0.14580917358398438"}
# Nr: 62, próba 11/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 12/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 13/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 14/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 15/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 16/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 17/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 18/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 19/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 20/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 21/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 22/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 23/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 24/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 25/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 26/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 27/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 28/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 29/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 62, próba 30/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 1/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 2/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 3/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 4/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 5/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 6/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 7/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 8/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 9/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 10/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 11/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 12/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Nr: 63, próba 13/30 – błąd: Request failed with status 404: {"detail":"Background loop has errored already."}
# Process Process-4440:
# Traceback (most recent call last):
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df = annotator.get_results()
#
# File ~/Desktop/anote-skrpyty 19.04/LLMAnnotator.py:138, in LLMAnnotator.get_results(self)
#     135     self._build_prompt()
#     136     self._build_chain()
# --> 138     self.results = self.fetch_answer(texts, labels)
#     139     return self.results
#     140 except Exception as e:
#
# File ~/anaconda3/envs/anote/lib/python3.12/site-packages/langsmith/run_helpers.py:614, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     612 except BaseException as e:
#     613     _on_run_end(run_container, error=e)
# --> 614     raise e
#     615 _on_run_end(run_container, outputs=function_result)
#     616 return function_result
#
# File ~/anaconda3/envs/anote/lib/python3.12/site-packages/langsmith/run_helpers.py:611, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     609     if not func_accepts_config:
#     610         kwargs.pop("config", None)
# --> 611     function_result = run_container["context"].run(func, *args, **kwargs)
#     612 except BaseException as e:
#     613     _on_run_end(run_container, error=e)
#
# File ~/Desktop/anote-skrpyty 19.04/LLMAnnotator.py:93, in LLMAnnotator.fetch_answer(self, texts, original_labels, max_retries, timeout_seconds)
#      91 process = multiprocessing.Process(target=call_chain_process, args=(self.chain, text, return_dict))
#      92 process.start()
# ---> 93 process.join(timeout_seconds)
#      95 if process.is_alive():
#      96     print(f"Nr: {i}, próba {attempt + 1}/{max_retries} – przekroczono timeout {timeout_seconds}s, przerywam")
#
# File ~/anaconda3/envs/anote/lib/python3.12/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/anaconda3/envs/anote/lib/python3.12/multiprocessing/popen_fork.py:40, in Popen.wait(self, timeout)
#      38 if timeout is not None:
#      39     from multiprocessing.connection import wait
# ---> 40     if not wait([self.sentinel], timeout):
#      41         return None
#      42 # This shouldn't block if wait() returned successfully.
#
# File ~/anaconda3/envs/anote/lib/python3.12/multiprocessing/connection.py:1136, in wait(object_list, timeout)
#    1133     deadline = time.monotonic() + timeout
#    1135 while True:
# -> 1136     ready = selector.select(timeout)
#    1137     if ready:
#    1138         return [key.fileobj for (key, events) in ready]
#
# File ~/anaconda3/envs/anote/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/julita/Desktop/anote-skrpyty 19.04/LLMAnnotator.py", line 13, in call_chain_process
#     result = chain.invoke({"text": text})
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain/chains/base.py", line 170, in invoke
#     raise e
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain/chains/base.py", line 160, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 755, in generate_prompt
#     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 950, in generate
#     output = self._generate_helper(
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 792, in _generate_helper
#     raise e
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 779, in _generate_helper
#     self._generate(
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 1504, in _generate
#     else self._call(prompt, stop=stop, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/Desktop/anote-skrpyty 19.04/Amodels/Llama3_1LLM.py", line 31, in _call
#     response = requests.post(
#                ^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/api.py", line 115, in post
#     return request("post", url, data=data, json=json, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     self._validate_conn(conn)
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/connectionpool.py", line 1095, in _validate_conn
#     conn.connect()
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/connection.py", line 730, in connect
#     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/connection.py", line 909, in _ssl_wrap_socket_and_match_hostname
#     ssl_sock = ssl_wrap_socket(
#                ^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/util/ssl_.py", line 469, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/util/ssl_.py", line 513, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/ssl.py", line 455, in wrap_socket
#     return self.sslsocket_class._create(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/ssl.py", line 1041, in _create
#     self.do_handshake()
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/ssl.py", line 1319, in do_handshake
#     self._sslobj.do_handshake()
# KeyboardInterrupt

# %%
annotator.save_results(output_path=output_path)
# Out:
# Results saved successfully to ./results/no_samples_temp0/cohere/sst5_cohere_no_samples_temp0_exp1.csv

# %%
df = pd.read_csv(output_path)
df
# Out:
#                                                   text  output  \
# 0    Though the opera itself takes place mostly ind...       3
# 1    If you can read the subtitles ( the opera is s...       3
# 2    ( `` Safe Conduct '' ) is a long movie at 163 ...       4
# 3    The beauty of Alexander Payne 's ode to the Ev...       4
# 4    The fourth in a series that I 'll bet most par...       4
# ..                                                 ...     ...
# 995           In other words , it 's badder than bad .       5
# 996  The direction occasionally rises to the level ...       2
# 997                       The movie is ingenious fun .       4
# 998  The cast comes through even when the movie doe...       3
# 999  Most of the movie is so deadly dull that watch...       1
#
#                                               logprobs  \
# 0    {'content': [{'token': '3', 'bytes': [51], 'lo...
# 1    {'content': [{'token': '3', 'bytes': [51], 'lo...
# 2    {'content': [{'token': '4', 'bytes': [52], 'lo...
# 3    {'content': [{'token': '4', 'bytes': [52], 'lo...
# 4    {'content': [{'token': '4', 'bytes': [52], 'lo...
# ..                                                 ...
# 995  {'content': [{'token': '5', 'bytes': [53], 'lo...
# 996  {'content': [{'token': '2', 'bytes': [50], 'lo...
# 997  {'content': [{'token': '4', 'bytes': [52], 'lo...
# 998  {'content': [{'token': '3', 'bytes': [51], 'lo...
# 999  {'content': [{'token': '1', 'bytes': [49], 'lo...
#
#                                           top_logprobs  original_label
# 0    [{'token': '3', 'bytes': [51], 'logprob': -0.6...               3
# 1    [{'token': '3', 'bytes': [51], 'logprob': -0.7...               4
# 2    [{'token': '4', 'bytes': [52], 'logprob': -0.6...               4
# 3    [{'token': '4', 'bytes': [52], 'logprob': -0.7...               4
# 4    [{'token': '4', 'bytes': [52], 'logprob': -0.9...               3
# ..                                                 ...             ...
# 995  [{'token': '5', 'bytes': [53], 'logprob': -0.1...               1
# 996  [{'token': '2', 'bytes': [50], 'logprob': -0.0...               2
# 997  [{'token': '4', 'bytes': [52], 'logprob': -0.6...               5
# 998  [{'token': '3', 'bytes': [51], 'logprob': -0.3...               3
# 999  [{'token': '1', 'bytes': [49], 'logprob': -0.4...               1
#
# [1000 rows x 5 columns]

# %%
import ast

def format_top_logprobs(top_logprobs_str):
    try:
        top_logprobs = ast.literal_eval(top_logprobs_str)
        return '\n'.join([f"{d['token']:<15} → logprob: {d['logprob']}" for d in top_logprobs])
    except Exception as e:
        return f"Error: {e}"

df['top_logprobs_formatted'] = df['top_logprobs'].apply(format_top_logprobs)

# %%
df['top_logprobs_formatted']
# Out:
# 0      3               → logprob: -0.6339502334594727...
# 1      3               → logprob: -0.7881949543952942...
# 2      4               → logprob: -0.6213630437850952...
# 3      4               → logprob: -0.7051126956939697...
# 4      4               → logprob: -0.9099186062812805...
#                              ...
# 995    5               → logprob: -0.1760061532258987...
# 996    2               → logprob: -0.0732197463512420...
# 997    4               → logprob: -0.6977537870407104...
# 998    3               → logprob: -0.3197877109050751...
# 999    1               → logprob: -0.4802128672599792...
# Name: top_logprobs_formatted, Length: 1000, dtype: object

# %%
import pprint

pprint.pprint(df['top_logprobs_formatted'].iloc[0])
# Out:
# ('3               → logprob: -0.6339502334594727\n'
#  '2               → logprob: -0.8839502334594727\n'
#  '1               → logprob: -3.3839502334594727\n'
#  '4               → logprob: -3.8839502334594727\n'
#  '5               → logprob: -6.383950233459473\n'
#  'Rating          → logprob: -8.883950233459473\n'
#  '.               → logprob: -11.883950233459473\n'
#  '0               → logprob: -11.883950233459473\n'
#  'Review          → logprob: -12.383950233459473\n'
#  'I               → logprob: -12.383950233459473\n'
#  ' Rating         → logprob: -12.633950233459473\n'
#  'This            → logprob: -13.133950233459473\n'
#  '-               → logprob: -13.383950233459473\n'
#  'Two             → logprob: -13.383950233459473\n'
#  'rating          → logprob: -13.383950233459473\n'
#  'Three           → logprob: -13.383950233459473\n'
#  ':               → logprob: -13.883950233459473\n'
#  '"               → logprob: -13.883950233459473\n'
#  'It              → logprob: -14.133950233459473\n'
#  'A               → logprob: -14.133950233459473')
