# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Dane wejściowe
data = {
    "dataset": [
        "20 Newsgroups", "20 Newsgroups", "20 Newsgroups",
        "AG News", "AG News", "AG News",
        "GoEmotions", "GoEmotions", "GoEmotions",
        "Social Media", "Social Media", "Social Media",
        "SST-5", "SST-5", "SST-5",
        "Yahoo", "Yahoo", "Yahoo"
    ],
    "method": [
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral"
    ],
    "f1_score": [
        0.535171, 0.574780, 0.578489,
        0.864845, 0.866746, 0.859725,
        0.339936, 0.300118, 0.311987,
        0.502993, 0.472404, 0.426532,
        0.544371, 0.497934, 0.529300,
        0.590238, 0.647259, 0.638389
    ]
}

df = pd.DataFrame(data)
plt.style.use('ggplot')

import os

# Wstępne przygotowanie danych
grouping_data = {
    "Dataset": [
        "20 Newsgroups", "20 Newsgroups", "20 Newsgroups",
        "AG News", "AG News", "AG News",
        "GoEmotions", "GoEmotions", "GoEmotions",
        "Social Media", "Social Media", "Social Media",
        "SST-5", "SST-5", "SST-5",
        "Yahoo", "Yahoo", "Yahoo"
    ],
    "Method": [
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral"
    ],
    "F1": [
        53.5, 57.5, 57.8,
        86.5, 86.7, 85.9,
        34.0, 30.0, 31.2,
        50.3, 47.2, 42.7,
        54.4, 49.8, 52.9,
        59.0, 64.7, 63.8
    ]
}

df_grouping = pd.DataFrame(grouping_data)

# Wykres słupkowy miary F1
plt.figure(figsize=(12, 8))
grouped = df_grouping.pivot(index="Dataset", columns="Method", values="F1")
grouped.plot(kind="bar", rot=30, figsize=(12, 8), color=["#1f77b4", "#ff7f0e", "#2ca02c"])

plt.ylabel("Miara F1 [%]", fontsize=14)
plt.title("Porównanie miary F1 dla pobudzeń z przykładami uzyskanymi \n z różnych metod grupowania dla modelu GPT-4o Mini", fontsize=18, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.yticks(np.arange(0, 101, 10), [f"{x}%" for x in range(0, 101, 10)])
plt.xticks(fontsize=12)
plt.legend(title="Metoda grupowania", fontsize=12)
plt.savefig('grupowanie_gpt4omini', dpi=300, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
# Nowe dane dla modelu Cohere
cohere_grouping_data = {
    "Dataset": [
        "20 Newsgroups", "20 Newsgroups", "20 Newsgroups",
        "AG News", "AG News", "AG News",
        "GoEmotions", "GoEmotions", "GoEmotions",
        "Social Media", "Social Media", "Social Media",
        "SST-5", "SST-5", "SST-5",
        "Yahoo", "Yahoo", "Yahoo"
    ],
    "Method": [
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral"
    ],
    "F1": [
        37.5, 32.4, 41.4,
        80.4, 82.6, 82.2,
        16.9, 13.9, 17.5,
        53.7, 51.6, 48.6,
        52.8, 46.6, 53.5,
        41.9, 35.3, 33.2
    ]
}

plt.style.use('ggplot')

df_cohere_grouping = pd.DataFrame(cohere_grouping_data)

# Wykres słupkowy miary F1 dla modelu Cohere
plt.figure(figsize=(12, 8))
grouped_cohere = df_cohere_grouping.pivot(index="Dataset", columns="Method", values="F1")
grouped_cohere.plot(kind="bar", rot=30, figsize=(12, 8), color=["#1f77b4", "#ff7f0e", "#2ca02c"])

plt.ylabel("Miara F1 [%]", fontsize=14)
plt.title("Porównanie miary F1 dla pobudzeń z przykładami uzyskanymi \n z różnych metod grupowania dla modelu Cohere", fontsize=18, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.yticks(np.arange(0, 101, 10), [f"{x}%" for x in range(0, 101, 10)])
plt.xticks(fontsize=12)
plt.legend(title="Metoda grupowania", fontsize=12)
plt.tight_layout()
plt.savefig('grupowanie_cohere', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Dane dla modelu Llama 3.1
llama_grouping_data = {
    "Dataset": [
        "20 Newsgroups", "20 Newsgroups", "20 Newsgroups",
        "AG News", "AG News", "AG News",
        "GoEmotions", "GoEmotions", "GoEmotions",
        "Social Media", "Social Media","Social Media",
        "SST-5", "SST-5", "SST-5",
        "Yahoo", "Yahoo", "Yahoo"
    ],
    "Method": [
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral",
        "Gaussian", "KMeans", "Spectral"
    ],
    "F1": [
        60.8, 56.7, 50.6,
        87.4, 44.9, 86.8,
        19.5, 17.9, 18.5,
        55.4, 49.8, 50.3,
        39.9, 56.0, 56.6,
        57.4, 65.6, 71.3
    ]
}

df_llama_grouping = pd.DataFrame(llama_grouping_data)
# Wykres słupkowy miary F1 dla modelu Llama 3.1
plt.figure(figsize=(12, 8))
grouped_llama = df_llama_grouping.pivot(index="Dataset", columns="Method", values="F1")
grouped_llama.plot(kind="bar", rot=30, figsize=(12, 8), color=["#1f77b4", "#ff7f0e", "#2ca02c"])

plt.ylabel("Miara F1 [%]", fontsize=14)
plt.title("Porównanie miary F1 dla pobudzeń z przykładami uzyskanymi \n z różnych metod grupowania dla modelu Llama 3.1", fontsize=18, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.yticks(np.arange(0, 101, 10), [f"{x}%" for x in range(0, 101, 10)])
plt.xticks(fontsize=12)
plt.legend(title="Metoda grupowania", fontsize=12)
plt.tight_layout()
plt.savefig('grupowanie_llama', dpi=300, bbox_inches='tight')
plt.show()
