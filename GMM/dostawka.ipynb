# %%
import pandas as pd

# %%
df1 = pd.read_csv('results/emb_temp0/llama3/20_newsgroups_llama3_emb_gaussian_temp0_exp1.csv')
df2 = pd.read_csv('results/emb_temp0/llama3/20_newsgroups_llama3_emb_gaussian_temp0_expdostawka.csv')

# %%
df1
# Out:
#                                                    text  \
# 0     article ashish arora writes excerpts netnewssc...
# 1     gateway telepath modem month actually one woul...
# 2     anybody provide advice concerning following tw...
# 3     article mike silverman writes anybody know goi...
# 4     article stich christian e writes installed mot...
# ...                                                 ...
# 1245  article nigel allen writes press release natio...
# 1246  sorry last post server neglected send message ...
# 1247  stuart esrock writes hittinghawks tried outmus...
# 1248  article nittmo camelot christopher taylor writ...
# 1249  wrote lets talk principles accept god sets sta...
#
#                        output  \
# 0          talk.politics.misc
# 1     comp.os.ms-windows.misc
# 2                     sci.med
# 3          rec.sport.baseball
# 4             sci.electronics
# ...                       ...
# 1245       talk.politics.guns
# 1246                rec.autos
# ...

# %%
df2 = df2.drop(columns=['was_in_selected_samples', 'extracted_label'])

# %%
df = pd.concat([df1, df2], ignore_index=True)
df
# Out:
#                                                    text  \
# 0     article ashish arora writes excerpts netnewssc...
# 1     gateway telepath modem month actually one woul...
# 2     anybody provide advice concerning following tw...
# 3     article mike silverman writes anybody know goi...
# 4     article stich christian e writes installed mot...
# ...                                                 ...
# 1981  david sternlight writes article karl barrus wr...
# 1982  hello im looking information alphanumeric page...
# 1983  john r daker writes would like offocially nomi...
# 1984  article writes looking information concerning ...
# 1985  steve brinich writes flaming libertarian paran...
#
#                        output  \
# 0          talk.politics.misc
# 1     comp.os.ms-windows.misc
# 2                     sci.med
# 3          rec.sport.baseball
# 4             sci.electronics
# ...                       ...
# 1981                sci.crypt
# 1982          sci.electronics
# ...

# %%
df.to_csv('results/emb_temp0/llama3/20_newsgroups_llama3_emb_gaussian_temp0_exp1.csv')
