# %%
import pandas as pd

# %%
# dataset = 'yahoo'
# num = 60
# exp = 2
# model = 'llama3'
# prompt = 'cot_random_samples_cohere'
dataset = 'ag_news'
num = 80
exp = 3
model = 'llama3'
prompt = 'cot_random_samples_cohere'
df = pd.read_csv(f'results/{prompt}_temp0.3/{model}/{dataset}_{model}_{prompt}_{model}_random42_{num}_temp0.3_exp{exp}.csv')
df
# Out:
#                                                   text  \
# 0    Coke is it: BHP coal to double BHP Billiton pl...
# 1    BIG HIKE IN ENERGY BILLS The company says the ...
# 2    Officials Blame Contractors in Tunnel Leak The...
# 3    Before the Bell: Krispy Kreme Down 11 Pct Shar...
# 4    Medical Examiner Finds No Injuries on Thanou-S...
# ..                                                 ...
# 995  Indian politician sent to prison Top Hindu nat...
# 996  Ravens - Bills: Game Notes COMPOSED: With Lewi...
# 997  Dell touts in-home services Dell offers to ins...
# 998  Lately, it's been fast times World Series anal...
# 999  Venezuela Raises Taxes on Orinoco Deals &lt;p&...
#
#                                                 output  \
# 0    To determine the most appropriate category for...
# 1    Let's analyze the text step by step:\n\n**Step...
# 2    Let's analyze the text step by step:\n\n**Step...
# 3    To determine the most appropriate category for...
# ...

# %%
import pandas as pd
df = pd.read_csv('extracted_new/results/cot_random_samples_cohere_temp0.3/llama3/20_newsgroups_llama3_cot_random_samples_cohere_llama3_random42_80_temp0.3_exp2.csv')
df
# Out:
#                                                   text  \
# 0    article henry spencer writes dragless satellit...
# 1    article michael covington writes strong prefer...
# 2    dillon comments space food sticks may bad dige...
# 3    article writes loosing whats loosing vote caus...
# 4    hi electronic engineering student electronic i...
# ..                                                 ...
# 745  hello im looking information alphanumeric page...
# 746  john r daker writes would like offocially nomi...
# 747  article writes looking information concerning ...
# 748  steve brinich writes flaming libertarian paran...
# 749  wrote lets talk principles accept god sets sta...
#
#                                                 output  \
# 0    Let's analyze the text step by step.\n\n**Step...
# 1    Let's break down the text step by step:\n\n1. ...
# 2    Let's break down the analysis step by step:\n\...
# 3    Let's analyze the text step by step.\n\n**Step...
# ...
