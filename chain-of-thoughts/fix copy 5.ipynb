# %%
import os 
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd # type: ignore

# %%
from utils import get_dataset, get_model_by_tag, get_prompt_template
from LLMAnnotator import LLMAnnotator

# %%
os.environ['OPENAI_API_KEY_CLARIN']=os.getenv("OPENAI_API_KEY_CLARIN")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

token = os.getenv("OPENAI_API_KEY_CLARIN")

# %%
import os
import pandas as pd
import re

def extract_bracketed_word(df, read_col, write_col):
    def extract_last_bracketed(text):
        matches = re.findall(r'\[([^\[\]]+?)\]', str(text))
        return matches[-1] if matches else None
    df[write_col] = df[read_col].apply(extract_last_bracketed)
    return df

def validate_text_column(df, df_reference):
    reference_texts = set(df_reference['text'].unique())
    df['was_in_selected_samples'] = df['text'].isin(reference_texts)
    df = extract_bracketed_word(df, 'output', 'extracted_label')
    return df

for i in [3]:
    print('\n\nMUMER', i, '\n\n')
    
    model_tag = 'llama3'
    dataset_tag = '20_newsgroups'
    prompt = 'cot_random_samples_cohere'
    temp = 0.3
    number_of_experimet = i
    selected_samples = f'{model_tag}_random42_80'
    
    model = get_model_by_tag(model_tag, token, temp)
    prompt_txt = get_prompt_template(dataset_tag, prompt)
    examples_for_prompt = pd.read_csv(f'./selected_samples/{dataset_tag}/{selected_samples}.csv')

    output_path = f'./results/{prompt}_temp{temp}/{model_tag}/{dataset_tag}_{model_tag}_{prompt}_{selected_samples}_temp{temp}_exp{number_of_experimet}.csv'
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    
    try:
        df_old = pd.read_csv(output_path)
    except FileNotFoundError:
        df_old = pd.DataFrame(columns=['text', 'label', 'output'])
        
    df_old = validate_text_column(df_old, examples_for_prompt)

    # Dodaj 'original_index', żeby móc później przywrócić kolejność
    full_dataset = get_dataset(dataset_tag=dataset_tag)
    full_dataset = full_dataset.reset_index().rename(columns={'index': 'original_index'})

    # Wczytaj stare wyniki lub stwórz pusty DataFrame
    try:
        df_old = pd.read_csv(output_path)
    except FileNotFoundError:
        df_old = pd.DataFrame(columns=['text', 'label', 'output', 'error'])
        
    # Do zaannotowania:
    # - brak tekstu w df_old
    # - lub w df_old jest 'error' niepuste dla danego textu
    if 'error' not in df_old.columns:
        df_old['error'] = None
    texts_with_errors = df_old[df_old['error'].notna() & (df_old['error'].astype(str) != '')]['text']
    texts_already_done = set(df_old['text']) - set(texts_with_errors)
    df_to_annotate = full_dataset[~full_dataset['text'].isin(texts_already_done)]

    print('Do zaannotowania:', len(df_to_annotate))


    if not df_to_annotate.empty:
        annotator = LLMAnnotator(
            model=model,
            dataset=df_to_annotate,
            examples_for_prompt=examples_for_prompt,
            prompt_template=prompt_txt,
            column_text="text",
            column_label="label",
            column_output="output"
        )
        df_new = annotator.get_results()
        df_new = validate_text_column(pd.DataFrame(df_new), examples_for_prompt)

        # Łączenie z zachowaniem indeksu
        
        df_new = df_new.merge(df_to_annotate[['text', 'original_index']], on='text', how='left')

        df_old = df_old.merge(full_dataset[['text', 'original_index']], on='text', how='left')
        
        df_combined = pd.concat([df_old, df_new], ignore_index=True)
        df_combined.drop_duplicates(subset='original_index', keep='last', inplace=True)
        df_combined.sort_values(by='original_index', inplace=True)
        
        # Usuń kolumnę 'error', jeśli wszystkie wartości są puste lub puste stringi
        if 'error' in df_combined.columns and df_combined['error'].replace('', pd.NA).isna().all():
            df_combined.drop(columns='error', inplace=True)

        df_combined.to_csv(output_path, index=False)
        print("Zaktualizowano plik:", output_path)

    else:
        print("Brak nowych przykładów do anotacji.")
# Out:
# MUMER 3
#
#
# Do zaannotowania: 749
# /home/julita/Desktop/anote-skrpyty 19.04/LLMAnnotator.py:77: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   self.chain = LLMChain(llm=self.model, prompt=self.prompt)
# Nr: 0 Predicted label: To determine the most appropriate category for the given text, let's analyze it step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text revolves around a discussion about a "dragless satellite" and its implications, mentioning concepts like laser geodesy, orbital parameters, and navigation.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "dragless satellite," "laser geodesy," "orbital parameters," and "navigation." These terms are closely related to space exploration and technology.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **rec.autos**: These categories are related to sports and vehicles, which do not match the content of the text.
#    - **soc.religion.christian**, **alt.atheism**, **talk.religion.misc**: These categories are related to religion and atheism, which do not match the content of the text.
#    - **sci.crypt**, **sci.med**, **sci.electronics**: While these categories are related to science, they focus on cryptography, medicine, and electronics, respectively. The text's focus on space and satellites makes it less likely to fit into these categories.
#    - **sci.space**: This category is directly related to space and astronomy, making it a strong candidate for the text's content.
#    - Other categories like **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.graphics**, **comp.windows.x**, **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**, and **misc.forsale** do not directly relate to the content of the text.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on space-related technology and concepts, the most appropriate category for the text is **sci.space**.
#
# [sci.space]
# Nr: 1 Predicted label: Let's break down the text step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about Bible editions, specifically the formatting and layout of verses and chapters. The author is discussing their preference for editions that do not show verse numbers and is looking for an English language edition that does not have verse numbers.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms and phrases that stand out include "Bible editions", "verse numbering", "Scots NT", "Jerusalem Bible", and "NEB". These terms are all related to biblical studies and Christian scripture.
#
# 3. **Compare the topic to the definitions of each category**: Based on the key terms and phrases, the topic appears to be most closely related to Christianity and biblical studies. The categories that seem most relevant are "soc.religion.christian" and "talk.religion.misc".
#
# 4. **Choose the most appropriate category based on your reasoning**: After considering the topic and key terms, I believe the most appropriate category is "soc.religion.christian". This category is specifically focused on Christianity and biblical studies, which aligns with the main topic of the text.
#
# [soc.religion.christian]
# Nr: 2 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text discusses the digestive properties of space food sticks and their potential impact on waste disposal in space, specifically referencing NASA's considerations for minimizing difficulties with waste.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "space food sticks," "NASA," "low fiber zero-residue products," and "waste disposal." These terms are closely related to space exploration and the challenges associated with it.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, and **rec.autos** are all related to sports and vehicles, which do not match the topic.
#    - **soc.religion.christian**, **alt.atheism**, and **talk.religion.misc** are related to religion and atheism, which are not relevant.
#    - **sci.crypt**, **sci.med**, and **sci.electronics** deal with cryptography, medicine, and electronics, respectively. While **sci.med** might seem somewhat relevant due to the mention of digestive properties, the primary focus is on space and NASA.
#    - **sci.space** is directly related to space and space exploration, making it a strong candidate.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.windows.x**, and **comp.graphics** are related to computer systems and software, which are not relevant to the topic.
#    - **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**, and **misc.forsale** are related to politics and sales, which do not match the topic.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on space, NASA, and the challenges of space exploration, the most appropriate category is clearly related to space.
#
# [sci.space]
# Nr: 3 Predicted label: Let's break down the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be a discussion about gun control laws, the Second Amendment, and the author's opposition to restrictions on gun ownership.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out include:
#
# * "RKBA" (Right to Keep and Bear Arms)
# * "Second Amendment"
# * "gun control laws"
# * "concealed carry permits"
# * "NRA-endorsed"
#
# These terms suggest a strong connection to firearms and gun ownership.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to politics, firearms, and gun ownership.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After reviewing the categories, I believe the most appropriate category for this text is [talk.politics.guns]. This category is specifically focused on discussions about gun control, firearms, and related politics, which aligns with the main topic of the text.
#
# [talk.politics.guns]
# Nr: 4 Predicted label: Let's break down the text step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about building a moderate wattage audio amplifier and seeking help from others on the internet to understand how to calculate watts in audio amp circuits and to find a suitable schematic and parts list.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms and phrases include "electronic engineering", "audio amp", "watts calculated", "schematic", "parts list", "IC", "amplifiers", "heatsink", "PSPICE simulation", and "opamp models". These terms are related to electronics and engineering.
#
# 3. **Compare the topic to the definitions of each category**: The topic is most closely related to electronics and engineering, specifically to the design and construction of electronic circuits.
#
# 4. **Choose the most appropriate category based on your reasoning**: Based on the key terms and phrases, the topic is most closely related to electronics and engineering.
#
# [sci.electronics]
# Nr: 5 Predicted label: Let's analyze the text step by step:
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text is a discussion about non-lethal bullets, such as rubber or plastic bullets, and their potential effectiveness in stopping an attack. The text also touches on the author's opinion on how different political parties (Democrats, Republicans, and Libertarians) approach problems and money.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# Key terms and phrases that stand out are "non-lethal bullets", "rubber bullets", "plastic bullets", "attack", "Democrats", "Republicans", and "Libertarians". These terms suggest a discussion about politics, guns, and law enforcement.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms and phrases, the topic seems to fit best with categories related to politics, guns, or law enforcement. The categories that come closest are:
#
# * talk.politics.guns
# * talk.politics.misc
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# After comparing the topic to the definitions of each category, I believe the most appropriate category is [talk.politics.guns]. The text discusses non-lethal bullets and their potential effectiveness in stopping an attack, which is a topic related to guns and law enforcement. While the text also touches on politics, the primary focus is on the discussion of non-lethal bullets, making talk.politics.guns the most suitable category.
# Nr: 6 Predicted label: Let's break down the text step by step:
#
# 1. Summarize the main topic of the text:
#
# The text appears to be a discussion or argument between two individuals, Joachim Martillo and Mohammed Elabdellaoui, about the relationship between Muslims and Nazis. The conversation is heated, with both parties exchanging insults and accusations.
#
# 2. Identify any key terms or phrases that hint at a specific category:
#
# Key terms and phrases include "Muslims," "Nazis," "Islam," "totalitarianism," "mufti," "Jerusalem," "Palestine," "Jewish lobby," and "Israel." These terms suggest a discussion about politics, religion, and international relations.
#
# 3. Compare the topic to the definitions of each category:
#
# Based on the key terms and phrases, the most relevant categories appear to be:
#
# * talk.politics.mideast (Middle East politics)
# * soc.religion.christian (Christianity and related discussions)
# * alt.atheism (Atheism and related discussions)
# * talk.politics.misc (Miscellaneous politics)
#
# However, the text does not seem to focus on Christianity or atheism specifically, so we can rule out those categories.
#
# 4. Choose the most appropriate category based on your reasoning:
#
# Given the focus on Middle East politics, Islam, and the Israeli-Palestinian conflict, the most appropriate category appears to be talk.politics.mideast.
#
# [talk.politics.mideast]
# Nr: 7 Predicted label: Let's analyze the text step by step:
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text is the author's struggle with a stepper controller board, specifically with wiring and transistor hookups. They're seeking help to resolve the issue.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# Key terms and phrases include "stepper controller board", "wire steppers", "phase lines", "transistor hookup", and "npns" (bipolar junction transistors). These terms suggest a technical, electronics-related topic.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms and phrases, the topic seems to fit best with categories related to electronics, technology, or engineering.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# After reviewing the categories, I think the most appropriate category is [sci.electronics], as it deals with electronics and technical discussions.
#
# So, the final category is: [sci.electronics]
# Nr: 8 Predicted label: Let's analyze the text step by step:
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is a personal anecdote about a motorcyclist who was pulled over by a cop in Canada during snowy weather. The motorcyclist was not given a ticket and was instead warned to watch their speed limit.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# The key terms and phrases that hint at a specific category are:
#
# * "motorcycle" (not explicitly mentioned, but implied by the context)
# * "cop pulled me over"
# * "centigrade" (a unit of temperature, which suggests a discussion about weather conditions)
# * "snowing"
# * "Canada"
# * "Honda" (a motorcycle brand)
#
# These terms and phrases suggest that the text is related to motorcycles and riding.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the most relevant categories are:
#
# * rec.motorcycles (a category for discussing motorcycles and riding)
# * rec.autos (a category for discussing cars and driving, but not directly related to motorcycles)
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for the text is rec.motorcycles, as it is a personal anecdote about a motorcyclist's experience with a cop during snowy weather.
#
# [rec.motorcycles]
# Nr: 9 Predicted label: Let's analyze the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text is the author asking for contact information to obtain a "Darwin fish" and mentioning that they have seen the answer on the net.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key term here is "Darwin fish", which is a symbol that represents evolution and is often used as a parody of the Christian "Jesus fish" symbol. This term is closely related to the topic of evolution, which is often discussed in the context of science and religion.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key term "Darwin fish", the topic seems to be related to evolution and science. However, the text also mentions the author's desire to obtain the symbol, which could be related to a hobby or interest. The categories that seem most relevant are sci.electronics, sci.med, sci.space, and talk.religion.misc.
#
# 4. Choose the most appropriate category based on your reasoning:
# After considering the key term "Darwin fish" and the context of the text, I believe that the most appropriate category is talk.religion.misc. This category seems to be the best fit because the Darwin fish is a symbol that is often used in discussions about evolution and creationism, which are topics that are frequently debated in the context of religion.
#
# [talk.religion.misc]
# Nr: 10 Predicted label: Let's break down the text step by step:
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is cryptography, specifically discussing the security of the Skipjack encryption algorithm and the possibility of the NSA compromising it.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases include "Skipjack", "NSA", "cryptography", "brute force keysearch", "PGP", and "DES". These terms are related to cryptography and encryption.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to cryptography and encryption. The categories that seem most relevant are:
#
# * sci.crypt (Science: Cryptography)
# * comp.os.ms-windows.misc (Computing: Microsoft Windows Miscellaneous) - although this category is not directly related to cryptography, it could be a possibility if the text was discussing Windows-specific encryption issues.
# * comp.sys.ibm.pc.hardware (Computing: IBM PC Hardware) - although this category is not directly related to cryptography, it could be a possibility if the text was discussing hardware-specific encryption issues.
#
# However, based on the content of the text, sci.crypt seems to be the most appropriate category.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for the text is [sci.crypt].
# Nr: 11 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The main topic revolves around the use of ultra-sticky labels as an alternative to wheel clamps for cars parked illegally. The discussion includes the potential liability and the effectiveness of such labels.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "ultra sticky labels," "wheel clamps," "parking," "liability," and "cars." These terms are closely related to vehicles and parking issues.
#
# 3. **Compare the topic to the definitions of each category**: Given the focus on vehicles and parking, the most relevant categories would likely be related to transportation or automotive topics.
#
# 4. **Choose the most appropriate category based on your reasoning**: Based on the content, the best category for this text would be one that deals with automobiles or automotive issues, including parking and vehicle management.
#
# After considering the provided categories, the most fitting one is **[rec.autos]**, as it directly pertains to automotive topics, including discussions about parking, vehicle management, and related issues.
#
# [rec.autos]
# Nr: 12 Predicted label: To determine the most appropriate category for the text, let's break it down step by step:
#
# 1. **Summarize the main topic of the text**: The text appears to be discussing computer hardware, specifically connections and interfaces related to drives (e.g., SCSI, SMD).
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "balanced-line connections," "IDC," "SMD interface," "SCSI," and "large drives." These terms are related to computer hardware, particularly storage devices and their interfaces.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **rec.autos**: These categories are related to sports and vehicles, which do not match the content of the text.
#    - **soc.religion.christian**, **alt.atheism**, **talk.religion.misc**: These categories are related to religion and atheism, which do not match the content of the text.
#    - **sci.crypt**, **sci.med**, **sci.space**: These categories are related to cryptography, medicine, and space, respectively, which do not match the content of the text.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.windows.x**, **comp.graphics**: These categories are related to computer hardware and software, which match the content of the text.
#    - **misc.forsale**, **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**: These categories are related to sales, politics, and miscellaneous discussions, which do not match the content of the text.
#
# 4. **Choose the most appropriate category based on your reasoning**: Based on the content of the text, which discusses computer hardware and interfaces, the most appropriate category is **comp.sys.ibm.pc.hardware**.
#
# [comp.sys.ibm.pc.hardware]
# Nr: 13 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is the sale of Sega Genesis games, specifically John Madden Football and Ecco the Dolphin, with original boxes and manuals.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# The key terms that hint at a specific category are "Sega Genesis", "games", "sale", and "original boxes" and "manuals". These terms suggest that the text is related to buying or selling video games.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms, the topic seems to fit best with categories related to buying or selling, or video games. However, there is no specific category for video games in the list. The closest categories are "misc.forsale" (which is a general category for items for sale) and "rec.sport.hockey" and "rec.sport.baseball" (which are categories for sports, but not directly related to video games).
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category is "misc.forsale" since the text is about selling items (Sega Genesis games) and the category is a general one for items for sale.
#
# [ misc.forsale ]
# Nr: 14 Predicted label: Let's analyze the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text appears to be a recommendation for someone named Michael to read something, possibly a book or article, and a discussion about faith and being a disciple.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms and phrases that stand out are "faith", "disciple", and "lifechanging", which suggest a religious or spiritual theme.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to fit best with categories related to religion or spirituality.
#
# 4. Choose the most appropriate category based on your reasoning:
# After comparing the topic to the definitions of each category, I believe the most appropriate category is [soc.religion.christian], as the language and themes used in the text are consistent with Christian religious discussions.
#
# [ soc.religion.christian ]
# Nr: 15 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text discusses the concept of rejecting God and leaving Islam, specifically referencing the case of Salman Rushdie and the legal implications of apostasy in Islam.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "rejecting God," "leaving Islam," "atheism," and "apostasy." These terms are closely related to religious discussions, particularly those involving Islam and atheism.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **soc.religion.christian**: This category is focused on Christianity, which doesn't directly relate to the content of the text.
#    - **alt.atheism**: This category is about atheism, which is mentioned in the text. However, the primary focus is on the context of Islam and apostasy, not atheism in general.
#    - **talk.religion.misc**: This category is for miscellaneous discussions about religion. Given that the text discusses a specific religious topic (apostasy in Islam) and involves a comparison with atheism, this category seems relevant.
#    - **talk.politics.mideast**: While the text does touch on a topic related to the Middle East (Islam), its focus is more on the religious aspect than on politics.
#
# 4. **Choose the most appropriate category based on your reasoning**: Considering the above points, the text best fits into the **talk.religion.misc** category because it involves a discussion about religious topics (Islam and atheism) without being specifically about Christianity or Middle Eastern politics.
#
# [talk.religion.misc]
# Nr: 16 Predicted label: Let's analyze the text step by step.
#
# 1. Summarize the main topic of the text:
# The main topic of the text is about finding software that can convert CorelDraw (CDR) files containing bitmaps to a specific format (SCODAL) that is recognized by bureaus and film recorders.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms and phrases that hint at a specific category are "CorelDraw", "CDR files", "bitmaps", "SCODAL format", "bureaus", and "filmrecorder". These terms are related to computer graphics and printing.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to fit best with categories related to computer graphics, printing, or software.
#
# 4. Choose the most appropriate category based on your reasoning:
# After comparing the topic to the definitions of each category, I think the most appropriate category is [comp.graphics].
#
# This category is a good fit because it deals with computer graphics, which is the main topic of the text. The text is asking about software that can convert graphics files, which is a common topic in the comp.graphics category.
# Nr: 17 Predicted label: Let's analyze the text step by step:
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be a discussion about the need to take action against individuals or groups that are perceived as threatening liberty and the economy. The author seems to be advocating for the removal of these "bums" and suggests that if they do not cease their "relentless encroachment," the masses will eventually react.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out in the text include "throw bums," "liberty," "despoilment economy," "war zone," "war on drugs," and "US Constitution." These terms suggest a discussion about politics, government, and social issues.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases identified, the topic appears to be most closely related to categories that deal with politics, government, and social issues. The categories that seem most relevant are:
#
# * talk.politics.misc
# * talk.politics.guns
# * talk.politics.mideast
#
# However, upon closer examination, the text does not appear to be specifically focused on guns or Middle Eastern politics. Therefore, the most relevant category seems to be talk.politics.misc.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for the text is [talk.politics.misc].
# Nr: 18 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about Japanese baseball league stats, specifically mentioning teams like the Yakult Swallows, Hanshin Tigers, and others. It also mentions a game and standings, indicating a discussion about baseball.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "Japanese league stats," "Yakult Swallows," "Hanshin Tigers," "Central League standing," and "Boston Red Sox." These terms are all related to baseball.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**: This category is about hockey, which doesn't match our text.
#    - **soc.religion.christian**: This category is about Christianity, which doesn't match our text.
#    - **rec.sport.baseball**: This category is about baseball, which matches our text perfectly.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given that the text is entirely about baseball, discussing teams, games, and league standings, the most appropriate category is clearly related to baseball.
#
# [rec.sport.baseball]
# Nr: 19 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text:**
#    The main topic revolves around the use of taggants in explosives to aid in investigations, specifically referencing the World Trade Center bombing. The discussion involves the effectiveness, feasibility, and challenges of implementing taggants, as well as the stance of organizations like the NRA and ATF on the matter.
#
# 2. **Identify any key terms or phrases that hint at a specific category:**
#    Key terms include "taggants," "explosives," "World Trade Center bombing," "NRA," "ATF," and "investigators." These terms are closely related to firearms, explosives, and law enforcement, which are often discussed in the context of politics and gun control.
#
# 3. **Compare the topic to the definitions of each category:**
#    - **rec.sport.hockey**, **rec.sport.baseball**, **sci.space**, **sci.electronics**, and **comp.graphics** are unrelated to the topic of explosives and gun control.
#    - **soc.religion.christian** and **alt.atheism** are focused on religious discussions, which is not relevant here.
#    - **sci.med** deals with medical topics, not applicable in this context.
#    - **talk.religion.misc** and **talk.politics.misc** could be considered, but the topic is more specific to gun control and explosives.
#    - **talk.politics.guns** directly relates to discussions about firearms, gun control, and related policies, making it a strong candidate.
#    - **talk.politics.mideast** focuses on Middle Eastern politics, which is not the primary focus of the text.
#
# 4. **Choose the most appropriate category based on your reasoning:**
#    Given the focus on explosives, the NRA, the ATF, and the implications for gun control and investigation, the most appropriate category for the text is **talk.politics.guns**.
#
# [talk.politics.guns]
# Nr: 20 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about repairing a broken zipper on a jacket or a tank bag, specifically a nylon-coil type zipper. The author is sharing their experience and tips on how to fix the zipper.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out are "zipper", "jacket", "tank bag", "motorcycle" (implied by the mention of Aerostich, a well-known motorcycle gear brand), and "repair".
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to be related to motorcycles and gear repair. Let's look at the categories:
#
# * rec.motorcycles: This category is about motorcycles and related topics, including gear and repair.
# * rec.autos: This category is about cars and related topics, which doesn't seem to fit the text.
# * Other categories don't seem to fit the topic either.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for the text is [rec.motorcycles].
# Nr: 21 Predicted label: Let's analyze the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text is a discussion about batteries, specifically red batteries, and their environmental impact.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms and phrases are "batteries", "lead", "EPA", and "environmental impact". These terms are related to science, technology, and the environment.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to fit best with categories related to science, technology, and the environment. The categories that come closest are sci.med, sci.electronics, and sci.space. However, the topic is more closely related to electronics and environmental science.
#
# 4. Choose the most appropriate category based on your reasoning:
# After comparing the topic to the definitions of each category, I would choose sci.electronics as the most appropriate category. The discussion about batteries and their environmental impact is more closely related to electronics and technology.
#
# [sci.electronics]
# Nr: 22 Predicted label: Let's analyze the text step by step.
#
# 1. Summarize the main topic of the text:
# The main topic of the text appears to be a discussion about the "xcursor" version and a new option to determine the requested cursor size. This suggests that the text is related to computer software or programming.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms in the text are "xcursor", "export", "tarz", "server", and "cursor size". These terms are related to computer programming and software development.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and the topic, the most relevant categories appear to be comp.os.ms-windows.misc, comp.sys.ibm.pc.hardware, comp.sys.mac.hardware, comp.graphics, and comp.windows.x.
#
# 4. Choose the most appropriate category based on your reasoning:
# After comparing the topic to the definitions of each category, I believe that the most appropriate category is comp.windows.x. This category is related to the X Window System, which is a computer software system that provides a graphical user interface (GUI) for Unix and Unix-like operating systems. The text mentions "xcursor", which is a component of the X Window System, and discusses a new option to determine the requested cursor size, which is a feature of the X Window System.
#
# [comp.windows.x]
# Nr: 23 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be a discussion about the Israeli government's policy towards Arabs, specifically the use of tough talk and aggressive actions. The author is criticizing the Israeli government's behavior and expressing disgust at the killing of people.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out are:
#
# * "Israel government"
# * "tough talk intimidation policy"
# * "Arab leader"
# * "Jews"
# * "killing people"
# * "murder"
#
# These terms suggest a discussion about politics, specifically in the Middle East, and the relationships between different groups.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to politics, specifically in the Middle East. The categories that come closest are:
#
# * talk.politics.mideast
# * soc.religion.christian (although this category seems less relevant, as the discussion is more focused on politics than religion)
# * alt.atheism (this category seems unrelated to the topic)
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category is [talk.politics.mideast], as the discussion is focused on the Israeli government's policy towards Arabs and the relationships between different groups in the Middle East.
# Nr: 24 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text is asking if there are any other manufacturers of low radiation emission monitors besides NEC, and comparing the quality of NEC's monitors in terms of radiation emission.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# The key terms that stand out are "low radiation emission monitors", "NEC", and "quality emissionwise". These terms suggest a technical or scientific topic related to computer hardware or electronics.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms, the topic seems to fit best with categories related to computer hardware or electronics. The categories that come closest are comp.sys.ibm.pc.hardware, comp.sys.mac.hardware, and sci.electronics.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# After considering the options, I think the most appropriate category is sci.electronics, as it is a broad category that encompasses topics related to electronics and computer hardware, including monitors and radiation emission.
#
# [sci.electronics]
# Nr: 25 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text:**
#    The text discusses the differences and similarities among various types of processors (sx, dx, etc.), focusing on aspects like cache, bus, and instruction sets. It also includes a humorous anecdote about a quantum mechanic and an auto mechanic.
#
# 2. **Identify any key terms or phrases that hint at a specific category:**
#    Key terms include "processor," "cache," "bus," "internal mathematical coprocessor," "instruction set," and "quantum mechanic." These terms are related to computer hardware and technology.
#
# 3. **Compare the topic to the definitions of each category:**
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **rec.autos**, **sci.space**, **sci.med**, **soc.religion.christian**, **alt.atheism**, **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**, and **talk.religion.misc** do not match the technical and computer-related content of the text.
#    - **sci.crypt** is about cryptography, which is not the focus of the text.
#    - **comp.os.ms-windows.misc** and **comp.sys.ibm.pc.hardware** are related to computer hardware and operating systems, which aligns with the content of the text.
#    - **comp.graphics**, **comp.windows.x**, and **sci.electronics** are related to computer graphics, windowing systems, and electronics, respectively. While they are somewhat related, they do not perfectly match the focus on processor types and computer hardware in general.
#    - **comp.sys.mac.hardware** is specific to Mac hardware, which is not the focus of the text.
#    - **misc.forsale** is about items for sale, which is not relevant to the content.
#
# 4. **Choose the most appropriate category based on your reasoning:**
#    Given the focus on computer hardware, specifically processors and their characteristics, the most appropriate category seems to be **comp.sys.ibm.pc.hardware**. This category directly relates to the discussion of processor types, their differences, and their technical specifications.
#
# [comp.sys.ibm.pc.hardware]
# Nr: 26 Predicted label: Let's break down the text step by step:
#
# 1. Summarize the main topic of the text:
#
# The main topic of the text is a discussion about a hockey game, specifically the Toronto Maple Leafs (referred to as "leafs") and their upcoming game against the Philadelphia Flyers. The author, Roger Maynard, is making predictions about the game and expressing his opinions about the teams.
#
# 2. Identify any key terms or phrases that hint at a specific category:
#
# Key terms and phrases that stand out include "leafs", "Philadelphia", "hockey", "Campbell Conference", and "Bruins Cup". These terms are all related to hockey, specifically the National Hockey League (NHL).
#
# 3. Compare the topic to the definitions of each category:
#
# Based on the key terms and phrases, the topic appears to be related to hockey. The categories that seem most relevant are rec.sport.hockey and rec.sport.baseball, but since there is no mention of baseball, rec.sport.hockey is the most likely category.
#
# 4. Choose the most appropriate category based on your reasoning:
#
# Based on the analysis, the most appropriate category for the text is rec.sport.hockey.
#
# [rec.sport.hockey]
# Nr: 27 Predicted label: Let's analyze the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text is about sharing and requesting pictures of motorcycles, specifically close-ups and different angles, and discussing the archive policy for posting pictures.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# Key terms and phrases include "motorcycles", "close-ups", "different angles", "archive policy", and "picture".
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to be related to motorcycles and sharing pictures, which suggests a category related to motorcycles or hobbies.
#
# 4. Choose the most appropriate category based on your reasoning:
# After comparing the topic to the definitions of each category, the most appropriate category seems to be [rec.motorcycles], as it is the only category that directly relates to motorcycles and hobbies.
#
# [rec.motorcycles]
# Nr: 28 Predicted label: Let's analyze the text step by step:
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about techniques for defending oneself against dog attacks while cycling or motorcycling. The author shares a personal experience and mentions various methods that have been used to repel dogs, including using a tire pump and a motorcycle telephone.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases that stand out include "cycling", "motorcycling", "dog attacks", "bicycling technique", and "motorcycle telephone". These terms suggest a connection to transportation, vehicles, or outdoor activities.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to transportation or outdoor activities. The categories that come closest are rec.autos, rec.motorcycles, and rec.sport.hockey (although hockey is not directly related to the topic).
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After comparing the topic to the definitions of each category, I believe the most appropriate category is rec.motorcycles. The text mentions motorcycling and techniques for defending oneself against dog attacks while motorcycling, which aligns with the topic of motorcycles and motorcycling.
#
# [rec.motorcycles]
# Nr: 29 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about the White House seeking public pressure on GOP senators to pass a billion-dollar stimulus bill. The text mentions that the senators are being bombarded with news releases warning that certain projects may not be funded if the bill isn't passed.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out are "White House", "GOP senators", "stimulus bill", "public pressure", and "politics". These terms suggest that the text is related to politics and government.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the text seems to fit best with categories related to politics and government. Let's compare the topic to the definitions of each category:
#
# * rec.sport.hockey: No mention of hockey or sports.
# * soc.religion.christian: No mention of religion or Christianity.
# * rec.sport.baseball: No mention of baseball or sports.
# * rec.motorcycles: No mention of motorcycles.
# * sci.crypt: No mention of cryptography or science.
# * rec.autos: No mention of cars or autos.
# * sci.med: No mention of medicine or science.
# * sci.space: No mention of space or science.
# * comp.os.ms-windows.misc: No mention of computers or technology.
# * comp.sys.ibm.pc.hardware: No mention of computers or technology.
# * sci.electronics: No mention of electronics or science.
# * comp.windows.x: No mention of computers or technology.
# * comp.graphics: No mention of graphics or computers.
# * misc.forsale: No mention of sales or commerce.
# * comp.sys.mac.hardware: No mention of computers or technology.
# * talk.politics.mideast: No mention of the Middle East or international politics.
# * talk.politics.guns: No mention of guns or firearms.
# * alt.atheism: No mention of atheism or religion.
# * talk.politics.misc: **This category seems to fit best**, as the text discusses politics and government in a general sense.
# * talk.religion.misc: No mention of religion.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for the text is [talk.politics.misc].
# Nr: 30 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text:**
#    - The text discusses rumors about a new Macintosh computer, specifically mentioning a CPU and a docking station for portable PowerBooks. It also touches on the potential for Apple to obsolete current models, leading to customer complaints.
#
# 2. **Identify any key terms or phrases that hint at a specific category:**
#    - Key terms include "Macintosh," "CPU," "docking station," "PowerBook," and "Apple." These terms are related to computer hardware and technology, particularly focusing on Apple products.
#
# 3. **Compare the topic to the definitions of each category:**
#    - The categories provided range from sports and religion to computers and electronics. Given the content of the text, categories like `rec.sport.hockey`, `soc.religion.christian`, `talk.politics.mideast`, etc., do not match the topic.
#    - Categories related to computers and technology, such as `comp.sys.mac.hardware`, `comp.os.ms-windows.misc`, `sci.electronics`, etc., seem more relevant.
#
# 4. **Choose the most appropriate category based on your reasoning:**
#    - The text specifically discusses Apple products (Macintosh, PowerBook) and computer hardware (CPU, docking station), making categories related to computer hardware and Apple products the most relevant.
#    - Between `comp.sys.mac.hardware` and other computer-related categories, `comp.sys.mac.hardware` is the most specific and relevant, as it directly pertains to Macintosh hardware, which is the focus of the text.
#
# Therefore, the most appropriate category for the text is [comp.sys.mac.hardware].
# Nr: 31 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is the proposal of creating a new newsgroup for discussing the effects of long-term space missions on humans.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# The key terms and phrases that hint at a specific category are:
#
# * "scispacemedicine"
# * "long term missions space affects humans"
# * "new newsgroup"
#
# These terms suggest that the text is related to space and medicine.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, we can compare the topic to the definitions of each category:
#
# * rec.sport.hockey: Not related to space or medicine.
# * soc.religion.christian: Not related to space or medicine.
# * rec.sport.baseball: Not related to space or medicine.
# * rec.motorcycles: Not related to space or medicine.
# * sci.crypt: Not related to space or medicine.
# * rec.autos: Not related to space or medicine.
# * sci.med: Related to medicine, but not specifically to space.
# * sci.space: Related to space, and the text mentions the effects of space on humans, which is a medical aspect.
# * comp.os.ms-windows.misc: Not related to space or medicine.
# * comp.sys.ibm.pc.hardware: Not related to space or medicine.
# * sci.electronics: Not related to space or medicine.
# * comp.windows.x: Not related to space or medicine.
# * comp.graphics: Not related to space or medicine.
# * misc.forsale: Not related to space or medicine.
# * comp.sys.mac.hardware: Not related to space or medicine.
# * talk.politics.mideast: Not related to space or medicine.
# * talk.politics.guns: Not related to space or medicine.
# * alt.atheism: Not related to space or medicine.
# * talk.politics.misc: Not related to space or medicine.
# * talk.religion.misc: Not related to space or medicine.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for the text is [sci.space], as it is related to space and the effects of space on humans, which is a medical aspect.
#
# However, it's worth noting that the text also mentions medicine, so [sci.med] could be a secondary category. But based on the primary focus of the text, [sci.space] is the most appropriate category.
# Nr: 32 Predicted label: Let's break down the text and determine the most appropriate category.
#
# **Step 1: Summarize the main topic of the text.**
#
# The text appears to be a comprehensive overview of planetary probes, including their historical missions, objectives, and achievements. It covers various space agencies, such as NASA, the Soviet Union, and Japan, and their respective missions to explore the solar system.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# ...
# * "client-server application"
#
# These terms suggest a technical or computing-related topic.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to computing, software, or technology.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After reviewing the categories, I think the most appropriate category is [comp.os.ms-windows.misc] or [comp.windows.x]. However, since the text mentions "X-Windows" and "Unix" more prominently, I would lean towards [comp.windows.x].
#
# So, the final category is [comp.windows.x].
# Nr: 740 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be a discussion about the handling of the Branch Davidian siege by the FBI and the government. The author is questioning the official narrative and suggesting that the government may have been responsible for the fire that occurred during the siege.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out include "FBI", "government", "Branch Davidian siege", "conspiracy theories", and "authority worshiper". These terms suggest a discussion about politics, government, and potentially controversial or sensitive topics.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic appears to be most closely related to categories such as "talk.politics.guns", "talk.politics.mideast", or "talk.politics.misc". However, the topic does not seem to be directly related to the Middle East or guns, so "talk.politics.misc" may be the most appropriate category.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After considering the topic and key terms, I believe the most appropriate category is [talk.politics.misc]. This category seems to be the best fit because the discussion is focused on a political topic (the Branch Davidian siege) and involves questioning the government's actions and motives.
#
# [talk.politics.misc]
# Nr: 741 Predicted label: Let's break down the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text appears to be hockey, specifically the Montreal Canadiens team and their chances of winning the cup.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# Key terms and phrases include "hockey", "Montreal Canadiens", "cup", and "teamwork". These terms are closely related to the sport of hockey.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to fit best with the category related to hockey.
#
# 4. Choose the most appropriate category based on your reasoning:
# Given the focus on hockey and the Montreal Canadiens team, the most appropriate category appears to be rec.sport.hockey.
#
# [rec.sport.hockey]
# Nr: 742 Predicted label: Let's analyze the text step by step:
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be a discussion about the Israeli-Palestinian conflict, specifically the use of civilians as human shields by guerillas and the Israeli government's response to these attacks.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases that stand out include "guerillas", "Israel", "Palestinians", "Lebanon", "border security", "attacks", and "peace talks". These terms suggest a discussion about politics, conflict, and international relations.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to politics, international relations, and conflict. The categories that come closest to matching this topic are:
#
# * talk.politics.mideast
# * talk.politics.misc
# * soc.religion.christian (although this category seems less relevant, as the discussion is more focused on politics and conflict than on religion)
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After considering the key terms and phrases, I believe the most appropriate category for this text is [talk.politics.mideast]. This category is specifically focused on discussions about politics and international relations in the Middle East, which aligns closely with the topic of the text.
# Nr: 743 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is the author's reaction to the behavior of the German audience during a World Cup game between Germany and the Czech Republic. The author is criticizing the audience's behavior, specifically their throwing of coins and trash onto the rink, and is drawing a connection between this behavior and a broader attitude of aggression and intolerance among Germans.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out in the text include "World Cup", "Germany", "Czechs", "hockey", "soccer", "sports", and "Nazi attitude". These terms suggest that the text is related to sports, specifically hockey or soccer, and that it involves a discussion of national identity and behavior.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases identified in Step 2, the text appears to be most closely related to the categories "rec.sport.hockey" and "talk.politics.mideast". However, upon closer inspection, it becomes clear that the text is primarily focused on a sports-related topic, rather than a political or religious one.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis above, the most appropriate category for this text is [rec.sport.hockey]. The text is primarily focused on a hockey game and the behavior of the audience, and it does not appear to involve a significant discussion of politics, religion, or other topics that might be more relevant to other categories.
# Nr: 744 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text:**
#    The main topic revolves around a discussion on whether to trust a "blackbox" NSA system for security over an open system, considering factors like government motivations, professionalism, and the need for secure communication to protect competitive bid information from commercial competitors and foreign governments.
#
# 2. **Identify any key terms or phrases that hint at a specific category:**
#    Key terms and phrases include "NSA," "blackbox," "secure," "government," "competitive bid information," and "foreign governments." These terms hint at a discussion related to security, government, and possibly cryptography or computer security.
#
# 3. **Compare the topic to the definitions of each category:**
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **rec.autos**: These categories are related to sports and vehicles, which do not match the content of the text.
#    - **soc.religion.christian**, **alt.atheism**, **talk.religion.misc**: These categories are related to religion and atheism, which do not align with the text's focus on security and government.
#    - **sci.med**: This category is related to medical science, which is not relevant to the text.
#    - **sci.space**: This category is related to space exploration, which does not match the text's content.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.windows.x**, **comp.graphics**: While these categories are related to computer systems and software, they do not specifically focus on security or cryptography.
#    - **sci.crypt**: This category is directly related to cryptography and security, which aligns with the discussion about secure systems, the NSA, and protecting information from unauthorized access.
#    - **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**: These categories are related to politics, but they do not specifically focus on the aspects of security and cryptography discussed in the text.
#
# 4. **Choose the most appropriate category based on your reasoning:**
#    Given the focus on security, the NSA, and protecting information, the most appropriate category for the text is **sci.crypt**, as it directly deals with cryptography and security.
#
# [sci.crypt]
# Nr: 745 Predicted label: Let's break down the text step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about alphanumeric pagers, specifically about decoding paging data and sending it to a device through an RS port.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: The key terms and phrases in the text are "alphanumeric pagers", "paging transmitter", "RS port", "baud rate", "radio receiver", and "paging tower". These terms suggest a technical or electronics-related topic.
#
# 3. **Compare the topic to the definitions of each category**: Based on the key terms and phrases, the topic seems to fit best with categories related to electronics, technology, or computing.
#
# 4. **Choose the most appropriate category based on your reasoning**: After comparing the topic to the definitions of each category, the most appropriate category seems to be [sci.electronics], as it deals with the technical aspects of alphanumeric pagers and decoding paging data.
#
# [sci.electronics]
# Nr: 746 Predicted label: To determine the most appropriate category for the given text, let's analyze it step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about nominating a product, specifically Maxima chain wax, as an official product of choice for the Department of Defense (DOD).
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "Maxima chain wax," "official DOD product," and "ERC FAQ." These terms suggest a context related to motorcycles or biking, as chain wax is a product used for maintaining motorcycle chains.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **sci.space**, **sci.med**, **sci.electronics**, **sci.crypt**, **soc.religion.christian**, **alt.atheism**, **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**, **talk.religion.misc**, **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.windows.x**, **comp.graphics**, and **misc.forsale** do not directly relate to the context of motorcycle maintenance or biking.
#    - **rec.motorcycles** directly relates to the topic as it involves a product (chain wax) used for motorcycle maintenance.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the context of the text, which involves a product used for motorcycle maintenance, the most appropriate category is **rec.motorcycles**.
#
# [rec.motorcycles]
# Nr: 747 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about a project involving solar sails, specifically a small-scale solar sail proposed for a student space project. The text discusses the concept of solar sails, their potential benefits, and the challenges of designing and controlling them. It also mentions a specific project idea, including the use of microelectronics, a tiny sail, and a low-cost mission to explore the solar system.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out are:
#
# * "solar sails"
# * "space science"
# * "spacecraft"
# * "space project"
# * "microelectronics"
# * "space exploration"
#
# These terms suggest a connection to space-related topics.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to space or science. Let's compare it to the available categories:
#
# * rec.sport.hockey: No connection to sports or hockey.
# * soc.religion.christian: No connection to religion or Christianity.
# * rec.sport.baseball: No connection to sports or baseball.
# * rec.motorcycles: No connection to motorcycles.
# * sci.crypt: No connection to cryptography.
# * rec.autos: No connection to automobiles.
# * sci.med: No connection to medicine.
# * sci.space: **This category seems to be a good fit**, as it deals with space-related topics, including space exploration and spacecraft.
# * comp.os.ms-windows.misc: No connection to computer operating systems or software.
# * comp.sys.ibm.pc.hardware: No connection to computer hardware.
# * sci.electronics: While there is a mention of microelectronics, the topic is not primarily about electronics.
# * comp.windows.x: No connection to computer graphics or windowing systems.
# * comp.graphics: No connection to computer graphics.
# * misc.forsale: No connection to sales or commerce.
# * comp.sys.mac.hardware: No connection to computer hardware.
# * talk.politics.mideast: No connection to politics or the Middle East.
# * talk.politics.guns: No connection to politics or firearms.
# * alt.atheism: No connection to atheism or religion.
# * talk.politics.misc: No connection to politics.
# * talk.religion.misc: No connection to religion.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for this text is [sci.space].
# Nr: 748 Predicted label: Let's break down the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text appears to be a discussion about a "cripple chip" standard and its potential impact on the high-tech market. The tone is informal and includes personal opinions and insults.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# Key terms and phrases include "flaming libertarian", "paranoid extremist", "cripple chip standard", and "high-tech market". These terms suggest a discussion about technology, politics, and social issues.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms and phrases, the topic seems to fit into categories related to technology, politics, and social issues. The categories that come closest are:
#
# * sci.crypt ( cryptography and security)
# * talk.politics.misc (miscellaneous politics)
# * comp.os.ms-windows.misc (Microsoft Windows miscellaneous)
#
# However, the tone and language used in the text suggest that it is more focused on the social and political implications of technology rather than the technical aspects of cryptography or Microsoft Windows.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# Based on the analysis, the most appropriate category for this text is [talk.politics.misc]. The text discusses the social and political implications of a technological issue (the "cripple chip" standard) and includes personal opinions and insults, which is consistent with the tone and style of discussions in the talk.politics.misc category.
# Zaktualizowano plik: ./results/cot_random_samples_cohere_temp0.3/llama3/20_newsgroups_llama3_cot_random_samples_cohere_llama3_random42_80_temp0.3_exp3.csv
# Failed to multipart ingest runs: Connection error caused failure to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. The content length of 414194747 bytes exceeds the maximum size limit of 20971520 bytes. ConnectionError(MaxRetryError("HTTPSConnectionPool(host='api.smith.langchain.com', port=443): Max retries exceeded with url: /runs/multipart (Caused by ProtocolError('Connection aborted.', TimeoutError('The write operation timed out')))"))
# Content-Length: 414194747
# API Key: lsv2_********************************************7etrace=bf29da55-990b-4a7c-967b-8f2c7af58510,id=bf29da55-990b-4a7c-967b-8f2c7af58510

# %%
output_path
# Out:
# './results/cot_random_samples_cohere_temp0.3/llama3/20_newsgroups_llama3_cot_random_samples_cohere_llama3_random42_80_temp0.3_exp3.csv'

# %%
df_combined
# Out:
#                                                    text  \
# 0     article ashish arora writes excerpts netnewssc...
# 1     gateway telepath modem month actually one woul...
# 2     anybody provide advice concerning following tw...
# 3     article mike silverman writes anybody know goi...
# 4     article stich christian e writes installed mot...
# ...                                                 ...
# 2019  david sternlight writes article karl barrus wr...
# 2020  hello im looking information alphanumeric page...
# 2021  john r daker writes would like offocially nomi...
# 2022  article writes looking information concerning ...
# 2023  steve brinich writes flaming libertarian paran...
#
#                                                  output  \
# 0     Let's analyze the text step by step.\n\n**Step...
# 1     Let's analyze the text step by step:\n\n1. Sum...
# 2     To determine the most appropriate category for...
# 3     Let's analyze the text step by step:\n\n1. Sum...
# 4     Let's break down the text step by step to dete...
# ...                                                 ...
# 2019  To determine the most appropriate category for...
# 2020  Let's break down the text step by step:\n\n1. ...
# 2021  To determine the most appropriate category for...
# 2022  Let's analyze the text step by step.\n\n**Step...
# 2023  Let's break down the text step by step.\n\n**S...
#
#                                                logprobs  \
# 0     {'content': [{'token': 'Let', 'bytes': [76, 10...
# 1     {'content': [{'token': 'Let', 'bytes': [76, 10...
# 2     {'content': [{'token': 'To', 'bytes': [84, 111...
# 3     {'content': [{'token': 'Let', 'bytes': [76, 10...
# 4     {'content': [{'token': 'Let', 'bytes': [76, 10...
# ...                                                 ...
# 2019  {'content': [{'token': 'To', 'bytes': [84, 111...
# 2020  {'content': [{'token': 'Let', 'bytes': [76, 10...
# 2021  {'content': [{'token': 'To', 'bytes': [84, 111...
# 2022  {'content': [{'token': 'Let', 'bytes': [76, 10...
# 2023  {'content': [{'token': 'Let', 'bytes': [76, 10...
#
#                                            top_logprobs  \
# 0     [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 1     [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 2     [{'token': 'To', 'bytes': [84, 111], 'logprob'...
# 3     [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 4     [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# ...                                                 ...
# 2019  [{'token': 'To', 'bytes': [84, 111], 'logprob'...
# 2020  [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 2021  [{'token': 'To', 'bytes': [84, 111], 'logprob'...
# 2022  [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 2023  [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
#
#                 original_label  original_index was_in_selected_samples  \
# 0           talk.politics.misc               0                     NaN
# 1     comp.sys.ibm.pc.hardware               1                     NaN
# 2                      sci.med               2                     NaN
# 3           rec.sport.baseball               3                     NaN
# 4              sci.electronics               4                     NaN
# ...                        ...             ...                     ...
# 2019                 sci.crypt            1995                   False
# 2020           sci.electronics            1996                   False
# 2021           rec.motorcycles            1997                   False
# 2022                 sci.space            1998                   False
# 2023                 sci.crypt            1999                   False
#
#          extracted_label
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 2019           sci.crypt
# 2020     sci.electronics
# 2021     rec.motorcycles
# 2022           sci.space
# 2023  talk.politics.misc
#
# [2000 rows x 8 columns]
