# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from utils import evaluate_predictions_from_folders

# %%
folder_paths = [f'results/entropy_temp0/cohere', f'results/entropy_temp0/llama3', f'results/entropy_temp0/gpt4omini']

# folder_paths = [f'results/entropy_temp0/gpt4omini']

# %%
df = evaluate_predictions_from_folders(folder_paths, True, 'original_label', 'output' )
df.sort_values(by='file')
# Out:
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                                                  file  accuracy  f1_score  \
# 0   20_newsgroups_cohere_entropy_cohere_entropy_80...  0.476562  0.321957
# 16  20_newsgroups_gpt4omini_entropy_gpt4omini_entr...  0.718016  0.688805
# 7   20_newsgroups_llama3_entropy_llama3_entropy_80...  0.731771  0.636999
# 1   ag_news_cohere_entropy_cohere_entropy_80_temp0...  0.847826  0.836042
# 14  ag_news_gpt4omini_entropy_gpt4omini_entropy_80...  0.886957  0.881770
# 10  ag_news_llama3_entropy_llama3_entropy_80_temp0...  0.911957  0.909090
# 3   go_emotions_cohere_entropy_cohere_entropy_96_t...  0.332785  0.196592
# 13  go_emotions_gpt4omini_entropy_gpt4omini_entrop...  0.358553  0.360885
# 8   go_emotions_llama3_entropy_llama3_entropy_96_t...  0.339364  0.205765
# 4   social_media_cohere_entropy_cohere_entropy_60_...  0.435259  0.442741
# 17  social_media_gpt4omini_entropy_gpt4omini_entro...  0.414000  0.410759
# 12  social_media_gpt4omini_entropy_gpt4omini_entro...  0.414000  0.410386
# 9   social_media_llama3_entropy_llama3_entropy_60_...  0.491542  0.469075
# 5   sst5_cohere_entropy_cohere_entropy_60_temp0_ex...  0.492553  0.480748
# 15  sst5_gpt4omini_entropy_gpt4omini_entropy_60_te...  0.555319  0.554986
# 6   sst5_llama3_entropy_llama3_entropy_60_temp0_ex...  0.590426  0.583383
# 2   yahoo_cohere_entropy_cohere_entropy_60_temp0_e...  0.682979  0.406479
# 18  yahoo_gpt4omini_entropy_gpt4omini_entropy_60_t...  0.710638  0.586377
# 11  yahoo_llama3_entropy_llama3_entropy_60_temp0_e...  0.710638  0.699902
#
#       recall  precision
# 0   0.330975   0.406496
# 16  0.684235   0.718695
# 7   0.638513   0.669582
# 1   0.835977   0.862959
# 14  0.881559   0.894609
# 10  0.908804   0.911355
# 3   0.190695   0.264311
# 13  0.345617   0.440520
# 8   0.198462   0.276616
# 4   0.551067   0.524221
# 17  0.518690   0.554815
# 12  0.523048   0.555907
# 9   0.550908   0.566502
# 5   0.496049   0.524568
# 15  0.554227   0.589911
# 6   0.584706   0.609760
# 2   0.401687   0.439527
# 18  0.589670   0.599526
# 11  0.709921   0.730144

# %%
df.to_csv('acc_f1_precision_recall.csv', index=False)
