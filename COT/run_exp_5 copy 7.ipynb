# %%
import os 
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd # type: ignore

# %%
from utils import get_dataset, get_model_by_tag, get_prompt_template
from LLMAnnotator import LLMAnnotator

# %%
os.environ['OPENAI_API_KEY_CLARIN']=os.getenv("OPENAI_API_KEY_CLARIN")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

token = os.getenv("OPENAI_API_KEY_CLARIN")

# %%
import pandas as pd
import re

def extract_bracketed_word(df, read_col, write_col):
    """
    Wyodrębnia pierwszy wyraz objęty nawiasami [] z kolumny `read_col`
    i zapisuje go do kolumny `write_col`.
    
    :param df: DataFrame wejściowy
    :param read_col: Nazwa kolumny z której odczytywany jest tekst
    :param write_col: Nazwa kolumny do której zapisywany będzie wynik
    :return: DataFrame z nową kolumną
    """
    def extract_last_bracketed(text):
        matches = re.findall(r'\[([^\[\]]+?)\]', str(text))
        return matches[-1] if matches else None
    
    df[write_col] = df[read_col].apply(extract_last_bracketed)
    return df

# %%
import pandas as pd

def validate_text_column(path, df_reference):
    # Wczytaj DataFrame z pliku CSV
    df = pd.read_csv(path)
    
    # Pobierz unikalne wartości z kolumny 'text' z df_reference
    reference_texts = set(df_reference['text'].unique())
    
    # Dodaj kolumnę 'is_valid'
    df['was_in_selected_samples'] = df['text'].isin(reference_texts)
    df = extract_bracketed_word(df, 'output', 'extracted_label')
    df.to_csv(path, index=False)
    
    return df

# %%
for i in [1]:
    print('')
    print('')
    print('MUMER', i)
    print('')
    print('')
    model_tag = 'llama3'  
    dataset_tag = '20_newsgroups'
    prompt = 'cot_random_samples_cohere'
    temp = 0
    number_of_experimet = i
    selected_samples =  f'{model_tag}_random42_80'
    
    
    model = get_model_by_tag(model_tag, token, temp)  
    dataset_for_annotation = get_dataset(dataset_tag=dataset_tag)
    prompt_txt = get_prompt_template(dataset_tag, prompt)
    examples_for_prompt = pd.read_csv(f'./selected_samples/{dataset_tag}/{selected_samples}.csv')

    output_path = f'./results/{prompt}_temp{temp}/{model_tag}/{dataset_tag}_{model_tag}_{prompt}_{selected_samples}_temp{temp}_exp{number_of_experimet}.csv'
    os.makedirs(f'./results/{prompt}_temp{temp}/{model_tag}', exist_ok=True)
    
    
    text_col = "text"
    label_col = "label"
    output_col = "output"
    
    
    annotator = LLMAnnotator(
        model=model,
        dataset=dataset_for_annotation,
        examples_for_prompt=examples_for_prompt,
        prompt_template=prompt_txt,
        column_text=text_col,
        column_label=label_col,
        column_output=output_col
    )
    
    df = annotator.get_results(is_save=True, output_path=output_path)
    annotator.save_results(output_path=output_path)
    df_new = validate_text_column(output_path, examples_for_prompt)
# Out:
# MUMER 1
# /home/julita/Desktop/anote-skrpyty 19.04/LLMAnnotator.py:77: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   self.chain = LLMChain(llm=self.model, prompt=self.prompt)
# Nr: 0 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be a discussion about economics, specifically the decline of deficits and the impact of tax spending on the economy.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases that stand out include "supply side economic", "deficits", "GNP", "tax spending", and "budget". These terms are commonly associated with economics and politics.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to economics and politics. The categories that come closest are:
#
# * talk.politics.misc
# * sci.econ (not listed, but a possible related category)
#
# However, since sci.econ is not an option, we'll focus on talk.politics.misc.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for the text is [talk.politics.misc], as it deals with a discussion on economic policies and their impact on the economy, which is a topic commonly found in political discussions.
#
# [talk.politics.misc]
# Nr: 1 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be the author's experience with a modem, specifically a Gateway Telepath modem, and its connectivity issues with a DOS BBS (Bulletin Board System). The author mentions trying different software and settings to resolve the issue.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases that stand out include "modem", "DOS BBS", "connectivity issues", "software", and "settings". These terms suggest a technical or computer-related topic.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to computers, technology, or electronics. The categories that come closest are:
#
# * comp.sys.ibm.pc.hardware
# * comp.os.ms-windows.misc
# * sci.electronics
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After considering the options, I think the most appropriate category is [comp.sys.ibm.pc.hardware]. The text mentions a specific modem model (Gateway Telepath) and discusses connectivity issues with a DOS BBS, which suggests a focus on PC hardware and technical troubleshooting.
#
# So, the final category is: [comp.sys.ibm.pc.hardware]
# Nr: 2 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is the author's health concerns, specifically two issues: a Schatzki ring and a hiatal hernia causing swallowing difficulty and heartburn, and an increase in extra heartbeats (PVCs) that may be related to the esophagus problems.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases include "health problems", "Schatzki ring", "hiatal hernia", "swallowing difficulty", "heartburn", "endoscope", "dilate", "PVCs", "cardiologist", "bloodtests", and "medical procedure". These terms suggest a medical or health-related category.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to health, medicine, or medical procedures.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After comparing the topic to the definitions of each category, I conclude that the most appropriate category is [sci.med], which is related to medicine and health.
#
# [sci.med]
# Nr: 3 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text is about a baseball player, Ray Lankford, and his recent performance issues, possibly due to an injury.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# Key terms and phrases include "baseball player", "injury", "plate", "basepaths", "baserunning", "Dodgers", and "Cincy series". These terms are related to baseball.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms and phrases, the topic is most closely related to baseball. The categories that are relevant to baseball are rec.sport.baseball and rec.sport.hockey. However, hockey is not mentioned in the text, so we can rule out rec.sport.hockey.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# Based on the analysis, the most appropriate category is rec.sport.baseball.
#
# [rec.sport.baseball]
# Nr: 4 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about installing a Motorola XC RC FPU (Floating Point Unit) on an Amiga board and troubleshooting issues with the installation.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases that hint at a specific category include:
#
# * "Motorola XC RC FPU"
# * "Amiga board"
# * "FPU"
# * "CPU"
# * "Math coprocessor"
# * "Clocking FPU"
#
# These terms suggest a technical discussion about computer hardware, specifically about installing and configuring a floating-point unit on a computer board.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to computer hardware and technology.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After comparing the topic to the definitions of each category, I conclude that the most appropriate category is [comp.sys.amiga.hardware]. However, since this category is not available, the next best fit is [comp.sys.ibm.pc.hardware], but it's not the best fit because the text is talking about Amiga board, not IBM PC. Another option is [sci.electronics], but it's more general and not specific to computer hardware.
#
# Considering the options, I would choose [comp.sys.mac.hardware] is not the best fit, but it's similar to the Amiga hardware, so I would choose this one.
#
# [comp.sys.mac.hardware]
# Nr: 5 Predicted label: Let's analyze the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text is about electronic circuits and devices, specifically a device designed to disconnect an answering machine extension line.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms and phrases are "circuits", "electronic project books", "radio shack", and "electronic device". These terms suggest a category related to electronics.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to fit best with categories related to electronics. The categories that come closest are "sci.electronics" and "comp.sys.ibm.pc.hardware". However, "sci.electronics" seems more relevant as it deals with the broader topic of electronics, whereas "comp.sys.ibm.pc.hardware" is more specific to computer hardware.
#
# 4. Choose the most appropriate category based on your reasoning:
# Based on the analysis, the most appropriate category for the text is [sci.electronics].
# Nr: 6 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text is baseball, specifically discussing a player's stance and performance.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# Key terms and phrases include "big cat", "saturday game", "montreal", "rockies", "gallarraga", "stance", "curve ball", and "pitchers". These terms are all related to baseball.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms and phrases, the topic is most closely related to the category "rec.sport.baseball", which is a category for discussing baseball.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# Based on the analysis, the most appropriate category for the text is [rec.sport.baseball].
# Nr: 7 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is a discussion about ethnic cleansing, genocide, and the persecution of Jews in Europe during World War II. The author is drawing parallels between the Holocaust and the genocide of Bosnian Muslims, and criticizing the inaction of the US and other countries in the face of these atrocities.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out are "ethnic cleansing", "genocide", "Holocaust", "Bosnian Muslims", "US foreign policy", and "international relations". These terms suggest a discussion about politics, history, and international relations.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to politics, history, and international relations. The categories that come closest are:
#
# * talk.politics.mideast (but the text doesn't specifically focus on the Middle East)
# * talk.politics.misc (this category seems to be a good fit, as the text discusses international relations and politics in a general sense)
# * soc.religion.christian (but the text doesn't specifically focus on Christianity or religion)
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for this text is [talk.politics.misc], as it discusses international relations, politics, and history in a general sense.
#
# [talk.politics.misc]
# Process Process-18:
# Traceback (most recent call last):
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/julita/Desktop/anote-skrpyty 19.04/LLMAnnotator.py", line 13, in call_chain_process
#     result = chain.invoke({"text": text})
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain/chains/base.py", line 170, in invoke
#     raise e
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain/chains/base.py", line 160, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain/chains/llm.py", line 126, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain/chains/llm.py", line 138, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 755, in generate_prompt
#     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 950, in generate
#     output = self._generate_helper(
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 792, in _generate_helper
#     raise e
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 779, in _generate_helper
#     self._generate(
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/langchain_core/language_models/llms.py", line 1504, in _generate
#     else self._call(prompt, stop=stop, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/Desktop/anote-skrpyty 19.04/Amodels/Llama3_1LLM.py", line 31, in _call
#     response = requests.post(
#                ^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/api.py", line 115, in post
#     return request("post", url, data=data, json=json, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/requests/adapters.py", line 667, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 39
#      26 output_col = "output"
#      29 annotator = LLMAnnotator(
#      30     model=model,
#      31     dataset=dataset_for_annotation,
#    (...)
#      36     column_output=output_col
#      37 )
# ---> 39 df = annotator.get_results(is_save=True, output_path=output_path)
#      40 annotator.save_results(output_path=output_path)
#      41 df_new = validate_text_column(output_path, examples_for_prompt)
#
# File ~/Desktop/anote-skrpyty 19.04/LLMAnnotator.py:146, in LLMAnnotator.get_results(self, is_save, output_path)
#     143     self._build_prompt()
#     144     self._build_chain()
# --> 146     self.results = self.fetch_answer(texts, labels,max_retries=30, timeout_seconds=60, is_save= is_save, output_path = output_path)
#     147     return self.results
#     148 except Exception as e:
#
# File ~/anaconda3/envs/anote/lib/python3.12/site-packages/langsmith/run_helpers.py:614, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     612 except BaseException as e:
#     613     _on_run_end(run_container, error=e)
# --> 614     raise e
#     615 _on_run_end(run_container, outputs=function_result)
#     616 return function_result
#
# File ~/anaconda3/envs/anote/lib/python3.12/site-packages/langsmith/run_helpers.py:611, in traceable.<locals>.decorator.<locals>.wrapper(langsmith_extra, *args, **kwargs)
#     609     if not func_accepts_config:
#     610         kwargs.pop("config", None)
# --> 611     function_result = run_container["context"].run(func, *args, **kwargs)
#     612 except BaseException as e:
#     613     _on_run_end(run_container, error=e)
#
# File ~/Desktop/anote-skrpyty 19.04/LLMAnnotator.py:93, in LLMAnnotator.fetch_answer(self, texts, original_labels, max_retries, timeout_seconds, is_save, output_path)
#      91 process = multiprocessing.Process(target=call_chain_process, args=(self.chain, text, return_dict))
#      92 process.start()
# ---> 93 process.join(timeout_seconds)
#      95 if process.is_alive():
#      96     print(f"Nr: {i}, próba {attempt + 1}/{max_retries} – przekroczono timeout {timeout_seconds}s, przerywam")
#
# File ~/anaconda3/envs/anote/lib/python3.12/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/anaconda3/envs/anote/lib/python3.12/multiprocessing/popen_fork.py:40, in Popen.wait(self, timeout)
#      38 if timeout is not None:
#      39     from multiprocessing.connection import wait
# ---> 40     if not wait([self.sentinel], timeout):
#      41         return None
#      42 # This shouldn't block if wait() returned successfully.
#
# File ~/anaconda3/envs/anote/lib/python3.12/multiprocessing/connection.py:1136, in wait(object_list, timeout)
#    1133     deadline = time.monotonic() + timeout
#    1135 while True:
# -> 1136     ready = selector.select(timeout)
#    1137     if ready:
#    1138         return [key.fileobj for (key, events) in ready]
#
# File ~/anaconda3/envs/anote/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/connectionpool.py", line 536, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/site-packages/urllib3/connection.py", line 507, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/http/client.py", line 1428, in getresponse
#     response.begin()
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/http/client.py", line 331, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/http/client.py", line 292, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/ssl.py", line 1251, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/julita/anaconda3/envs/anote/lib/python3.12/ssl.py", line 1103, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
