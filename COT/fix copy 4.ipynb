# %%
import os 
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd # type: ignore

# %%
from utils import get_dataset, get_model_by_tag, get_prompt_template
from LLMAnnotator import LLMAnnotator

# %%
os.environ['OPENAI_API_KEY_CLARIN']=os.getenv("OPENAI_API_KEY_CLARIN")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

token = os.getenv("OPENAI_API_KEY_CLARIN")

# %%
import os
import pandas as pd
import re

def extract_bracketed_word(df, read_col, write_col):
    def extract_last_bracketed(text):
        matches = re.findall(r'\[([^\[\]]+?)\]', str(text))
        return matches[-1] if matches else None
    df[write_col] = df[read_col].apply(extract_last_bracketed)
    return df

def validate_text_column(df, df_reference):
    reference_texts = set(df_reference['text'].unique())
    df['was_in_selected_samples'] = df['text'].isin(reference_texts)
    df = extract_bracketed_word(df, 'output', 'extracted_label')
    return df

for i in [4]:
    print('\n\nMUMER', i, '\n\n')
    
    model_tag = 'llama3'
    dataset_tag = '20_newsgroups'
    prompt = 'cot_random_samples_cohere'
    temp = 0.3
    number_of_experimet = i
    selected_samples = f'{model_tag}_random42_80'
    model = get_model_by_tag(model_tag, token, temp)
    prompt_txt = get_prompt_template(dataset_tag, prompt)
    examples_for_prompt = pd.read_csv(f'./selected_samples/{dataset_tag}/{selected_samples}.csv')

    output_path = f'./results/{prompt}_temp{temp}/{model_tag}/{dataset_tag}_{model_tag}_{prompt}_{selected_samples}_temp{temp}_exp{number_of_experimet}.csv'
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    
    try:
        df_old = pd.read_csv(output_path)
    except FileNotFoundError:
        df_old = pd.DataFrame(columns=['text', 'label', 'output'])

    # Dodaj 'original_index', żeby móc później przywrócić kolejność
    full_dataset = get_dataset(dataset_tag=dataset_tag)
    full_dataset = full_dataset.reset_index().rename(columns={'index': 'original_index'})

    # Wczytaj stare wyniki lub stwórz pusty DataFrame
    try:
        df_old = pd.read_csv(output_path)
    except FileNotFoundError:
        df_old = pd.DataFrame(columns=['text', 'label', 'output', 'error'])
        
    df_old = validate_text_column(df_old, examples_for_prompt)
        
    # Do zaannotowania:
    # - brak tekstu w df_old
    # - lub w df_old jest 'error' niepuste dla danego textu
    if 'error' not in df_old.columns:
        df_old['error'] = None
    texts_with_errors = df_old[df_old['error'].notna() & (df_old['error'].astype(str) != '')]['text']
    texts_already_done = set(df_old['text']) - set(texts_with_errors)
    df_to_annotate = full_dataset[~full_dataset['text'].isin(texts_already_done)]

    print('Do zaannotowania:', len(df_to_annotate))


    if not df_to_annotate.empty:
        annotator = LLMAnnotator(
            model=model,
            dataset=df_to_annotate,
            examples_for_prompt=examples_for_prompt,
            prompt_template=prompt_txt,
            column_text="text",
            column_label="label",
            column_output="output"
        )
        df_new = annotator.get_results()
        df_new = validate_text_column(pd.DataFrame(df_new), examples_for_prompt)

        # Łączenie z zachowaniem indeksu
        
        df_new = df_new.merge(df_to_annotate[['text', 'original_index']], on='text', how='left')

        df_old = df_old.merge(full_dataset[['text', 'original_index']], on='text', how='left')
        
        df_combined = pd.concat([df_old, df_new], ignore_index=True)
        df_combined.drop_duplicates(subset='original_index', keep='last', inplace=True)
        df_combined.sort_values(by='original_index', inplace=True)
        
        # Usuń kolumnę 'error', jeśli wszystkie wartości są puste lub puste stringi
        if 'error' in df_combined.columns and df_combined['error'].replace('', pd.NA).isna().all():
            df_combined.drop(columns='error', inplace=True)

        df_combined.to_csv(output_path, index=False)
        print("Zaktualizowano plik:", output_path)

    else:
        print("Brak nowych przykładów do anotacji.")
# Out:
# MUMER 4
#
#
# Do zaannotowania: 749
# /home/julita/Desktop/anote-skrpyty 19.04/LLMAnnotator.py:77: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   self.chain = LLMChain(llm=self.model, prompt=self.prompt)
# Nr: 0 Predicted label: Let's analyze the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text appears to be a discussion about satellites, specifically a "dragless satellite" and its orbit.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms and phrases that stand out are "satellite", "drag", "laser geodesy", "orbital parameters", and "navigation". These terms suggest a connection to space or astronomy.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to fit best with the category related to space or astronomy.
#
# 4. Choose the most appropriate category based on your reasoning:
# After comparing the topic to the definitions of each category, I believe the most appropriate category is [sci.space].
#
# This category is the best fit because the text discusses satellites, orbital parameters, and laser geodesy, which are all topics related to space and astronomy.
# Nr: 1 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text is about Bible editions, specifically the formatting and layout of verses and chapters. The author is discussing their preference for editions that do not show verse numbers and is asking if anyone knows of an English language edition that does not include verse numbers.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# Key terms and phrases that stand out include "Bible editions", "verse numbering", "Scots NT", "Jerusalem Bible", and "study edition". These terms suggest a religious or biblical theme.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms and phrases, the topic appears to be related to religion, specifically Christianity. The categories that seem most relevant are soc.religion.christian and talk.religion.misc.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# After comparing the topic to the definitions of each category, I believe the most appropriate category is soc.religion.christian. The text is specifically discussing Bible editions and formatting, which is a topic of interest to Christians. The tone of the text is also informative and inquiring, which is consistent with the soc.religion.christian category.
#
# [soc.religion.christian]
# Nr: 2 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text discusses the digestive properties of space food sticks, specifically mentioning NASA's consideration of low-fiber and zero-residue products to minimize waste disposal difficulties in space.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "space food sticks," "NASA," "low fiber," "zero-residue products," and "waste disposal." These terms hint at a category related to space or science, possibly focusing on the practical aspects of space exploration.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, and **rec.autos** are all related to sports and vehicles, which doesn't match the content.
#    - **soc.religion.christian**, **alt.atheism**, and **talk.religion.misc** are related to religion and atheism, which also doesn't match.
#    - **sci.crypt** is about cryptography, which is not relevant.
#    - **sci.med** is about medicine and health, which touches on the digestive issues mentioned but is broader than the specific context of space exploration.
#    - **sci.space** is directly related to space and space exploration, which aligns perfectly with the content of discussing NASA's food products for space missions.
#    - Other categories like **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.graphics**, **comp.windows.x**, and **misc.forsale** are related to computers, software, and sales, which are not relevant.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on space exploration and NASA's food products, the most appropriate category is clearly related to space.
#
# [sci.space]
# Nr: 3 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be a discussion about gun control laws, the right to bear arms (RKBA), and the author's opposition to gun control measures. The author also mentions their support for the state of Idaho's pro-gun stance and criticizes the Clinton administration's views on gun control.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out in the text include:
#
# * "RKBA" (Right to Keep and Bear Arms)
# * "gun control laws"
# * "Clinton administration"
# * "Second Amendment"
# * "NRA" (National Rifle Association)
# * "concealed carry permits"
#
# These terms suggest a strong connection to the topic of gun rights and politics.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases identified, the topic of the text appears to be most closely related to the category of "talk.politics.guns". This category is focused on discussions about gun politics, gun control laws, and the right to bear arms, which aligns with the main topic of the text.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After analyzing the text and comparing it to the definitions of each category, I conclude that the most appropriate category for this text is [talk.politics.guns].
# Nr: 4 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about building a moderate wattage audio amplifier. The author is an electronic engineering student who is seeking help and guidance from the online community to build an audio amp. They have a few questions about calculating watts in audio amp circuits and are looking for suggestions on how to improve their circuit design.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out in the text are:
#
# * "electronic engineering student"
# * "build moderate wattage audio amp"
# * "audio amp circuits"
# * "watts calculated"
# * "schematic"
# * "PSPICE simulation"
# * "opamp models"
#
# These terms suggest that the text is related to electronics and engineering.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases identified, the topic of the text seems to fit best with the category of electronics and engineering. Let's compare it to the categories provided:
#
# * rec.sport.hockey: This category is related to hockey, which is not relevant to the text.
# * soc.religion.christian: This category is related to Christianity, which is not relevant to the text.
# * rec.sport.baseball: This category is related to baseball, which is not relevant to the text.
# * rec.motorcycles: This category is related to motorcycles, which is not relevant to the text.
# * sci.crypt: This category is related to cryptography, which is not relevant to the text.
# * rec.autos: This category is related to autos, which is not relevant to the text.
# * sci.med: This category is related to medicine, which is not relevant to the text.
# * sci.space: This category is related to space, which is not relevant to the text.
# * comp.os.ms-windows.misc: This category is related to Microsoft Windows, which is not relevant to the text.
# * comp.sys.ibm.pc.hardware: This category is related to IBM PC hardware, which is not relevant to the text.
# * sci.electronics: This category is related to electronics, which is relevant to the text.
# * comp.windows.x: This category is related to X Windows, which is not relevant to the text.
# * comp.graphics: This category is related to computer graphics, which is not relevant to the text.
# * misc.forsale: This category is related to items for sale, which is not relevant to the text.
# * comp.sys.mac.hardware: This category is related to Mac hardware, which is not relevant to the text.
# * talk.politics.mideast: This category is related to Middle East politics, which is not relevant to the text.
# * talk.politics.guns: This category is related to gun politics, which is not relevant to the text.
# * alt.atheism: This category is related to atheism, which is not relevant to the text.
# * talk.politics.misc: This category is related to miscellaneous politics, which is not relevant to the text.
# * talk.religion.misc: This category is related to miscellaneous religion, which is not relevant to the text.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category for the text is [sci.electronics].
# Nr: 5 Predicted label: Let's analyze the text step by step.
#
# 1. Summarize the main topic of the text:
# The main topic of the text is a discussion about non-lethal bullets, specifically rubber or plastic bullets, as a means to stop an attack. The text also touches on the topic of politics, mentioning Democrats, Republicans, and Libertarians.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# Key terms and phrases include "non-lethal bullets", "rubber bullets", "plastic bullets", "attack", "Democrats", "Republicans", and "Libertarians".
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to be related to politics and guns. The categories that come closest to this topic are "talk.politics.guns" and "talk.politics.misc".
#
# 4. Choose the most appropriate category based on your reasoning:
# After analyzing the text, I would say that the most appropriate category is "talk.politics.misc" because the text discusses politics and mentions different political parties, but it's not exclusively focused on guns. The mention of non-lethal bullets is more of a tangent to the main discussion about politics.
#
# [talk.politics.misc]
# Nr: 6 Predicted label: Let's break down the text step by step:
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text appears to be a discussion about the relationship between Muslims and Nazis, with one person accusing Muslims of helping Nazis and another person responding with anger and insults.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# Key terms and phrases that stand out include "Muslims", "Nazis", "Islam", "Jews", "Palestine", and "Israel". These terms suggest a discussion about politics, religion, and international relations.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms and phrases, the topic seems to fit best with categories related to politics, religion, and international relations.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# After considering the options, I think the most appropriate category is [talk.politics.mideast]. This category seems to fit best because the discussion is focused on the Middle East region and involves topics such as the Israeli-Palestinian conflict, Muslims, Jews, and international relations.
#
# So, the final answer is: [talk.politics.mideast]
# Nr: 7 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is the author's frustration with a stepper controller board, specifically with wiring steppers and getting transistors to work.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases include "stepper controller board", "wire steppers", "phase lines", "transistor hookup", and "npns" and "pnps" (types of transistors). These terms suggest a technical or electronics-related topic.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic appears to be related to electronics or computer hardware. The categories that seem most relevant are:
#
# * sci.electronics
# * comp.sys.ibm.pc.hardware
# * comp.sys.mac.hardware
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After comparing the topic to the definitions of each category, I believe the most appropriate category is **sci.electronics**. The text discusses a specific electronics project (a stepper controller board) and uses technical terms related to electronics (e.g. transistors, phase lines). While the other categories could be related, sci.electronics seems the most specific and relevant match.
#
# [sci.electronics]
# Nr: 8 Predicted label: Let's analyze the text step by step.
#
# 1. Summarize the main topic of the text:
# The main topic of the text is a personal anecdote about a motorcyclist who was pulled over by a cop in Canada during snowy weather.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms or phrases that hint at a specific category are "motorcyclist", "cop", "Canada", "snowy weather", and "Honda".
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to be related to motorcycles and riding experiences.
#
# 4. Choose the most appropriate category based on your reasoning:
# After comparing the topic to the definitions of each category, I believe the most appropriate category is [rec.motorcycles].
#
# This category fits best because the text is a personal anecdote about a motorcyclist's experience with a cop in Canada during snowy weather, which is a common topic of discussion in motorcycle communities.
# Nr: 9 Predicted label: Let's analyze the text step by step.
#
# 1. Summarize the main topic of the text:
# The main topic of the text is the author asking for information about obtaining a "Darwin fish" and seeking contact from someone who can provide an answer.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key term "Darwin fish" is a symbol often associated with evolution and atheism, which could hint at a category related to science, religion, or skepticism.
#
# 3. Compare the topic to the definitions of each category:
# The topic doesn't seem to fit well with categories like sports, politics, or computers. However, it could be related to science, religion, or skepticism.
#
# 4. Choose the most appropriate category based on your reasoning:
# Based on the mention of "Darwin fish," which is often associated with evolution and atheism, the most appropriate category seems to be [alt.atheism] or [talk.religion.misc]. However, since the text doesn't explicitly discuss atheism or criticize religion, [talk.religion.misc] might be a better fit.
#
# [talk.religion.misc]
# Nr: 10 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is cryptography, specifically discussing the security of the Skipjack encryption algorithm and the possibility of compromising it through brute force key search.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases include "Skipjack", "NSA", "cryptography", "brute force key search", "PGP", and "DES". These terms are related to cryptography and computer security.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic is most closely related to computer security and cryptography. The categories that seem most relevant are:
#
# * sci.crypt (science of cryptography)
# * comp.os.ms-windows.misc (computer operating systems, but not specifically related to cryptography)
# * comp.sys.ibm.pc.hardware (computer hardware, but not specifically related to cryptography)
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# Based on the analysis, the most appropriate category is sci.crypt, as it is the only category that specifically deals with cryptography and computer security.
#
# [sci.crypt]
# Nr: 11 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about using ultra-sticky labels as a deterrent for parking in a no-parking zone, specifically on car windshields. The author shares a personal anecdote about a friend who had a near-accident due to a blocked windshield and suggests that using these labels could be a humorous and effective way to prevent illegal parking.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases that stand out include "ultra-sticky labels", "parking", "car", "windshield", and "illegal parking". These terms suggest a connection to vehicles and parking, which could relate to a category about cars or transportation.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to cars or transportation. The most relevant categories appear to be rec.autos, rec.motorcycles, and talk.politics.guns (although the latter seems less likely due to the lack of any mention of guns or politics).
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After considering the options, I believe the most appropriate category for this text is rec.autos, as it deals with cars and parking, which are common topics of discussion in the rec.autos category.
#
# [rec.autos]
# Nr: 12 Predicted label: Let's analyze the text step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is a discussion about computer hardware connections, specifically balanced-line connections, IDC, and SMD interfaces, in the context of SCSI and large drives.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: The key terms and phrases that hint at a specific category are "balanced-line connections", "IDC", "SMD interface", "SCSI", and "large drives". These terms are related to computer hardware and technology.
#
# 3. **Compare the topic to the definitions of each category**: Based on the key terms and phrases, the topic seems to fit best with categories related to computer hardware and technology.
#
# 4. **Choose the most appropriate category based on your reasoning**: After comparing the topic to the definitions of each category, the most appropriate category seems to be [comp.sys.ibm.pc.hardware] or [sci.electronics]. However, since the text specifically mentions SCSI and large drives, which are more related to PC hardware, the most appropriate category is [comp.sys.ibm.pc.hardware].
#
# [comp.sys.ibm.pc.hardware]
# Nr: 13 Predicted label: Let's break down the text step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is the sale of Sega Genesis games, specifically mentioning a few titles and their prices.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: The key terms here are "Sega Genesis" and "games," which suggest a category related to video games or gaming consoles.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, and other sports categories don't fit because the topic isn't about sports.
#    - **sci.crypt**, **sci.med**, **sci.space**, and other science categories don't fit because the topic isn't about science or technology in a broad sense.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, and other computer categories don't fit because the topic isn't about computer hardware or software.
#    - **misc.forsale** seems like the most appropriate category because the text is about selling items, specifically Sega Genesis games.
#
# 4. **Choose the most appropriate category based on your reasoning**: Based on the analysis, the most appropriate category for the text is **misc.forsale** because it directly deals with the sale of items.
#
# [**misc.forsale**]
# Nr: 14 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text appears to be a recommendation for someone named Michael to read something (likely a book or article) that is described as "true" and "reasonable." The context suggests a discussion about faith or spirituality, as it mentions "dents in armor" and becoming a "disciple."
#
# 2. **Identify any key terms or phrases that hint at a specific category**: The key terms here are "faith," "disciple," and "life-changing," which strongly suggest a discussion related to religion or spirituality.
#
# 3. **Compare the topic to the definitions of each category**: Given the focus on faith and personal spiritual development, we can narrow down the categories to those related to religion or spirituality. The most relevant categories would be `soc.religion.christian`, `talk.religion.misc`, and `alt.atheism`. However, `alt.atheism` is focused on atheism, which doesn't align with the text's supportive tone towards faith.
#
# 4. **Choose the most appropriate category based on your reasoning**: Between `soc.religion.christian` and `talk.religion.misc`, the text doesn't specifically mention Christian beliefs or practices, making `talk.religion.misc` a broader and more fitting category for a general discussion about faith and spirituality.
#
# The final category is: [talk.religion.misc]
# Nr: 15 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step.
#
# 1. **Summarize the main topic of the text:**
#    The text discusses the concept of rejecting God and the implications of this rejection in the context of Islam. It mentions the legal issue of apostasy (leaving one's faith) and references the case of Salman Rushdie, an author known for his controversial writings on Islam.
#
# 2. **Identify any key terms or phrases that hint at a specific category:**
#    Key terms include "rejecting God," "Islam," "atheism," "Salman Rushdie," and "apostasy." These terms are closely related to discussions of religion, faith, and the consequences of leaving one's faith.
#
# 3. **Compare the topic to the definitions of each category:**
#    - **soc.religion.christian:** This category is focused on Christianity, which doesn't directly relate to the content of the text.
#    - **alt.atheism:** This category involves discussions about atheism, which is relevant since the text mentions "atheism" and the rejection of God.
#    - **talk.religion.misc:** This category is for miscellaneous discussions about religion, which could include topics like apostasy and the rejection of God in the context of Islam.
#    - Other categories like **rec.sport.hockey**, **sci.space**, **comp.os.ms-windows.misc**, etc., are unrelated to the content of the text.
#
# 4. **Choose the most appropriate category based on your reasoning:**
#    Given the focus on the rejection of God, atheism, and the context of Islam, the most appropriate category seems to be **talk.religion.misc**. This category is broad enough to encompass discussions about various aspects of religion, including apostasy and the specific case of rejecting God in Islam.
#
# [talk.religion.misc]
# Nr: 16 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step.
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about finding software that can convert CorelDraw (CDR) files containing bitmaps into a format (SCODAL) that bureaus' film recorders can recognize.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "software," "convert," "CorelDraw," "CDR files," "bitmaps," "SCODAL format," and "filmrecorder." These terms are related to computer graphics, file conversion, and printing or publishing processes.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **soc.religion.christian**, **rec.sport.baseball**, **talk.politics.mideast**, **alt.atheism**, and others do not match the context of the text.
#    - **comp.graphics** seems relevant because it deals with computer graphics, which includes file formats and conversion between them.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on software for converting graphic file formats, the most appropriate category is **comp.graphics**.
#
# [comp.graphics]
# Nr: 17 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text appears to be a discussion about the need to take action against individuals or groups that are perceived as a threat to liberty and the economy. The author seems to be advocating for the removal of these individuals or groups, using phrases such as "throw bums" and "despoilment of economy".
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out in the text include:
#
# * "throw bums"
# * "despoilment of economy"
# * "war zone"
# * "war on drugs"
# * "US Constitution"
#
# These terms suggest that the text is related to politics, government, and social issues.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases identified, the text appears to be most closely related to categories that deal with politics, government, and social issues.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After comparing the topic to the definitions of each category, I believe that the most appropriate category for this text is [talk.politics.misc]. This category seems to be the best fit because the text discusses general political and social issues, including the need to take action against perceived threats to liberty and the economy, and mentions specific topics such as the war on drugs and the US Constitution.
#
# [talk.politics.misc]
# Nr: 18 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text:**
#    The main topic of the text revolves around baseball, specifically discussing Japanese league stats and mentioning teams like the Yakult Swallows, Hanshin Tigers, and others. It also references a job opportunity and the Boston Red Sox, indicating a broader interest in baseball.
#
# 2. **Identify any key terms or phrases that hint at a specific category:**
#    Key terms include "Japanese league stats," "Yakult Swallows," "Hanshin Tigers," "Central League standing," and "Boston Red Sox." These terms are directly related to baseball.
#
# 3. **Compare the topic to the definitions of each category:**
#    - **rec.sport.hockey:** This category is about hockey, which doesn't match our text.
#    - **soc.religion.christian:** This category is about Christianity, which is unrelated to our text.
#    - **rec.sport.baseball:** This category is specifically about baseball, which aligns perfectly with the content of our text.
#    - Other categories like **rec.autos**, **sci.crypt**, **comp.os.ms-windows.misc**, etc., do not match the content of the text.
#
# 4. **Choose the most appropriate category based on your reasoning:**
#    Given the focus on baseball teams, leagues, and stats, the most appropriate category for the text is clearly related to baseball.
#
# [rec.sport.baseball]
# Nr: 19 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about the use of taggants in explosives to help investigators trace the source of explosives used in crimes, such as the World Trade Center bombing. The author is discussing the effectiveness of taggants and how they could be used to aid in forensic analysis.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out are:
#
# * "NRA" (National Rifle Association)
# * "ATF" (Bureau of Alcohol, Tobacco, Firearms and Explosives)
# * "explosives"
# * "taggants"
# * "World Trade Center bombing"
# * "forensic analysis"
#
# These terms suggest a connection to firearms, explosives, and law enforcement, which could be related to politics or firearms.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to be related to firearms and explosives, which could fit into the category of "talk.politics.guns". This category is focused on discussions about firearms and gun control, which aligns with the mention of the NRA and ATF in the text.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After analyzing the text, I believe the most appropriate category is [talk.politics.guns]. The text discusses the use of taggants in explosives, which is related to firearms and law enforcement, and the author mentions the NRA and ATF, which are key organizations involved in firearms policy.
# Nr: 20 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step.
#
# 1. **Summarize the main topic of the text**: The main topic of the text revolves around repairing and maintaining zippers, specifically on jackets and possibly other clothing items. The discussion includes tips, tricks, and experiences with different types of zippers and how to fix common issues.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms and phrases include "zipper," "jacket," "nylon-coil type zippers," "molded plastic teeth," "repair broken zipper," and brand names like "Aerostich" and "YKK." These terms are closely related to clothing, textiles, and possibly motorcycles or outdoor gear, given the mention of specific brands known in those contexts.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **sci.space**, **sci.med**, **sci.electronics**, **sci.crypt**, **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.graphics**, **comp.windows.x**, **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**, **talk.religion.misc**, **soc.religion.christian**, **alt.atheism**, and **misc.forsale** do not directly relate to the topic of zipper repair and maintenance.
#    - **rec.autos** and **rec.motorcycles** could be relevant due to the mention of specific brands (Aerostich) that are known in the motorcycle gear context, and the discussion about zippers could apply to jackets or gear used in these hobbies.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the context and the specific brands mentioned (like Aerostich, which is well-known for motorcycle gear), the most appropriate category seems to be **rec.motorcycles**. This is because the discussion, although focused on zipper repair, is likely set in the context of maintaining motorcycle gear, such as jackets.
#
# [rec.motorcycles]
# Nr: 21 Predicted label: Let's analyze the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text is a discussion about batteries, specifically red batteries, and their environmental impact.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms and phrases are "batteries", "lead", "EPA", and "environmental impact". These terms suggest a category related to science, technology, or the environment.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms and phrases, the topic seems to fit best with categories related to science, technology, or the environment. The categories that come closest are sci.electronics, sci.med, and sci.space. However, the topic is more closely related to electronics and environmental concerns.
#
# 4. Choose the most appropriate category based on your reasoning:
# Based on the analysis, the most appropriate category is sci.electronics, as it deals with the environmental impact of batteries, which is a topic related to electronics and technology.
#
# [sci.electronics]
# Nr: 22 Predicted label: Let's analyze the text step by step:
#
# 1. Summarize the main topic of the text:
# The main topic of the text is about an "xcursor" version and its export, specifically about a new option to determine the requested cursor size.
#
# 2. Identify any key terms or phrases that hint at a specific category:
# The key terms are "xcursor", "export", "cursor size", and "server". These terms are related to computer programming and software development.
#
# 3. Compare the topic to the definitions of each category:
# Based on the key terms, the topic seems to be related to computer programming and software development. The categories that are most relevant are comp.os.ms-windows.misc, comp.sys.ibm.pc.hardware, comp.sys.mac.hardware, comp.windows.x, and comp.graphics.
#
# 4. Choose the most appropriate category based on your reasoning:
# After comparing the topic to the definitions of each category, I think the most appropriate category is comp.windows.x, as it is related to X Window System, which is a windowing system for bitmap displays, and the text mentions "xcursor" and "server", which are terms commonly used in the X Window System.
#
# [comp.windows.x]
# Nr: 23 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text discusses the use of tough talk and aggressive actions by politicians, specifically referencing the Israeli government and its actions towards Arabs. It touches on the themes of intimidation, pride in aggressive actions, and differing opinions on the justification of such actions.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key phrases include "tough talk," "arrogance," "American politicians," "Israel government," "aggressive actions," and "Arab leader." These terms suggest a focus on politics, international relations, and possibly the Middle East.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **rec.autos**: These categories are related to sports and hobbies, which do not match the content of the text.
#    - **soc.religion.christian**, **alt.atheism**, **talk.religion.misc**: While the text mentions Israel, it does not specifically discuss religious topics but rather political actions and attitudes.
#    - **sci.crypt**, **sci.med**, **sci.electronics**, **sci.space**: These categories are related to science and technology, which do not align with the text's focus on politics and international relations.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.windows.x**, **comp.graphics**: These categories are related to computer science and technology, which are not relevant to the text's content.
#    - **misc.forsale**: This category is about items for sale, which does not match the text's topic.
#    - **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**: These categories are related to politics, with **talk.politics.mideast** specifically focusing on the Middle East. The text's discussion of the Israeli government and its actions towards Arabs makes this category the most relevant.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the text's focus on the Israeli government's actions and the political dynamics in the Middle East, the most appropriate category is **talk.politics.mideast**.
#
# [talk.politics.mideast]
# Nr: 24 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about low radiation emission monitors, specifically asking if there are other manufacturers besides NEC and comparing NEC's quality in terms of emission.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "low radiation emission monitors," "NEC," and "quality emissionwise." These terms are related to computer hardware, specifically monitors, and their safety or environmental impact.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **sci.space**, **talk.politics.mideast**, **talk.politics.guns**, **alt.atheism**, **soc.religion.christian**, **sci.med**, **talk.religion.misc**, **talk.politics.misc**: These categories are unrelated to computer hardware or monitors.
#    - **rec.autos**: While this category involves technology, it's specifically about automobiles, not computer hardware.
#    - **sci.crypt**: This category is about cryptography, which is not relevant to the topic of monitors.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.windows.x**, **comp.graphics**: These categories are related to computer hardware and software. Specifically, **comp.sys.ibm.pc.hardware** and **comp.sys.mac.hardware** deal with computer hardware, which includes monitors.
#    - **misc.forsale**: While monitors could be for sale, the text does not indicate that the monitors are being sold or sought after for purchase.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on computer monitors and their emission qualities, the most relevant categories would be **comp.sys.ibm.pc.hardware** or **comp.sys.mac.hardware**. However, since the text does not specify the type of computer (IBM PC or Mac) the monitors are for, and considering the broader scope of computer hardware beyond just IBM PC or Mac, a more general category could be considered. But among the provided options, **comp.sys.ibm.pc.hardware** is a reasonable choice because it directly involves computer hardware, which includes monitors.
#
# [comp.sys.ibm.pc.hardware]
# Nr: 25, próba 1/30 – przekroczono timeout 60s, przerywam
# Nr: 25 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text discusses the differences and similarities between various types of processors, specifically mentioning cache, bus, and instruction sets. It also includes a humorous anecdote about a quantum mechanic and an auto mechanic.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "processors," "cache," "bus," "internal mathematical coprocessor," "instruction set," "sx," "dx," and "quantum mechanic." These terms are related to computer hardware and electronics.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **soc.religion.christian**, **rec.sport.baseball**, **talk.politics.mideast**, **alt.atheism**, and **talk.religion.misc** do not match the content, as they relate to sports, religion, politics, and miscellaneous discussions, respectively.
#    - **sci.crypt** and **sci.med** are also not relevant, as they focus on cryptography and medicine, respectively.
#    - **sci.space** does not match, as it deals with space-related topics.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **sci.electronics**, **comp.windows.x**, and **comp.graphics** are all related to computer science and technology. Among these, **comp.sys.ibm.pc.hardware** seems the most relevant, as it specifically deals with IBM PC hardware, which includes processors and their specifications.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on processors and their technical specifications, the most appropriate category is **comp.sys.ibm.pc.hardware**.
#
# [comp.sys.ibm.pc.hardware]
# Nr: 26 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text discusses a prediction about a hockey game involving the Toronto Maple Leafs (referred to as "leafs") and the Philadelphia team. The author, Roger Maynard, expresses confidence in the Leafs' abilities, calling them the best team in the Campbell Conference.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "leafs," "hockey," "Toronto Maple Leafs," and "Campbell Conference." These terms are directly related to hockey, specifically the National Hockey League (NHL).
#
# 3. **Compare the topic to the definitions of each category**: The categories provided include various topics such as religion, politics, electronics, and sports. Given the context of the text, the most relevant category would be related to sports, specifically hockey.
#
# 4. **Choose the most appropriate category based on your reasoning**: Based on the presence of hockey-related terms and the discussion of a hockey game, the most appropriate category for this text is clearly related to hockey.
#
# The final category is: [rec.sport.hockey]
# Nr: 27 Predicted label: Let's analyze the text step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about sharing and requesting pictures of motorcycles, specifically close-ups and different angles. The author is also providing information on how to submit pictures and is mentioning a specific motorcycle, the Stanley ID.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms and phrases include "motorcycles", "closeups", "different angles", "picture", "archivepolicytxt", "gif", "ftp", "cerritosedu", "account", "anonymous", "password", "incoming", "binary mode", "notify mail", "mail", "uuencoded", "description", "inclusion", "aaareadmetxt", "charlie smiths pictures", "seabass", "sears", "dod", "stanley id", "motorcycle", "nice little town", "nice road", "getting", "bruce bruce tanner", "cerritos college", "norwalk", "ca", "dod", "nomad".
#
# 3. **Compare the topic to the definitions of each category**: Based on the key terms and phrases, the topic seems to be related to motorcycles and sharing pictures of them. This suggests that the category is likely to be related to motorcycles or hobbies.
#
# 4. **Choose the most appropriate category based on your reasoning**: Based on the analysis, the most appropriate category is [rec.motorcycles].
#
# So, the final category is [rec.motorcycles].
# Nr: 28 Predicted label: Let's break down the analysis step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about techniques for defending oneself against dog attacks while cycling or motorcycling. The author shares a personal experience and discusses various methods, including using a tire pump or a motorcycle telephone, to deter dogs.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Key terms and phrases that stand out include "dog attacks," "cycling," "motorcycling," "tire pump," and "motorcycle telephone." These terms suggest a connection to transportation, vehicles, or outdoor activities.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to fit best with categories related to transportation or outdoor activities. The most relevant categories appear to be rec.autos, rec.motorcycles, or possibly sci.electronics (due to the mention of a motorcycle telephone).
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After considering the options, I believe the most appropriate category is rec.motorcycles. The text mentions motorcycling and discusses techniques for defending oneself against dog attacks while motorcycling, which aligns with the topic of motorcycles and motorcycling.
#
# [rec.motorcycles]
# Nr: 29 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step.
#
# 1. **Summarize the main topic of the text**: The text discusses the White House's efforts to pressure GOP senators into passing a stimulus bill by highlighting potential projects that could be funded. It criticizes the approach as dishonest and mob rule, suggesting that the administration is using a wish list of projects not actually included in the bill to garner support.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms and phrases include "White House," "GOP senators," "stimulus bill," "public pressure," "dishonest," and "mob rule." These terms are associated with politics and government.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **sci.space**, **sci.electronics**, **sci.med**, **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.graphics**, **comp.windows.x**, **misc.forsale**, **alt.atheism**, **soc.religion.christian**, **talk.religion.misc**: These categories do not match the content of the text, which focuses on political issues rather than sports, technology, science, or religion.
#    - **talk.politics.mideast**, **talk.politics.guns**: While these categories relate to politics, they are too specific and do not match the general political discussion in the text.
#    - **talk.politics.misc**: This category is the most appropriate because the text discusses general political issues, specifically the tactics used by the White House to pass a stimulus bill, without focusing on a specific area like the Middle East or guns.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on general political issues and the absence of specific topics that would align with other categories, **talk.politics.misc** is the most fitting category.
#
# [talk.politics.misc]
# Nr: 30 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
# The main topic of the text is a discussion about a rumor of a new Macintosh computer coming in the second quarter, specifically about a CPU and a docking station for portable PowerBooks.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
# The key terms and phrases that hint at a specific category are:
# - Macintosh
# - CPU
# - PowerBook
# - Docking station
# - Apple
#
# These terms are related to computers and technology, specifically Apple products.
#
# **Step 3: Compare the topic to the definitions of each category.**
# Based on the key terms and phrases, the topic seems to fit best with categories related to computers and technology, specifically Apple products.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
# After comparing the topic to the definitions of each category, I believe the most appropriate category is [comp.sys.mac.hardware].
#
# This category is specifically related to Macintosh hardware, which aligns with the discussion about Macintosh computers, CPUs, docking stations, and Apple products in the text.
# Nr: 31 Predicted label: Let's analyze the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is the proposal to create a new newsgroup for discussing the effects of long-term space missions on humans.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# The key terms and phrases that hint at a specific category are "space", "long term missions", "affects humans", and "scispacemedicine".
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, the topic seems to be related to space and medicine. The category that best fits this topic is sci.space or sci.med.
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# ...
#
# 4. Choose the most appropriate category based on your reasoning:
#
# Based on the analysis, the most appropriate category for this text is [talk.politics.misc]. This category seems to be the best fit because the topic is a discussion about the government's actions and the author's skepticism about the official story, which is a general topic related to politics and social issues.
# Nr: 741 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text discusses the Montreal Canadiens, a hockey team, and their chances of winning the cup. It mentions teamwork, a recent slump, and the need for better performance from the goalie, Roy. There's also a mention of a longtime hockey announcer's death and a reference to the team's spirit.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "Montreal Canadiens," "hockey," "cup," "teamwork," "goalie," and "announcer." These terms are closely related to hockey, indicating that the text falls under a sports category, specifically hockey.
#
# 3. **Compare the topic to the definitions of each category**: Given the focus on hockey, we can directly compare this to categories related to sports and hockey. The categories provided include "rec.sport.hockey" and "rec.sport.baseball," among others. Since the text specifically talks about hockey and not baseball or any other sport, "rec.sport.hockey" is the most relevant category.
#
# 4. **Choose the most appropriate category based on your reasoning**: Based on the analysis, the text clearly falls under the category of hockey discussions, making "rec.sport.hockey" the most appropriate category.
#
# [rec.sport.hockey]
# Nr: 742 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text:**
#    The text revolves around a discussion on the Israeli-Palestinian conflict, specifically addressing the use of civilians as cover by guerillas, the responsibility of guerillas and the Israeli government in protecting civilians, and the challenges in peace talks between Israelis and Palestinians.
#
# 2. **Identify any key terms or phrases that hint at a specific category:**
#    Key terms include "guerillas," "Israel," "Palestinians," "peace talks," "autonomy," and "Lebanon." These terms are closely related to politics, specifically international relations and conflicts in the Middle East.
#
# 3. **Compare the topic to the definitions of each category:**
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **rec.autos**: These categories are related to sports and hobbies, which do not match the content of the text.
#    - **soc.religion.christian**, **alt.atheism**, **talk.religion.misc**: While religion might be tangentially related to the conflict discussed, the text does not primarily focus on religious topics.
#    - **sci.crypt**, **sci.electronics**, **sci.med**, **sci.space**: These categories are related to science and technology, which are not relevant to the discussion in the text.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**, **comp.windows.x**, **comp.graphics**: These categories are related to computer science and technology, which do not align with the content of the text.
#    - **misc.forsale**: This category is related to items for sale, which is not relevant to the text.
#    - **talk.politics.mideast**: This category specifically deals with discussions on Middle East politics, which aligns closely with the content of the text.
#
# 4. **Choose the most appropriate category based on your reasoning:**
#    Given the focus on the Israeli-Palestinian conflict, the use of civilians as cover by guerillas, and the challenges in peace talks, the most appropriate category for the text is clearly related to Middle East politics.
#
# [talk.politics.mideast]
# Nr: 743 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The text discusses the behavior of the German audience during a hockey game between Germany and the Czech Republic. The author expresses astonishment and disapproval of the crowd's behavior, specifically mentioning the throwing of coins and trash onto the rink, and makes a broader commentary on what they perceive as a negative attitude among German fans in various sports.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "hockey," "German audience," "behavior," "sports," and "WC" (which likely refers to the World Cup, a major international sporting event). These terms suggest a connection to sports, specifically hockey, and the behavior of fans.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**: This category is directly related to hockey, which is the sport being discussed in the text. The discussion about the behavior of the German audience during a hockey game fits well within this category.
#    - Other categories like **talk.politics.misc**, **soc.religion.christian**, **sci.med**, etc., do not directly relate to the content of the text, which focuses on sports and fan behavior.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on hockey and the discussion of fan behavior during a hockey game, the most appropriate category for this text is **rec.sport.hockey**.
#
# [rec.sport.hockey]
# Nr: 744 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text:**
#    The text revolves around a discussion on whether to trust a "black box" system provided by the NSA (National Security Agency) for security, or to opt for an open system from elsewhere. The context suggests concerns about the security and confidentiality of information, particularly in a competitive or governmental setting.
#
# 2. **Identify any key terms or phrases that hint at a specific category:**
#    Key terms include "black box," "NSA," "secure," "government," "competitive bid information," and "foreign governments." These terms are closely related to security, confidentiality, and governmental or competitive interests.
#
# 3. **Compare the topic to the definitions of each category:**
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **rec.autos**: These categories are related to sports and hobbies, which do not match the content of the text.
#    - **soc.religion.christian**, **alt.atheism**, **talk.religion.misc**: These categories focus on religious discussions, which are not relevant to the text.
#    - **sci.med**: This category is about medical science, which does not align with the text's content.
#    - **sci.space**: This category deals with space and astronomy, not related to the text.
#    - **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.sys.mac.hardware**: While these categories are related to computer hardware and software, they do not specifically address security or cryptographic issues.
#    - **comp.graphics**: This category is about computer graphics, which is not relevant.
#    - **comp.windows.x**: This category deals with the X Window System, not directly related to the security concerns discussed.
#    - **sci.electronics**: This category is about electronics, which might seem relevant but does not specifically address the security and cryptographic aspects discussed.
#    - **sci.crypt**: This category is about cryptography and security, which aligns closely with the discussion about trusting a "black box" system for security and the mention of the NSA.
#    - **talk.politics.mideast**, **talk.politics.guns**, **talk.politics.misc**: While these categories deal with political discussions, they do not specifically focus on security or cryptographic issues in the context of governmental or competitive interests.
#    - **misc.forsale**: This category is about items for sale, which is not relevant.
#
# 4. **Choose the most appropriate category based on your reasoning:**
#    Given the focus on security, the NSA, and the discussion about trusting a system for confidentiality and security, the most appropriate category is **sci.crypt**.
#
# [sci.crypt]
# Nr: 745 Predicted label: Let's analyze the text step by step:
#
# 1. **Summarize the main topic of the text**: The main topic of the text is about alphanumeric pagers, specifically about decoding paging data and building a device to receive and decode paging messages.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms and phrases include "alphanumeric pagers", "paging transmitter", "RS port", "baud rate", "radio receiver", and "paging tower". These terms suggest a technical or electronics-related topic.
#
# 3. **Compare the topic to the definitions of each category**: Based on the key terms and phrases, the topic seems to fit best with categories related to electronics, technology, or computing.
#
# 4. **Choose the most appropriate category based on your reasoning**: After comparing the topic to the definitions of each category, the most appropriate category seems to be **sci.electronics**, as it deals with electronic devices, communication systems, and technical details related to pagers and radio receivers.
#
# [sci.electronics]
# Nr: 746 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step.
#
# 1. **Summarize the main topic of the text**: The text is about nominating a product, specifically "maxima chain wax," as an official product of choice for the "dod" (likely referring to a cycling or motorcycle group, given the context of chain wax).
#
# 2. **Identify any key terms or phrases that hint at a specific category**: The key terms here are "maxima chain wax" and "dod product choice." These terms suggest a connection to motorcycles or bicycles, as chain wax is a product used for maintaining chains in these vehicles.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**: This category is about hockey, which doesn't match the content of the text.
#    - **soc.religion.christian**: This category is about Christianity, which also doesn't match.
#    - **rec.sport.baseball**: This category is about baseball, again not matching the content.
#    - **rec.motorcycles**: This category is about motorcycles, which aligns with the mention of chain wax, a product used in motorcycle maintenance.
#    - Other categories like **sci.crypt**, **rec.autos**, **sci.med**, etc., do not match the content of the text.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the mention of chain wax and its relevance to motorcycles, the most appropriate category for the text is **rec.motorcycles**.
#
# [rec.motorcycles]
# Nr: 747 Predicted label: Let's break down the text step by step.
#
# **Step 1: Summarize the main topic of the text.**
#
# The main topic of the text is about a project involving solar sails, specifically a small-scale solar sail proposed for a student space project. The text discusses the concept of solar sails, their potential benefits, and the challenges of designing and controlling them.
#
# **Step 2: Identify any key terms or phrases that hint at a specific category.**
#
# Some key terms and phrases that stand out are:
#
# * "solar sails"
# * "spacecraft"
# * "space science dept"
# * "student space project"
# * "space project"
# * "spacecraft design"
# * "space exploration"
#
# These terms suggest a connection to space-related topics.
#
# **Step 3: Compare the topic to the definitions of each category.**
#
# Based on the key terms and phrases, we can rule out categories that are unrelated to space or science. The categories that seem most relevant are:
#
# * sci.space
# * sci.electronics
# * comp.os.ms-windows.misc (although this one seems less likely)
#
# **Step 4: Choose the most appropriate category based on your reasoning.**
#
# After comparing the topic to the definitions of each category, I believe the most appropriate category is [sci.space]. The text is primarily focused on a space-related project, and the discussion of solar sails, spacecraft design, and space exploration aligns well with the sci.space category.
#
# Therefore, the final answer is: [sci.space]
# Nr: 748 Predicted label: To determine the most appropriate category for the given text, let's break down the process step by step:
#
# 1. **Summarize the main topic of the text**: The main topic appears to be a discussion or criticism of an idea related to a "cripple chip standard" in the context of US manufacturers and high-tech markets. The tone is argumentative and critical.
#
# 2. **Identify any key terms or phrases that hint at a specific category**: Key terms include "libertarian," "paranoid extremist," "cripple chip standard," "US manufacturers," and "high-tech market." These terms suggest a discussion that involves politics, technology, and possibly economics.
#
# 3. **Compare the topic to the definitions of each category**:
#    - **rec.sport.hockey**, **rec.sport.baseball**, **rec.motorcycles**, **sci.space**, **sci.med**, **sci.electronics**, **comp.os.ms-windows.misc**, **comp.sys.ibm.pc.hardware**, **comp.graphics**, **comp.windows.x**, **misc.forsale**, **comp.sys.mac.hardware**, **talk.politics.mideast**, **talk.politics.guns**, **alt.atheism**, **talk.religion.misc**, **soc.religion.christian**, **sci.crypt**, **rec.autos**, and **talk.politics.misc**.
#
#    The discussion seems to touch on themes of technology ("cripple chip standard"), politics or social issues ("libertarian," "paranoid extremist"), and possibly economics ("high-tech market"). It does not fit well with sports, space, medicine, electronics, computer hardware or software, graphics, or religion. The mention of a "cripple chip standard" and its implications for the market suggests a topic that could be related to cryptography or security, but it's more broadly about technology policy and its implications.
#
# 4. **Choose the most appropriate category based on your reasoning**: Given the focus on a technological issue with political and economic implications, the best fit seems to be a category that deals with the intersection of technology and policy or politics. While **sci.crypt** could be a consideration due to the mention of a "cripple chip standard," which might imply some form of cryptographic or security-related technology, the broader context of the discussion suggests it's more about the policy and political implications of such technology rather than the cryptographic aspects themselves.
#
# Considering the options, **talk.politics.misc** seems the most appropriate category because it encompasses discussions on various political topics, including those related to technology policy and its implications for society and the economy. The discussion does not fit neatly into the more specialized categories like **sci.crypt** or **talk.politics.guns**, and it's broader than what's typically covered in **sci.electronics** or **comp.os.ms-windows.misc**.
#
# [**talk.politics.misc**]
# Zaktualizowano plik: ./results/cot_random_samples_cohere_temp0.3/llama3/20_newsgroups_llama3_cot_random_samples_cohere_llama3_random42_80_temp0.3_exp4.csv
# Failed to multipart ingest runs: Connection error caused failure to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. The content length of 410940336 bytes exceeds the maximum size limit of 20971520 bytes. SSLError(MaxRetryError("HTTPSConnectionPool(host='api.smith.langchain.com', port=443): Max retries exceeded with url: /runs/multipart (Caused by SSLError(SSLError(5, '[SYS] unknown error (_ssl.c:2417)')))"))
# Content-Length: 410940336
# API Key: lsv2_********************************************7etrace=f32b21ef-16c8-47c1-a82e-9af6952a3b16,id=f32b21ef-16c8-47c1-a82e-9af6952a3b16

# %%
output_path
# Out:
# './results/cot_random_samples_cohere_temp0.3/llama3/20_newsgroups_llama3_cot_random_samples_cohere_llama3_random42_80_temp0.3_exp4.csv'

# %%
df_combined
# Out:
#                                                    text  \
# 0     article ashish arora writes excerpts netnewssc...
# 1     gateway telepath modem month actually one woul...
# 2     anybody provide advice concerning following tw...
# 3     article mike silverman writes anybody know goi...
# 4     article stich christian e writes installed mot...
# ...                                                 ...
# 2019  david sternlight writes article karl barrus wr...
# 2020  hello im looking information alphanumeric page...
# 2021  john r daker writes would like offocially nomi...
# 2022  article writes looking information concerning ...
# 2023  steve brinich writes flaming libertarian paran...
#
#                                                  output  \
# 0     To determine the most appropriate category for...
# 1     Let's break down the text step by step.\n\n**S...
# 2     Let's analyze the text step by step:\n\n**Step...
# 3     Let's analyze the text step by step:\n\n1. Sum...
# 4     Let's break down the analysis step by step:\n\...
# ...                                                 ...
# 2019  To determine the most appropriate category for...
# 2020  Let's analyze the text step by step:\n\n1. **S...
# 2021  To determine the most appropriate category for...
# 2022  Let's break down the text step by step.\n\n**S...
# 2023  To determine the most appropriate category for...
#
#                                                logprobs  \
# 0     {'content': [{'token': 'To', 'bytes': [84, 111...
# 1     {'content': [{'token': 'Let', 'bytes': [76, 10...
# 2     {'content': [{'token': 'Let', 'bytes': [76, 10...
# 3     {'content': [{'token': 'Let', 'bytes': [76, 10...
# 4     {'content': [{'token': 'Let', 'bytes': [76, 10...
# ...                                                 ...
# 2019  {'content': [{'token': 'To', 'bytes': [84, 111...
# 2020  {'content': [{'token': 'Let', 'bytes': [76, 10...
# 2021  {'content': [{'token': 'To', 'bytes': [84, 111...
# 2022  {'content': [{'token': 'Let', 'bytes': [76, 10...
# 2023  {'content': [{'token': 'To', 'bytes': [84, 111...
#
#                                            top_logprobs  \
# 0     [{'token': 'To', 'bytes': [84, 111], 'logprob'...
# 1     [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 2     [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 3     [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 4     [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# ...                                                 ...
# 2019  [{'token': 'To', 'bytes': [84, 111], 'logprob'...
# 2020  [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 2021  [{'token': 'To', 'bytes': [84, 111], 'logprob'...
# 2022  [{'token': 'Let', 'bytes': [76, 101, 116], 'lo...
# 2023  [{'token': 'To', 'bytes': [84, 111], 'logprob'...
#
#                 original_label  original_index was_in_selected_samples  \
# 0           talk.politics.misc               0                     NaN
# 1     comp.sys.ibm.pc.hardware               1                     NaN
# 2                      sci.med               2                     NaN
# 3           rec.sport.baseball               3                     NaN
# 4              sci.electronics               4                     NaN
# ...                        ...             ...                     ...
# 2019                 sci.crypt            1995                   False
# 2020           sci.electronics            1996                   False
# 2021           rec.motorcycles            1997                   False
# 2022                 sci.space            1998                   False
# 2023                 sci.crypt            1999                   False
#
#              extracted_label
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 2019               sci.crypt
# 2020         sci.electronics
# 2021         rec.motorcycles
# 2022               sci.space
# 2023  **talk.politics.misc**
#
# [2000 rows x 8 columns]
