# %%
import pandas as pd
from dict import depression_labels, newsgroups_labels, emotion_labels, news_labels, yahoo_labels, rating_labels
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from utils import get_dataset, get_model_by_tag, get_prompt_template
from LLMAnnotator import LLMAnnotator

# %%
os.environ['OPENAI_API_KEY_CLARIN']=os.getenv("OPENAI_API_KEY_CLARIN")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

token = os.getenv("OPENAI_API_KEY_CLARIN")

# %%
dataset = '20_newsgroups'
# exp = 5
num_exp = 80
model_tag = 'llama3'
# path = f'results/cot_random_samples_cohere_temp0.3/cohere/{dataset}_cohere_cot_random_samples_cohere_cohere_random42_{num_exp}_temp0.3_exp{exp}.csv'
# df = pd.read_csv(path)
selected_samples = 'cot_random_samples_cohere'
tempp = 0

# %%
def get_dict(dataset):
    if(dataset == 'ag_news'):
        return news_labels
    if(dataset == 'yahoo'):
        return yahoo_labels
    if(dataset == '20_newsgroups'):
        return newsgroups_labels
    if(dataset == 'social_media'):
        return depression_labels
    if(dataset == 'go_emotions'):
        return emotion_labels
    if(dataset == 'sst5'):
        return rating_labels

# %%
def calculate_accuracy(df):
    # Bierzemy tylko wiersze, gdzie obie kolumny nie są NaN i was_in_selected_samples jest False
    valid = df[df['was_in_selected_samples'] == False]

    # Zastępujemy wartości NaN pustym ciągiem (lub inną wartością)
    valid['original_label'] = valid['original_label'].fillna('')
    valid['extraction_complete'] = valid['extraction_complete'].fillna('')

    # Liczymy ile jest zgodnych wartości
    matches = (valid['original_label'] == valid['extraction_complete']).sum()

    # Dokładność = liczba zgodnych / liczba wierszy do porównania
    accuracy = matches / len(valid) if len(valid) > 0 else 0

    return accuracy

# %%
labels = get_dict(dataset)
labels
# Out:
# {'rec.sport.hockey': 0,
#  'soc.religion.christian': 1,
#  'rec.sport.baseball': 2,
#  'rec.motorcycles': 3,
#  'sci.crypt': 4,
#  'rec.autos': 5,
#  'sci.med': 6,
#  'sci.space': 7,
#  'comp.os.ms-windows.misc': 8,
#  'comp.sys.ibm.pc.hardware': 9,
#  'sci.electronics': 10,
#  'comp.windows.x': 11,
#  'comp.graphics': 12,
#  'misc.forsale': 13,
#  'comp.sys.mac.hardware': 14,
#  'talk.politics.mideast': 15,
#  'talk.politics.guns': 16,
#  'alt.atheism': 17,
#  'talk.politics.misc': 18,
#  'talk.religion.misc': 19}

# %%
def find_non_matching_labels_df(label_dict, df):
    keys_set = set(label_dict.keys())
    mask = (~df['extracted_label'].isin(keys_set)) & (df['extracted_label'].notna()) & (df['extracted_label'] != '')
    filtered = df.loc[mask].copy()
    filtered['indeks'] = filtered.index
    return filtered.reset_index(drop=True)

# %%
def fill_missing_labels(df, label_dict, new_values):
    keys_set = set(label_dict.keys())
    
    # Znajdź indeksy wierszy, gdzie extracted_label nie jest w kluczach i jest puste lub inne
    mask = (~df['extracted_label'].isin(keys_set)) | (df['extracted_label'].isna()) | (df['extracted_label'] == '')
    indices_to_fill = df.index[mask]

    n_fill = min(len(indices_to_fill), len(new_values))

    # Podstawiamy nowe wartości do kolumny 'extracted_label_by_llm'
    for i in range(n_fill):
        df.at[indices_to_fill[i], 'extracted_label_by_llm'] = new_values[i]

    # Tworzymy kolumnę 'extraction_complete':
    # Jeśli 'extracted_label' jest w keys_set, to bierzemy ją,
    # w przeciwnym razie jeśli 'extracted_label_by_llm' jest w keys_set, to ją bierzemy,
    # inaczej NaN
    def choose_label(row):
        if row['extracted_label'] in keys_set:
            return row['extracted_label']
        elif 'extracted_label_by_llm' in row and row['extracted_label_by_llm'] in keys_set:
            return row['extracted_label_by_llm']
        else:
            return pd.NA

    df['extraction_complete'] = df.apply(choose_label, axis=1)

    return df



def generate_task_string(category_dict):
    categories = ', '.join(category_dict.keys())
    prompt = (
        "Task: Determine which category was chosen as the final one. Possible categories:\n\n"
        f"{categories}\n\n"
        'Text for you: "{text}"\n\n'
        "Return only one category. No explanations."
    )
    return prompt

# %%
prompt = generate_task_string(labels)

# %%
prompt
# Out:
# 'Task: Determine which category was chosen as the final one. Possible categories:\n\nrec.sport.hockey, soc.religion.christian, rec.sport.baseball, rec.motorcycles, sci.crypt, rec.autos, sci.med, sci.space, comp.os.ms-windows.misc, comp.sys.ibm.pc.hardware, sci.electronics, comp.windows.x, comp.graphics, misc.forsale, comp.sys.mac.hardware, talk.politics.mideast, talk.politics.guns, alt.atheism, talk.politics.misc, talk.religion.misc\n\nText for you: "{text}"\n\nReturn only one category. No explanations.'

# %%
from LLMAnnotator import LLMAnnotator
from utils import get_dataset, get_model_by_tag, get_prompt_template


for i in [1]:
    print(f"Iteration {i}")
    path  = f'results/{selected_samples}_temp{tempp}/{model_tag}/{dataset}_{model_tag}_{selected_samples}_{model_tag}_random42_{num_exp}_temp{tempp}_exp{i}.csv'
    temp = 0
    model = get_model_by_tag(model_tag, token)  
    df_ori = pd.read_csv(path)
    wrong = find_non_matching_labels_df(labels, df_ori)
    dataset_for_annotation = wrong
    prompt_txt = prompt
    # output_path = f'./results/cot_random_samples_temp{temp}/{model_tag}_extraction/{model_tag}_{model_tag}_{prompt}_{selected_samples}_temp{temp}_exp{i}.csv'
    # os.makedirs(f'./results/{prompt}_temp{temp}/{model_tag}', exist_ok=True)
    text_col = "output"
    label_col = "original_label"
    output_col = "extracted_by_llm"
    
    print('Len:', len(wrong))
    if(len(wrong) != 0):
        
        annotator = LLMAnnotator(
            model=model,
            dataset=dataset_for_annotation,
            examples_for_prompt=pd.DataFrame(),
            prompt_template=prompt,
            column_text=text_col,
            column_label=label_col,
            column_output=output_col
        )
        
        new_val_list = annotator.get_results()
        
        new_val_df = pd.DataFrame(new_val_list)   
        new_vals = new_val_df['extracted_by_llm'].tolist()  

        df = fill_missing_labels(df_ori, labels, new_vals)
        
        output_path_new = 'extracted/' + path

        folder = os.path.dirname(output_path_new)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
        print(f"Accuracy: {calculate_accuracy(df)}")

        df.to_csv(output_path_new, index=False)
        
    else:
        
        df = fill_missing_labels(df_ori, labels, [])
        output_path_new = 'extracted/' + path
        folder = os.path.dirname(output_path_new)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
        print(f"Accuracy: {calculate_accuracy(df)}")

        df.to_csv(output_path_new, index=False)
# Out:
# Iteration 1
# Len: 121
# Nr: 0 Predicted label: misc.forsale
# Nr: 1 Predicted label: misc.forsale
# Nr: 2 Predicted label: soc.religion.christian
# Nr: 3 Predicted label: talk.politics.misc
# Nr: 4 Predicted label: misc.forsale
# Nr: 5 Predicted label: soc.religion.christian
# Nr: 6 Predicted label: misc.forsale
# Nr: 7 Predicted label: soc.religion.christian
# Nr: 8 Predicted label: talk.religion.misc
# Nr: 9 Predicted label: talk.politics.misc
# Nr: 10 Predicted label: misc.forsale
# Nr: 11 Predicted label: misc.forsale
# Nr: 12 Predicted label: misc.forsale
# Nr: 13 Predicted label: soc.religion.christian
# Nr: 14 Predicted label: talk.religion.misc
# Nr: 15 Predicted label: soc.religion.christian
# Nr: 16 Predicted label: misc.forsale
# Nr: 17 Predicted label: soc.religion.christian
# Nr: 18 Predicted label: talk.religion.misc
# Nr: 19 Predicted label: soc.religion.christian
# Nr: 20 Predicted label: soc.religion.christian
# Nr: 21 Predicted label: talk.politics.misc
# Nr: 22 Predicted label: misc.forsale
# Nr: 23 Predicted label: talk.religion.misc
# Nr: 24 Predicted label: soc.religion.christian
# Nr: 25 Predicted label: soc.religion.christian
# Nr: 26 Predicted label: talk.politics.mideast
# Nr: 27 Predicted label: soc.religion.christian
# Nr: 28 Predicted label: soc.religion.christian
# Nr: 29 Predicted label: talk.politics.misc
# Nr: 30 Predicted label: misc.forsale
# Nr: 31 Predicted label: misc.forsale
# Nr: 32 Predicted label: misc.forsale
# Nr: 33 Predicted label: misc.forsale
# Nr: 34 Predicted label: talk.politics.misc
# Nr: 35 Predicted label: misc.forsale
# Nr: 36 Predicted label: soc.religion.christian
# Nr: 37 Predicted label: soc.religion.christian
# Nr: 38 Predicted label: misc.forsale
# Nr: 39 Predicted label: talk.religion.misc
# Nr: 40 Predicted label: talk.politics.misc
# Nr: 41 Predicted label: misc.forsale
# Nr: 42 Predicted label: soc.religion.christian
# Nr: 43 Predicted label: soc.religion.christian
# Nr: 44 Predicted label: talk.religion.misc
# Nr: 45 Predicted label: misc.forsale
# Nr: 46 Predicted label: soc.religion.christian
# Nr: 47 Predicted label: misc.forsale
# Nr: 48 Predicted label: talk.religion.misc
# Nr: 49 Predicted label: misc.forsale
# Nr: 50 Predicted label: misc.forsale
# Nr: 51 Predicted label: soc.religion.christian
# Nr: 52 Predicted label: misc.forsale
# Nr: 53 Predicted label: misc.forsale
# Nr: 54 Predicted label: talk.religion.misc
# Nr: 55 Predicted label: talk.politics.misc
# Nr: 56 Predicted label: misc.forsale
# Nr: 57 Predicted label: talk.politics.mideast
# Nr: 58 Predicted label: talk.politics.misc
# Nr: 59 Predicted label: talk.politics.misc
# Nr: 60 Predicted label: talk.politics.misc
# Nr: 61 Predicted label: misc.forsale
# Nr: 62 Predicted label: talk.politics.misc
# Nr: 63 Predicted label: talk.politics.misc
# Nr: 64 Predicted label: soc.religion.christian
# Nr: 65 Predicted label: talk.religion.misc
# Nr: 66 Predicted label: talk.politics.misc
# Nr: 67 Predicted label: soc.religion.christian
# Nr: 68 Predicted label: soc.religion.christian
# Nr: 69 Predicted label: misc.forsale
# Nr: 70 Predicted label: soc.religion.christian
# Nr: 71 Predicted label: misc.forsale
# Nr: 72 Predicted label: talk.religion.misc
# Nr: 73 Predicted label: talk.religion.misc
# Nr: 74 Predicted label: misc.forsale
# Nr: 75 Predicted label: soc.religion.christian
# Nr: 76 Predicted label: talk.religion.misc
# Nr: 77 Predicted label: soc.religion.christian
# Nr: 78 Predicted label: misc.forsale
# Nr: 79 Predicted label: talk.politics.misc
# Nr: 80 Predicted label: talk.politics.guns
# Nr: 81 Predicted label: talk.politics.guns
# Nr: 82 Predicted label: talk.religion.misc
# Nr: 83 Predicted label: soc.religion.christian
# Nr: 84 Predicted label: talk.religion.misc
# Nr: 85 Predicted label: misc.forsale
# Nr: 86 Predicted label: misc.forsale
# Nr: 87 Predicted label: soc.religion.christian
# Nr: 88 Predicted label: talk.religion.misc
# Nr: 89 Predicted label: rec.autos
# Nr: 90 Predicted label: misc.forsale
# Nr: 91 Predicted label: talk.religion.misc
# Nr: 92 Predicted label: soc.religion.christian
# Nr: 93 Predicted label: talk.politics.misc
# Nr: 94 Predicted label: talk.religion.misc
# Nr: 95 Predicted label: misc.forsale
# Nr: 96 Predicted label: talk.religion.misc
# Nr: 97 Predicted label: misc.forsale
# Nr: 98 Predicted label: soc.religion.christian
# Nr: 99 Predicted label: soc.religion.christian
# Nr: 100 Predicted label: talk.politics.misc
# Nr: 101 Predicted label: talk.politics.misc
# Nr: 102 Predicted label: alt.atheism
# Nr: 103 Predicted label: talk.politics.misc
# Nr: 104 Predicted label: misc.forsale
# Nr: 105 Predicted label: talk.politics.guns
# Nr: 106 Predicted label: soc.religion.christian
# Nr: 107 Predicted label: misc.forsale
# Nr: 108 Predicted label: talk.politics.misc
# Nr: 109 Predicted label: soc.religion.christian
# Nr: 110 Predicted label: talk.politics.guns
# Nr: 111 Predicted label: soc.religion.christian
# Nr: 112 Predicted label: soc.religion.christian
# Nr: 113 Predicted label: misc.forsale
# Nr: 114 Predicted label: soc.religion.christian
# Nr: 115 Predicted label: soc.religion.christian
# Nr: 116 Predicted label: talk.politics.misc
# Nr: 117 Predicted label: soc.religion.christian
# Nr: 118 Predicted label: misc.forsale
# Nr: 119 Predicted label: misc.forsale
# Nr: 120 Predicted label: misc.forsale
# Accuracy: 0.7438706311945749
# /tmp/ipykernel_4975/3222108288.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['original_label'] = valid['original_label'].fillna('')
# /tmp/ipykernel_4975/3222108288.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['extraction_complete'] = valid['extraction_complete'].fillna('')

# %%
df
# Out:
#       Unnamed: 0                                               text  \
# 0              0  article ashish arora writes excerpts netnewssc...
# 1              1  gateway telepath modem month actually one woul...
# 2              2  anybody provide advice concerning following tw...
# 3              3  article mike silverman writes anybody know goi...
# 4              4  article stich christian e writes installed mot...
# ...          ...                                                ...
# 1995         645  david sternlight writes article karl barrus wr...
# 1996         646  hello im looking information alphanumeric page...
# 1997         647  john r daker writes would like offocially nomi...
# 1998         648  article writes looking information concerning ...
# 1999         649  steve brinich writes flaming libertarian paran...
#
#                                                  output  \
# 0     To determine the most suitable category for th...
# 1     To determine the most suitable category for th...
# 2     To determine the most suitable category for th...
# 3     To determine the most suitable category for th...
# 4     To determine the most suitable category for th...
# ...                                                 ...
# 1995  To determine the most suitable category for th...
# 1996  To determine the most suitable category for th...
# 1997  To determine the most suitable category for th...
# 1998  To determine the most suitable category for th...
# 1999  To determine the most suitable category for th...
#
#                                                logprobs  \
# 0     {'content': [{'token': 'To', 'logprob': -0.176...
# 1     {'content': [{'token': 'To', 'logprob': -0.233...
# 2     {'content': [{'token': 'To', 'logprob': -0.225...
# 3     {'content': [{'token': 'To', 'logprob': -0.148...
# 4     {'content': [{'token': 'To', 'logprob': -0.219...
# ...                                                 ...
# 1995  {'content': [{'token': 'To', 'logprob': -0.181...
# 1996  {'content': [{'token': 'To', 'logprob': -0.183...
# 1997  {'content': [{'token': 'To', 'logprob': -0.148...
# 1998  {'content': [{'token': 'To', 'logprob': -0.268...
# 1999  {'content': [{'token': 'To', 'logprob': -0.166...
#
#                                            top_logprobs  \
# 0     [{'token': 'To', 'logprob': -0.176899492740631...
# 1     [{'token': 'To', 'logprob': -0.233964130282402...
# 2     [{'token': 'To', 'logprob': -0.225865259766578...
# 3     [{'token': 'To', 'logprob': -0.148368075489997...
# 4     [{'token': 'To', 'logprob': -0.219457104802131...
# ...                                                 ...
# 1995  [{'token': 'To', 'logprob': -0.181033700704574...
# 1996  [{'token': 'To', 'logprob': -0.183513775467872...
# 1997  [{'token': 'To', 'logprob': -0.148061156272888...
# 1998  [{'token': 'To', 'logprob': -0.268602669239044...
# 1999  [{'token': 'To', 'logprob': -0.166409581899642...
#
#                 original_label  was_in_selected_samples  \
# 0           talk.politics.misc                     True
# 1     comp.sys.ibm.pc.hardware                    False
# 2                      sci.med                    False
# 3           rec.sport.baseball                    False
# 4              sci.electronics                    False
# ...                        ...                      ...
# 1995                 sci.crypt                    False
# 1996           sci.electronics                    False
# 1997           rec.motorcycles                    False
# 1998                 sci.space                    False
# 1999                 sci.crypt                    False
#
#                extracted_label error extracted_label_by_llm  \
# 0           talk.politics.misc   NaN                    NaN
# 1     comp.sys.ibm.pc.hardware   NaN                    NaN
# 2                      sci.med   NaN                    NaN
# 3           rec.sport.baseball   NaN                    NaN
# 4     comp.sys.ibm.pc.hardware   NaN                    NaN
# ...                        ...   ...                    ...
# 1995                 sci.crypt   NaN                    NaN
# 1996           sci.electronics   NaN                    NaN
# 1997           rec.motorcycles   NaN                    NaN
# 1998                 sci.space   NaN                    NaN
# 1999                 sci.crypt   NaN                    NaN
#
#            extraction_complete
# 0           talk.politics.misc
# 1     comp.sys.ibm.pc.hardware
# 2                      sci.med
# 3           rec.sport.baseball
# 4     comp.sys.ibm.pc.hardware
# ...                        ...
# 1995                 sci.crypt
# 1996           sci.electronics
# 1997           rec.motorcycles
# 1998                 sci.space
# 1999                 sci.crypt
#
# [2000 rows x 11 columns]
